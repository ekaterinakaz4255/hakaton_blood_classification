# %% [markdown]
# # Импорт библиотек

# %%
import re  # Для работы с регулярными выражениями
import os
import pandas as pd
import numpy as np
from datetime import datetime
from glob import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Чтение датасета
df = pd.read_csv('data/data.csv', sep=';')
display(df)
display(df.info())
# Out:
#                          ID истории болезни  \
# 0      2e1d0b3f-488a-11ed-ab5a-0050568844e6
# 1      2e1d0b3f-488a-11ed-ab5a-0050568844e6
# 2      2e1d0b3f-488a-11ed-ab5a-0050568844e6
# 3      2e1d0b3f-488a-11ed-ab5a-0050568844e6
# 4      2e1d0b3f-488a-11ed-ab5a-0050568844e6
# ...                                     ...
# 36292  516f652e-8bb8-11eb-bb95-2cea7fe73f75
# 36293  516f652e-8bb8-11eb-bb95-2cea7fe73f75
# 36294  516f652e-8bb8-11eb-bb95-2cea7fe73f75
# 36295  516f652e-8bb8-11eb-bb95-2cea7fe73f75
# 36296  516f652e-8bb8-11eb-bb95-2cea7fe73f75
#
#               Осн. диаг. при выписке МКБ10 (текст) Заголовок документа  \
# 0                           Плазмоклеточный лейкоз  Общий анализ крови
# 1                           Плазмоклеточный лейкоз  Общий анализ крови
# 2                           Плазмоклеточный лейкоз  Общий анализ крови
# 3                           Плазмоклеточный лейкоз  Общий анализ крови
# 4                           Плазмоклеточный лейкоз  Общий анализ крови
# ...                                            ...                 ...
# 36292  Острый лейкоз неуточненного клеточного типа  Общий анализ крови
# 36293  Острый лейкоз неуточненного клеточного типа  Общий анализ крови
# 36294  Острый лейкоз неуточненного клеточного типа  Общий анализ крови
# 36295  Острый лейкоз неуточненного клеточного типа  Общий анализ крови
# 36296  Острый лейкоз неуточненного клеточного типа  Общий анализ крови
#
#                  Кол. лаб. показатель  Значение кол. показателя  \
# 0                     Лейкоциты (WBC)                      1.80
# 1                    Эритроциты (RBC)                      4.18
# 2                    Гемоглобин (HGB)                    120.00
# 3                    Гематокрит (HCT)                     35.10
# 4      Средний объем эритроцита (MCV)                     84.00
# ...                               ...                       ...
# 36292                        Базофилы                      1.00
# 36293                      Эозинофилы                      0.00
# 36294                    Пролимфоциты                      0.00
# 36295                       Лимфоциты                     65.00
# 36296                        Моноциты                      1.00
#
#       Ед. изм. кол. показателя Норма кол. показателя  \
# 0                       10*9/л                  4:11
# 1                      10*12/л               3,8:5,7
# 2                          г/л               117:160
# 3                            %                 35:47
# 4                           фл                 80:99
# ...                        ...                   ...
# 36292                        %                   0:2
# 36293                        %                   0:5
# 36294                        %                   0:0
# 36295                        %                 18:44
# 36296                        %                  2:12
#
#       Флаг нормы кол. показателя Кач. лаб. показатель  \
# 0                          Пониж                  NaN
# 1                           Норм                  NaN
# 2                           Норм                  NaN
# 3                           Норм                  NaN
# 4                           Норм                  NaN
# ...                          ...                  ...
# 36292                       Норм          Комментарий
# 36293                       Норм          Комментарий
# 36294                       Норм          Комментарий
# 36295                      Повыш          Комментарий
# 36296                      Пониж          Комментарий
#
#                                 Значение кач. показателя  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 36292  Тромбоциты проверены. Рекомендована консультац...
# 36293  Тромбоциты проверены. Рекомендована консультац...
# 36294  Тромбоциты проверены. Рекомендована консультац...
# 36295  Тромбоциты проверены. Рекомендована консультац...
# 36296  Тромбоциты проверены. Рекомендована консультац...
#
#       Норма кач. показателя Пол Дата рождения пациента
# 0                       NaN   Ж    1962-09-22 00:00:00
# 1                       NaN   Ж    1962-09-22 00:00:00
# 2                       NaN   Ж    1962-09-22 00:00:00
# 3                       NaN   Ж    1962-09-22 00:00:00
# 4                       NaN   Ж    1962-09-22 00:00:00
# ...                     ...  ..                    ...
# 36292                     _   М    2014-10-17 00:00:00
# 36293                     _   М    2014-10-17 00:00:00
# 36294                     _   М    2014-10-17 00:00:00
# 36295                     _   М    2014-10-17 00:00:00
# 36296                     _   М    2014-10-17 00:00:00
#
# [36297 rows x 13 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36297 entries, 0 to 36296
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ID истории болезни                    36297 non-null  object
#  1   Осн. диаг. при выписке МКБ10 (текст)  36297 non-null  object
#  2   Заголовок документа                   36297 non-null  object
#  3   Кол. лаб. показатель                  36236 non-null  object
#  4   Значение кол. показателя              36236 non-null  float64
#  5   Ед. изм. кол. показателя              36236 non-null  object
#  6   Норма кол. показателя                 36236 non-null  object
#  7   Флаг нормы кол. показателя            36236 non-null  object
#  8   Кач. лаб. показатель                  7005 non-null   object
#  9   Значение кач. показателя              7005 non-null   object
#  10  Норма кач. показателя                 7005 non-null   object
#  11  Пол                                   36297 non-null  object
#  12  Дата рождения пациента                36297 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 3.6+ MB
# None

# %%
unique_kach_lab = df['Кач. лаб. показатель'].unique()
print(f"Уникальные значения в столбце 'Кач. лаб. показатель': {unique_kach_lab}")
# Out:
# Уникальные значения в столбце 'Кач. лаб. показатель': [nan 'Комментарий' 'Анизоцитоз' 'Гипохромия' 'Пойкилоцитоз' 'Нормобласты'
#  'Микроцитоз' 'Макроцитоз']

# %%
# Удаляем неинформативные столбцы (и так понятно что у нас документ -- ОАК)
print(f'Всего уникальных значений в Заголовке документа: {df["Заголовок документа"].nunique()}')
df = df.drop('Заголовок документа', axis=1)
# Out:
# Всего уникальных значений в Заголовке документа: 1

# %% [markdown]
# ### Этап 1: Перекодировка пола в числовой признак
#
# (перекодируем значение пола и добавим обработку неожиданных значений)

# %%
# Проверяем уникальные значения в столбце "Пол", чтобы убедиться в наличии только ожидаемых значений
unique_gender_values = df['Пол'].unique()
print(f"Уникальные значения в столбце 'Пол' перед преобразованием: {unique_gender_values}")
# Out:
# Уникальные значения в столбце 'Пол' перед преобразованием: ['Ж' 'М']

# %%
# Проверяем и обрабатываем значения
if set(unique_gender_values) <= {"Ж", "М"}:
    # Заменяем "Ж" на 0 и "М" на 1
    df['Пол'] = df['Пол'].map({"Ж": 0, "М": 1})
    print("Значения в столбце 'Пол' успешно заменены на числовые коды.")
else:
    # Если найдены другие значения, выводим предупреждение и не изменяем данные
    print("Предупреждение: найдены неожиданные значения в столбце 'Пол'. Проверьте данные перед продолжением.")
# Out:
# Значения в столбце 'Пол' успешно заменены на числовые коды.

# %% [markdown]
# ### Этап 2: Расчет возраста пациентов

# %%
# Преобразование в формат даты с обработкой некорректных значений
df['Дата рождения пациента'] = pd.to_datetime(df['Дата рождения пациента'], errors='coerce')
print("Столбец 'Дата рождения пациента' успешно преобразован в формат даты.")
# Out:
# Столбец 'Дата рождения пациента' успешно преобразован в формат даты.

# %%
# Удаляем строки с некорректными датами рождения, если такие имеются
initial_row_count = df.shape[0]
df = df.dropna(subset=['Дата рождения пациента'])
dropped_rows = initial_row_count - df.shape[0]
print(f"Количество удаленных строк с некорректными датами рождения: {dropped_rows}")
# Out:
# Количество удаленных строк с некорректными датами рождения: 0

# %%
# Расчет возраста пациента
today = datetime.today()
df['Возраст'] = df['Дата рождения пациента'].apply(
    lambda birth_date: today.year - birth_date.year - ((today.month, today.day) < (birth_date.month, birth_date.day))
)

# %%
# Удаление столбца "Дата рождения пациента"
df = df.drop(columns=['Дата рождения пациента'])
print("Столбец 'Дата рождения пациента' удален из данных после расчета возраста.")
# Out:
# Столбец 'Дата рождения пациента' удален из данных после расчета возраста.

# %% [markdown]
# ### Этап 3: Обработка пропусков по столбцу 'Кол. лаб. показатель'

# %%
# Вывод всех уникальных значений в колонке "Кол. лаб. показатель"
unique_lab_indicators = df['Кол. лаб. показатель'].unique()
print("Уникальные значения в колонке 'Кол. лаб. показатель':")
print(unique_lab_indicators)
# Out:
# Уникальные значения в колонке 'Кол. лаб. показатель':
# ['Лейкоциты (WBC)' 'Эритроциты (RBC)' 'Гемоглобин (HGB)'
#  'Гематокрит (HCT)' 'Средний объем эритроцита (MCV)'
#  'Среднее содержание гемоглобина в эритроците (MCH)'
#  'Средняя концентрация гемоглобина в эритроците (MCHC)' 'Тромбоциты (PLT)'
#  'Нейтрофилы, относительное количество (NE%)'
#  'Лимфоциты, относительное количество (LY%)'
#  'Нейтрофилы, абсолютное количество (NE#)'
#  'Лимфоциты, абсолютное количество (LY#)'
#  'Смешанная фракция, абсолютное количество (MXD#)'
#  'Смешанная фракция, относительное количество (MXD%)'
#  'Ширина распределения эритроцитов по объему, коэффициент вариации (RDW-CV)'
#  'Ширина распределения эритроцитов по объему, стандартное отклонение (RDW-SD)'
#  'Ширина распределения эритроцитов по объему (RDW)' 'Тромбокрит (PCT)'
#  'Средний объем тромбоцита (MPV)' 'Ширина распределения тромбоцитов (PDW)'
#  'Моноциты, относительное количество (MO%)'
#  'Эозинофилы, относительное количество (EO%)'
#  'Базофилы, относительное количество (BA%)'
#  'Моноциты, абсолютное количество (MO#)'
#  'Эозинофилы, абсолютное количество (EO#)'
#  'Базофилы, абсолютное количество (BA#)' 'Цветовой показатель' 'СОЭ Вест.'
#  'Палочкоядерные' 'Сегментоядерные' 'Эозинофилы' 'Лимфоциты' 'Моноциты'
#  'Плазматические клетки'
#  'Скорость оседания эритроцитов (СОЭ) по Вестергрену' 'Базофилы'
#  'Лейкоциты' 'Эритроциты' 'Гемоглобин' 'Гематокрит'
#  'Средний объем эритроцита' 'Среднее содержание гемоглобина в эритроците'
#  'Средняя концентрация гемоглобина в эритроците' 'Тромбоциты' 'Тромбокрит'
#  'Ширина распределения тромбоцитов' 'Нейтрофилы, относительное количество'
#  'Лимфоциты, относительное количество'
#  'Моноциты, относительное количество'
#  'Эозинофилы, относительное количество'
#  'Базофилы, относительное количество' 'Нейтрофилы, абсолютное количество'
#  'Лимфоциты, абсолютное количество' 'Моноциты, абсолютное количество'
#  'Эозинофилы, абсолютное количество' 'Базофилы, абсолютное количество'
#  'Ширина распределения эритроцитов' 'Средний объем тромбоцита' 'Миелоциты'
#  'Юные' 'Бласты' 'Нормобласты'
#  'Ширина распределения эритроцитов по объему, стандартное отклонение'
#  'Ширина распределения эритроцитов по объему, коэффициент вариации'
#  'Ширина распределения тромбоцитов по объему' 'Средний объём тромбоцитов'
#  'Смешанная фракция, относительное количество'
#  'Смешанная фракция, абсолютное количество' 'RET%' 'Ретикулоциты кол-во'
#  'WBC' 'RBC' 'HGB' 'HCT' 'MCV' 'MCH' 'MCHC' 'PLT' 'RDW-SD' 'RDW-CV '
#  'Нейтрофилы %' 'Лимфоциты %' 'Нейтрофилы #' 'Лимфоциты #' 'MXD%' 'MXD#'
#  'Общее количество лейкоцитов (WBC)' 'Общее количество эритроцитов (RBC)'
#  'Относительное количество нейтрофилов (NE%)'
#  'Относительное количество лимфоцитов (LY%)'
#  'Относительное количество моноцитов (MO%)'
#  'Относительное количество эозинофилов (EO%)'
#  'Относительное количество базофилов (BA%)'
#  'Абсолютное количество нейтрофилов (NE#)'
#  'Абсолютное количество лимфоцитов (LY#)'
#  'Абсолютное количество моноцитов (MO#)'
#  'Абсолютное количество эозинофилов (EO#)'
#  'Абсолютное количество базофилов (BA#)'
#  'Ширина распределения эритроцитов (RDW)' 'NE%' 'LY%' 'MO%' 'EO%' 'BA%'
#  'Моноциты #' 'Эозинофилы # ' 'Базофилы #' 'RDW' nan 'СОЭ Панч.'
#  'Моноциты %' 'Эозинофилы %' 'Базофилы %' 'Неклассифицируемые кол-во'
#  'Неклассифицируемые %' 'Пролимфоциты' 'PCT' 'Базофилы # '
#  'MPV (Средний объём тромбоцитов)' 'Ретикулоциты %' 'PDW' 'MPV ' 'MXD'
#  'P-LCR' 'MPV' 'Промиелоциты'
#  'Ширина распределения эритроцитов, стандартное отклонение (RDW-SD)'
#  'СОЭ по Панченкову' 'MXD# ' 'Плазматич. клетки' 'Нормобласты %'
#  'Нормобласты #']

# %% [markdown]
# #### Обработка пропусков

# %%
# Выборка с пропущенными значениями по столбцу Кол. лаб. показатель
df_na = df[df["Кол. лаб. показатель"].isna()]
print(f'Всего строк с пропусками по показателям крови: {df_na.shape[0]}')
print(f'Комментарии: {df_na["Кач. лаб. показатель"].unique()}')
print(f'Причины в комментариях: {df_na["Значение кач. показателя"].unique()}')
# Out:
# Всего строк с пропусками по показателям крови: 61
# Комментарии: ['Комментарий']
# Причины в комментариях: ['сгусток крови!' 'Сгусток' 'сгусток крови'
#  'тромбоциты по мазку 81х10*9/л' ' тромбоциты по мазку 23*10*9/л'
#  'тромбоциты по мазку 21' 'формулу подсчитать невозможно'
#  'тромбоциты пртоверены' 'встречаются микросгустки тромбоцитов' 'сгусток'
#  'тромбоциты проверены по мазку'
#  'шизоциты 4:1000 эритроцитов(№до 10:1000) ' 'нет на месте'
#  'тромбоциты при подсчете по мазку 102' ',' 'ТРОМЮОЦИТЫ ПРОВЕРЕНЫ'
#  'тромбоциты проверены' 'Тромбоциты проверены.' 'сгусток в крови'
#  'тромбоциты по мазку 64*10*9/Л' 'Тромбоциты проверены\t' 'тромб.пров'
#  'СОЭ - 7 мм/ч'
#  'Лейкоциты после пересчета (без учета нормобластов) - 14,4х10х9/л. Тромбоциты проверены.  Моноцитоидные элементы отличаются полимрфизмом ядер,  наличием зернистости в цитоплазме , высоким ядерноцитоплазматическим соотношением .'
#  'подсчитано 50 клеток, моноцитоидные элементы -16'
#  'моноцитарные элементы с нуклеолами в ядре 63,5'
#  'Тромбоциты проверены. Большинство бластных клеток представляет собой клетки крупных и средних размеров, с высоким ядерно-цитоплазматическим соотношением, уродливыми ядрами (неправильной формы ядра). хроматин сглаженный, встречаются нуклеолы. Цитоплазма у части клеток вакуолизированная. '
#  'моноцитойдн элемент49' 'моноцитраные элементы - 60'
#  'бласты 59 ( моноцитоидные)' 'бласты - большая часть моноцитоидной формы'
#  'лейкоцитарную формулу подсчитать невозможно' 'подсчитано 50 клеток'
#  'моноцидоидные элементы с грубой структурой хроматина и остатаками нуклеол'
#  'подсчет л/ф невозможен'
#  'Тромбоциты проверены.  Подсчет лейкоцитарной формулы невозможен из-за  крайне низкого колическва лейкоцитов крови.']

# %% [markdown]
# Среди этих значений можно выделить те, которые нам говорят о некачественном и непригодном образце для определения показателей ОАК. Это, например, указания на наличие сгустка крови и другие причины, при которых подсчет клеток невозможен. Такие строки необходимо удалить:

# %%
# Определяем значения, при которых строки должны быть удалены
values_to_delete = [
    'сгусток крови!', 'Сгусток', 'сгусток крови', 'формулу подсчитать невозможно',
    'тромбоциты пртоверены', 'встречаются микросгустки тромбоцитов', 'сгусток',
    'тромбоциты проверены по мазку', 'нет на месте', 'сгусток в крови', ',',
    'ТРОМЮОЦИТЫ ПРОВЕРЕНЫ', 'тромбоциты проверены', 'Тромбоциты проверены.', 'Тромбоциты проверены\t', 'тромб.пров',
    'Тромбоциты проверены. Большинство бластных клеток представляет собой клетки крупных и средних размеров, с высоким ядерно-цитоплазматическим соотношением, уродливыми ядрами (неправильной формы ядра). хроматин сглаженный, встречаются нуклеолы. Цитоплазма у части клеток вакуолизированная.',
    'лейкоцитарную формулу подсчитать невозможно', 'подсчет л/ф невозможен',
    'моноцидоидные элементы с грубой структурой хроматина и остатаками нуклеол',
    'Тромбоциты проверены. Подсчет лейкоцитарной формулы невозможен из-за крайне низкого количества лейкоцитов крови.',
    'шизоциты 4:1000 эритроцитов(№до 10:1000) ',
    'Лейкоциты после пересчета (без учета нормобластов) - 14,4х10х9/л. Тромбоциты проверены.  Моноцитоидные элементы отличаются полимрфизмом ядер,  наличием зернистости в цитоплазме , высоким ядерноцитоплазматическим соотношением .',
    'моноцитарные элементы с нуклеолами в ядре 63,5',
    'Тромбоциты проверены. Большинство бластных клеток представляет собой клетки крупных и средних размеров, с высоким ядерно-цитоплазматическим соотношением, уродливыми ядрами (неправильной формы ядра). хроматин сглаженный, встречаются нуклеолы. Цитоплазма у части клеток вакуолизированная. ',
    'моноцитойдн элемент49', 'моноцитраные элементы - 60',
    'Тромбоциты проверены.  Подсчет лейкоцитарной формулы невозможен из-за  крайне низкого колическва лейкоцитов крови.'
]

# %%
# Удаляем строки с определенными значениями в "Значение кач. показателя"
df = df[~(df['Кол. лаб. показатель'].isna() & df['Значение кач. показателя'].isin(values_to_delete))]
deleted_rows = initial_row_count - df.shape[0]
print(f"Количество удаленных строк: {deleted_rows}")
# Out:
# Количество удаленных строк: 51

# %% [markdown]
# #### Восстанавливаем оставшеся значения пропусков:

# %%
# Оставшиеся пропуски по столбцу 'Кол. лаб. показатель'
print(f"Всего строк с пропуском по столбцу 'Кол. лаб. показатель': {df[df['Кол. лаб. показатель'].isna()].shape[0]}")
print(f"Причина этих пропусков: {df[df['Кол. лаб. показатель'].isna()]['Значение кач. показателя'].unique()}")
# Out:
# Всего строк с пропуском по столбцу 'Кол. лаб. показатель': 10
# Причина этих пропусков: ['тромбоциты по мазку 81х10*9/л' ' тромбоциты по мазку 23*10*9/л'
#  'тромбоциты по мазку 21' 'тромбоциты при подсчете по мазку 102'
#  'тромбоциты по мазку 64*10*9/Л' 'СОЭ - 7 мм/ч'
#  'подсчитано 50 клеток, моноцитоидные элементы -16'
#  'бласты 59 ( моноцитоидные)' 'бласты - большая часть моноцитоидной формы'
#  'подсчитано 50 клеток']

# %%
# Условие для выбора строк, где 'Значение кач. показателя' == 'тромбоциты по мазку 81х10*9/л'
condition = df['Значение кач. показателя'] == 'тромбоциты по мазку 81х10*9/л'

# Заполнение значений в соответствующих столбцах
df.loc[condition, 'Кол. лаб. показатель'] = 'Тромбоциты (PLT)'
df.loc[condition, 'Значение кол. показателя'] = 81
df.loc[condition, 'Ед. изм. кол. показателя'] = '10*9/л'

# Проверка изменений
df[condition]
# Out:
#                         ID истории болезни  \
# 2378  b36a2106-4308-11ed-ab5a-0050568844e6
#
#      Осн. диаг. при выписке МКБ10 (текст) Кол. лаб. показатель  \
# 2378     Хронический лимфоцитарный лейкоз     Тромбоциты (PLT)
#
#       Значение кол. показателя Ед. изм. кол. показателя Норма кол. показателя  \
# 2378                      81.0                   10*9/л                   NaN
#
#      Флаг нормы кол. показателя Кач. лаб. показатель  \
# 2378                        NaN          Комментарий
#
#            Значение кач. показателя Норма кач. показателя  Пол  Возраст
# 2378  тромбоциты по мазку 81х10*9/л                     _    1       77

# %%
# Условие для выбора строк, где 'Значение кач. показателя' == ' тромбоциты по мазку 23*10*9/л'
condition = df['Значение кач. показателя'] == ' тромбоциты по мазку 23*10*9/л'

# Заполнение значений в соответствующих столбцах
df.loc[condition, 'Кол. лаб. показатель'] = 'Тромбоциты (PLT)'
df.loc[condition, 'Значение кол. показателя'] = 23
df.loc[condition, 'Ед. изм. кол. показателя'] = '10*9/л'

# Проверка изменений
df[condition]
# Out:
#                         ID истории болезни  \
# 5609  eebeb925-9f8e-11ec-ab54-0050568844e6
#
#      Осн. диаг. при выписке МКБ10 (текст) Кол. лаб. показатель  \
# 5609             Другой уточненный лейкоз     Тромбоциты (PLT)
#
#       Значение кол. показателя Ед. изм. кол. показателя Норма кол. показателя  \
# 5609                      23.0                   10*9/л                   NaN
#
#      Флаг нормы кол. показателя Кач. лаб. показатель  \
# 5609                        NaN          Комментарий
#
#             Значение кач. показателя Норма кач. показателя  Пол  Возраст
# 5609   тромбоциты по мазку 23*10*9/л                     _    1       68

# %%
# Условие для выбора строк, где 'Значение кач. показателя' == 'тромбоциты по мазку 21'
condition = df['Значение кач. показателя'] == 'тромбоциты по мазку 21'

# Заполнение значений в соответствующих столбцах
df.loc[condition, 'Кол. лаб. показатель'] = 'Тромбоциты (PLT)'
df.loc[condition, 'Значение кол. показателя'] = 21
df.loc[condition, 'Ед. изм. кол. показателя'] = '10*9/л'

# Проверка изменений
df[condition]
# Out:
#                         ID истории болезни  \
# 5610  eebeb925-9f8e-11ec-ab54-0050568844e6
#
#      Осн. диаг. при выписке МКБ10 (текст) Кол. лаб. показатель  \
# 5610             Другой уточненный лейкоз     Тромбоциты (PLT)
#
#       Значение кол. показателя Ед. изм. кол. показателя Норма кол. показателя  \
# 5610                      21.0                   10*9/л                   NaN
#
#      Флаг нормы кол. показателя Кач. лаб. показатель Значение кач. показателя  \
# 5610                        NaN          Комментарий   тромбоциты по мазку 21
#
#      Норма кач. показателя  Пол  Возраст
# 5610                     _    1       68

# %%
# Условие для выбора строк, где 'Значение кач. показателя' == 'тромбоциты при подсчете по мазку 102',
condition = df['Значение кач. показателя'] ==  'тромбоциты при подсчете по мазку 102'

# Заполнение значений в соответствующих столбцах
df.loc[condition, 'Кол. лаб. показатель'] = 'Тромбоциты (PLT)'
df.loc[condition, 'Значение кол. показателя'] = 102
df.loc[condition, 'Ед. изм. кол. показателя'] = '10*9/л'

# Проверка изменений
df[condition]
# Out:
#                          ID истории болезни  \
# 17789  7b9025cb-ae7c-11ec-ab54-0050568844e6
#
#       Осн. диаг. при выписке МКБ10 (текст) Кол. лаб. показатель  \
# 17789             Другой уточненный лейкоз     Тромбоциты (PLT)
#
#        Значение кол. показателя Ед. изм. кол. показателя  \
# 17789                     102.0                   10*9/л
#
#       Норма кол. показателя Флаг нормы кол. показателя Кач. лаб. показатель  \
# 17789                   NaN                        NaN          Комментарий
#
#                    Значение кач. показателя Норма кач. показателя  Пол  \
# 17789  тромбоциты при подсчете по мазку 102                     _    0
#
#        Возраст
# 17789       72

# %%
# Условие для выбора строк, где 'Значение кач. показателя' == 'тромбоциты по мазку 64*10*9/Л'
condition = df['Значение кач. показателя'] ==  'тромбоциты по мазку 64*10*9/Л'

# Заполнение значений в соответствующих столбцах
df.loc[condition, 'Кол. лаб. показатель'] = 'Тромбоциты (PLT)'
df.loc[condition, 'Значение кол. показателя'] = 64
df.loc[condition, 'Ед. изм. кол. показателя'] = '10*9/л'

# Проверка изменений
df[condition]
# Out:
#                          ID истории болезни  \
# 22833  268d2f6a-32ae-11ea-80c5-901b0e633689
#
#       Осн. диаг. при выписке МКБ10 (текст) Кол. лаб. показатель  \
# 22833             Другой уточненный лейкоз     Тромбоциты (PLT)
#
#        Значение кол. показателя Ед. изм. кол. показателя  \
# 22833                      64.0                   10*9/л
#
#       Норма кол. показателя Флаг нормы кол. показателя Кач. лаб. показатель  \
# 22833                   NaN                        NaN          Комментарий
#
#             Значение кач. показателя Норма кач. показателя  Пол  Возраст
# 22833  тромбоциты по мазку 64*10*9/Л                     _    0       86

# %%
# Условие для выбора строк, где 'Значение кач. показателя' == 'СОЭ - 7 мм/ч'
condition = df['Значение кач. показателя'] ==  'СОЭ - 7 мм/ч'

# Заполнение значений в соответствующих столбцах
df.loc[condition, 'Кол. лаб. показатель'] = 'СОЭ по Вестергрену'
df.loc[condition, 'Значение кол. показателя'] = 7
df.loc[condition, 'Ед. изм. кол. показателя'] = 'мм/час'

# Проверка изменений
df[condition]
# Out:
#                          ID истории болезни  \
# 25849  81f895b9-2ee2-11eb-80e0-901b0e633689
#
#       Осн. диаг. при выписке МКБ10 (текст) Кол. лаб. показатель  \
# 25849             Другой миелоидный лейкоз   СОЭ по Вестергрену
#
#        Значение кол. показателя Ед. изм. кол. показателя  \
# 25849                       7.0                   мм/час
#
#       Норма кол. показателя Флаг нормы кол. показателя Кач. лаб. показатель  \
# 25849                   NaN                        NaN          Комментарий
#
#       Значение кач. показателя Норма кач. показателя  Пол  Возраст
# 25849             СОЭ - 7 мм/ч                     _    1       50

# %%
# Условие для выбора строк, где 'Значение кач. показателя' == 'бласты 59 ( моноцитоидные)'
condition = df['Значение кач. показателя'] ==  'бласты 59 ( моноцитоидные)'

# Заполнение значений в соответствующих столбцах
df.loc[condition, 'Кол. лаб. показатель'] = 'Бласты (абс)'
df.loc[condition, 'Значение кол. показателя'] = 59
df.loc[condition, 'Ед. изм. кол. показателя'] = 'кол-во клеток'
df.loc[condition, 'Норма кол. показателя'] = '0:0'
df.loc[condition, 'Флаг нормы кол. показателя'] = 'Повыш'

# Проверка изменений
df[condition]
# Out:
#                          ID истории болезни  \
# 27365  72f64027-6cf5-11ea-80ce-901b0e63368b
#
#       Осн. диаг. при выписке МКБ10 (текст) Кол. лаб. показатель  \
# 27365             Острый миелоидный лейкоз         Бласты (абс)
#
#        Значение кол. показателя Ед. изм. кол. показателя  \
# 27365                      59.0            кол-во клеток
#
#       Норма кол. показателя Флаг нормы кол. показателя Кач. лаб. показатель  \
# 27365                   0:0                      Повыш          Комментарий
#
#          Значение кач. показателя Норма кач. показателя  Пол  Возраст
# 27365  бласты 59 ( моноцитоидные)                     _    0       61

# %%
# Условие для выбора строк, где 'Значение кач. показателя' == 'подсчитано 50 клеток'
condition = df['Значение кач. показателя'] ==  'подсчитано 50 клеток'

# Заполнение значений в соответствующих столбцах
df.loc[condition, 'Кол. лаб. показатель'] = 'Бласты (абс)'
df.loc[condition, 'Значение кол. показателя'] = 50
df.loc[condition, 'Ед. изм. кол. показателя'] = 'кол-во клеток'
df.loc[condition, 'Норма кол. показателя'] = '0:0'
df.loc[condition, 'Флаг нормы кол. показателя'] = 'Повыш'

# Проверка изменений
df[condition]
# Out:
#                          ID истории болезни  \
# 27708  4f87b4a4-4406-11ea-80c7-901b0e633688
#
#       Осн. диаг. при выписке МКБ10 (текст) Кол. лаб. показатель  \
# 27708             Острый миелоидный лейкоз         Бласты (абс)
#
#        Значение кол. показателя Ед. изм. кол. показателя  \
# 27708                      50.0            кол-во клеток
#
#       Норма кол. показателя Флаг нормы кол. показателя Кач. лаб. показатель  \
# 27708                   0:0                      Повыш          Комментарий
#
#       Значение кач. показателя Норма кач. показателя  Пол  Возраст
# 27708     подсчитано 50 клеток                     _    0       65

# %%
# Условие для выбора строк, где 'Значение кач. показателя' == 'подсчитано 50 клеток, моноцитоидные элементы -16'
condition = df['Значение кач. показателя'] ==  'подсчитано 50 клеток, моноцитоидные элементы -16'

# Заполнение значений в соответствующих столбцах
df.loc[condition, 'Кол. лаб. показатель'] = 'Бласты (абс)'
df.loc[condition, 'Значение кол. показателя'] = 50
df.loc[condition, 'Ед. изм. кол. показателя'] = 'кол-во клеток'
df.loc[condition, 'Норма кол. показателя'] = '0:0'
df.loc[condition, 'Флаг нормы кол. показателя'] = 'Повыш'

# Проверка изменений
df[condition]
# Out:
#                          ID истории болезни  \
# 27047  72f64027-6cf5-11ea-80ce-901b0e63368b
#
#       Осн. диаг. при выписке МКБ10 (текст) Кол. лаб. показатель  \
# 27047             Острый миелоидный лейкоз         Бласты (абс)
#
#        Значение кол. показателя Ед. изм. кол. показателя  \
# 27047                      50.0            кол-во клеток
#
#       Норма кол. показателя Флаг нормы кол. показателя Кач. лаб. показатель  \
# 27047                   0:0                      Повыш          Комментарий
#
#                                Значение кач. показателя Норма кач. показателя  \
# 27047  подсчитано 50 клеток, моноцитоидные элементы -16                     _
#
#        Пол  Возраст
# 27047    0       61

# %%
# Условие для выбора строк, где 'Значение кач. показателя' == 'бласты - большая часть моноцитоидной формы'
condition = df['Значение кач. показателя'] ==  'бласты - большая часть моноцитоидной формы'

# Заполнение значений в соответствующих столбцах
df.loc[condition, 'Кол. лаб. показатель'] = 'Бласты (абс)'
df.loc[condition, 'Значение кол. показателя'] = "1"
df.loc[condition, 'Ед. изм. кол. показателя'] = 'кол-во клеток'
df.loc[condition, 'Норма кол. показателя'] = '0:0'
df.loc[condition, 'Флаг нормы кол. показателя'] = 'Повыш'

# Проверка изменений
df[condition]
# Out:
# C:\Users\Екатерина\AppData\Local\Temp\ipykernel_10652\3272911212.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[condition, 'Значение кол. показателя'] = "1"
#                          ID истории болезни  \
# 27366  72f64027-6cf5-11ea-80ce-901b0e63368b
#
#       Осн. диаг. при выписке МКБ10 (текст) Кол. лаб. показатель  \
# 27366             Острый миелоидный лейкоз         Бласты (абс)
#
#       Значение кол. показателя Ед. изм. кол. показателя Норма кол. показателя  \
# 27366                        1            кол-во клеток                   0:0
#
#       Флаг нормы кол. показателя Кач. лаб. показатель  \
# 27366                      Повыш          Комментарий
#
#                          Значение кач. показателя Норма кач. показателя  Пол  \
# 27366  бласты - большая часть моноцитоидной формы                     _    0
#
#        Возраст
# 27366       61

# %%
# Оставшиеся пропуски по столбцу 'Кол. лаб. показатель'
print(f"Всего строк с пропуском по столбцу 'Кол. лаб. показатель': {df[df['Кол. лаб. показатель'].isna()].shape[0]}")
# Out:
# Всего строк с пропуском по столбцу 'Кол. лаб. показатель': 0

# %% [markdown]
# ### Этап 4: Унификация лаб. показателей в столбце 'Кол. лаб. показатель'
#
# Цель: Объединить одинаковые показатели, которые представлены разными наименованиями и единицами, чтобы сделать данные более унифицированными и удобными для анализа.

# %%
# Создаем словарь для унификации показателей и приведения их к общему названию
unification_dict = {
    'Лейкоциты (WBC)': 'Лейкоциты (WBC)',
    'WBC': 'Лейкоциты (WBC)',
    'Общее количество лейкоцитов (WBC)': 'Лейкоциты (WBC)',
    'Лейкоциты': 'Лейкоциты (WBC)', # проверено
    
    'Эритроциты (RBC)': 'Эритроциты (RBC)',
    'RBC': 'Эритроциты (RBC)',
    'Общее количество эритроцитов (RBC)': 'Эритроциты (RBC)',
    'Эритроциты': 'Эритроциты (RBC)', # проверено
    
    'Гемоглобин (HGB)': 'Гемоглобин (HGB)',
    'HGB': 'Гемоглобин (HGB)',
    'Гемоглобин': 'Гемоглобин (HGB)', # проверено
    
    'Гематокрит (HCT)': 'Гематокрит (HCT)',
    'HCT': 'Гематокрит (HCT)',
    'Гематокрит': 'Гематокрит (HCT)', # проверено

    'Тромбоциты (PLT)': 'Тромбоциты (PLT)',
    'PLT': 'Тромбоциты (PLT)',
    'Тромбоциты': 'Тромбоциты (PLT)', # проверено
    
    'Средний объем эритроцита (MCV)': 'Средний объем эритроцита (MCV)',
    'MCV': 'Средний объем эритроцита (MCV)',
    'Средний объем эритроцита': 'Средний объем эритроцита (MCV)', # проверено
    
    'Среднее содержание гемоглобина в эритроците (MCH)': 'Среднее содержание гемоглобина в эритроците (MCH)',
    'MCH': 'Среднее содержание гемоглобина в эритроците (MCH)',
    'Среднее содержание гемоглобина в эритроците': 'Среднее содержание гемоглобина в эритроците (MCH)', # проверено
    
    'Средняя концентрация гемоглобина в эритроците (MCHC)': 'Средняя концентрация гемоглобина в эритроците (MCHC)',
    'MCHC': 'Средняя концентрация гемоглобина в эритроците (MCHC)',
    'Средняя концентрация гемоглобина в эритроците': 'Средняя концентрация гемоглобина в эритроците (MCHC)', # проверено

    'Средний объем тромбоцита (MPV)': 'Средний объем тромбоцита (MPV)',
    'MPV': 'Средний объем тромбоцита (MPV)',
    'MPV ': 'Средний объем тромбоцита (MPV)',
    'MPV (Средний объём тромбоцитов)': 'Средний объем тромбоцита (MPV)',
    'Средний объём тромбоцитов': 'Средний объем тромбоцита (MPV)',
    'Средний объём тромбоцита': 'Средний объем тромбоцита (MPV)', 
    'Средний объем тромбоцита': 'Средний объем тромбоцита (MPV)', # проверено

    'Тромбокрит (PCT)': 'Тромбокрит (PCT)',
    'PCT': 'Тромбокрит (PCT)',
    'Тромбокрит': 'Тромбокрит (PCT)', # проверено
    
    'Ширина распределения эритроцитов по объему (RDW)': 'Распределение эритроцитов по объему (RDW)',
    'Ширина распределения эритроцитов': 'Распределение эритроцитов по объему (RDW)',
    'RDW': 'Распределение эритроцитов по объему (RDW)', # проверено
    'Ширина распределения эритроцитов (RDW)': 'Распределение эритроцитов по объему (RDW)',

    'Ширина распределения эритроцитов по объему, коэффициент вариации (RDW-CV)': 'Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)',
    'Ширина распределения эритроцитов по объему, коэффициент вариации': 'Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)',
    'RDW-CV': 'Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)',
    'RDW-CV ': 'Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)', # проверено

    'Ширина распределения эритроцитов по объему, стандартное отклонение (RDW-SD)': 'Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)',
    'Ширина распределения эритроцитов по объему, стандартное отклонение': 'Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)', 
    'Ширина распределения эритроцитов, стандартное отклонение (RDW-SD)': 'Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)',
    'RDW-SD': 'Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)', # проверено

    'Ширина распределения тромбоцитов (PDW)': 'Распределение тромбоцитов по объему (PDW)',
    'Ширина распределения тромбоцитов': 'Распределение тромбоцитов по объему (PDW)',
    'Ширина распределения тромбоцитов по объему': 'Распределение тромбоцитов по объему (PDW)',
    'PDW': 'Распределение тромбоцитов по объему (PDW)', # проверено

    'Скорость оседания эритроцитов (СОЭ) по Вестергрену': 'СОЭ по Вестергрену',
    'СОЭ Вест.': 'СОЭ по Вестергрену',
    'СОЭ': 'СОЭ по Вестергрену', # проверено
    
    'Нейтрофилы, относительное количество (NE%)': 'Нейтрофилы, относительное количество (NE%)',
    'Относительное количество нейтрофилов (NE%)': 'Нейтрофилы, относительное количество (NE%)',
    'NE%': 'Нейтрофилы, относительное количество (NE%)',
    'Нейтрофилы %': 'Нейтрофилы, относительное количество (NE%)',
    'Нейтрофилы, относительное количество': 'Нейтрофилы, относительное количество (NE%)', # проверено
    
    'Нейтрофилы, абсолютное количество (NE#)': 'Нейтрофилы, абсолютное количество (NE#)',
    'Абсолютное количество нейтрофилов (NE#)': 'Нейтрофилы, абсолютное количество (NE#)',
    'Нейтрофилы #': 'Нейтрофилы, абсолютное количество (NE#)',
    'Нейтрофилы, абсолютное количество': 'Нейтрофилы, абсолютное количество (NE#)', # проверено
    
    'Лимфоциты, относительное количество (LY%)': 'Лимфоциты, относительное количество (LY%)',
    'Относительное количество лимфоцитов (LY%)': 'Лимфоциты, относительное количество (LY%)',
    'LY%': 'Лимфоциты, относительное количество (LY%)',
    'Лимфоциты %': 'Лимфоциты, относительное количество (LY%)',
    'Лимфоциты, относительное количество': 'Лимфоциты, относительное количество (LY%)', # проверено
    
    'Лимфоциты, абсолютное количество (LY#)': 'Лимфоциты, абсолютное количество (LY#)',
    'Абсолютное количество лимфоцитов (LY#)': 'Лимфоциты, абсолютное количество (LY#)',
    'Лимфоциты #': 'Лимфоциты, абсолютное количество (LY#)',
    'Лимфоциты, абсолютное количество': 'Лимфоциты, абсолютное количество (LY#)', # проверено

    'Моноциты, относительное количество (MO%)': 'Моноциты, относительное количество (MO%)',
    'Моноциты, относительное количество': 'Моноциты, относительное количество (MO%)',
    'Относительное количество моноцитов (MO%)': 'Моноциты, относительное количество (MO%)',
    'MO%': 'Моноциты, относительное количество (MO%)',
    'Моноциты %': 'Моноциты, относительное количество (MO%)', # проверено

    'Моноциты, абсолютное количество (MO#)': 'Моноциты, абсолютное количество (MO#)',
    'Моноциты, абсолютное количество': 'Моноциты, абсолютное количество (MO#)',
    'Абсолютное количество моноцитов (MO#)': 'Моноциты, абсолютное количество (MO#)',
    'Моноциты #': 'Моноциты, абсолютное количество (MO#)', # проверено

    'Эозинофилы, относительное количество (EO%)': 'Эозинофилы, относительное количество (EO%)',
    'Эозинофилы, относительное количество': 'Эозинофилы, относительное количество (EO%)',
    'Относительное количество эозинофилов (EO%)': 'Эозинофилы, относительное количество (EO%)',
    'Эозинофилы %': 'Эозинофилы, относительное количество (EO%)',
    'EO%': 'Эозинофилы, относительное количество (EO%)', # проверено

    'Эозинофилы, абсолютное количество (EO#)': 'Эозинофилы, абсолютное количество (EO#)',
    'Эозинофилы, абсолютное количество': 'Эозинофилы, абсолютное количество (EO#)',
    'Абсолютное количество эозинофилов (EO#)': 'Эозинофилы, абсолютное количество (EO#)',
    'Эозинофилы # ': 'Эозинофилы, абсолютное количество (EO#)',
    'Эозинофилы #': 'Эозинофилы, абсолютное количество (EO#)', # проверено

    'Базофилы, относительное количество (BA%)': 'Базофилы, относительное количество (BA%)',
    'Базофилы, относительное количество': 'Базофилы, относительное количество (BA%)',
    'Относительное количество базофилов (BA%)': 'Базофилы, относительное количество (BA%)',
    'Базофилы %': 'Базофилы, относительное количество (BA%)',
    'BA%': 'Базофилы, относительное количество (BA%)', # проверено

    'Базофилы, абсолютное количество (BA#)': 'Базофилы, абсолютное количество (BA#)',
    'Абсолютное количество базофилов (BA#)': 'Базофилы, абсолютное количество (BA#)',
    'Базофилы, абсолютное количество': 'Базофилы, абсолютное количество (BA#)',
    'Базофилы #': 'Базофилы, абсолютное количество (BA#)',
    'Базофилы # ': 'Базофилы, абсолютное количество (BA#)', # проверено
    
    'Смешанная фракция, относительное количество (MXD%)': 'Смешанная фракция, относительное количество (MXD%)',
    'Смешанная фракция, относительное количество': 'Смешанная фракция, относительное количество (MXD%)',
    'MXD%': 'Смешанная фракция, относительное количество (MXD%)', # проверено
        
    'Смешанная фракция, абсолютное количество (MXD#)': 'Смешанная фракция, абсолютное количество (MXD#)',
    'Смешанная фракция, абсолютное количество': 'Смешанная фракция, абсолютное количество (MXD#)',
    'MXD#': 'Смешанная фракция, абсолютное количество (MXD#)',
    'MXD# ': 'Смешанная фракция, абсолютное количество (MXD#)', # проверено

    'Нормобласты %': 'Нормобласты, относительное количество (%)', # проверено
    'Нормобласты #': 'Нормобласты, абсолютное количество (#)', # проверено
    'Ретикулоциты %': 'Ретикулоциты, абсолютное количество (#)', # проверено
    'Ретикулоциты кол-во': 'Ретикулоциты, абсолютное количество (#)', # проверено
    'RET%': 'Ретикулоциты, относительное количество (%)', # проверено
    'Цветовой показатель': 'Цветовой показатель', 
    
    'Палочкоядерные': 'Палочкоядерные нейтрофилы (%)',
    'Сегментоядерные': 'Сегментоядерные нейтрофилы (%)',
    'Базофилы': 'Базофилы (лейкоцитарная формула, %)',
    'Лимфоциты': 'Лимфоциты (лейкоцитарная формула, %)',
    'Моноциты': 'Моноциты (лейкоцитарная формула, %)',
    'Эозинофилы': 'Эозинофилы (лейкоцитарная формула, %)',
    'Плазматические клетки': 'Плазматические клетки',
    'Плазматич. клетки': 'Плазматические клетки',
    'Миелоциты': 'Миелоциты (лейкоцитарная формула, %)',
    'Промиелоциты': 'Промиелоциты (лейкоцитарная формула, %)',
    'Пролимфоциты': 'Пролимфоциты (лейкоцитарная формула, %)',
    'Нормобласты': 'Нормобласты',
    'P-LCR': 'P-LCR',
}

# %%
# Применяем унификацию названий
df['Кол. лаб. показатель'] = df['Кол. лаб. показатель'].replace(unification_dict)
print("Наименования показателей успешно унифицированы.")
# Out:
# Наименования показателей успешно унифицированы.

# %%
new_unique_lab_indicators = df['Кол. лаб. показатель'].unique()
print("Новые уникальные значения в колонке 'Кол. лаб. показатель':")
print(new_unique_lab_indicators)
# Out:
# Новые уникальные значения в колонке 'Кол. лаб. показатель':
# ['Лейкоциты (WBC)' 'Эритроциты (RBC)' 'Гемоглобин (HGB)'
#  'Гематокрит (HCT)' 'Средний объем эритроцита (MCV)'
#  'Среднее содержание гемоглобина в эритроците (MCH)'
#  'Средняя концентрация гемоглобина в эритроците (MCHC)' 'Тромбоциты (PLT)'
#  'Нейтрофилы, относительное количество (NE%)'
#  'Лимфоциты, относительное количество (LY%)'
#  'Нейтрофилы, абсолютное количество (NE#)'
#  'Лимфоциты, абсолютное количество (LY#)'
#  'Смешанная фракция, абсолютное количество (MXD#)'
#  'Смешанная фракция, относительное количество (MXD%)'
#  'Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)'
#  'Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)'
#  'Распределение эритроцитов по объему (RDW)' 'Тромбокрит (PCT)'
#  'Средний объем тромбоцита (MPV)'
#  'Распределение тромбоцитов по объему (PDW)'
#  'Моноциты, относительное количество (MO%)'
#  'Эозинофилы, относительное количество (EO%)'
#  'Базофилы, относительное количество (BA%)'
#  'Моноциты, абсолютное количество (MO#)'
#  'Эозинофилы, абсолютное количество (EO#)'
#  'Базофилы, абсолютное количество (BA#)' 'Цветовой показатель'
#  'СОЭ по Вестергрену' 'Палочкоядерные нейтрофилы (%)'
#  'Сегментоядерные нейтрофилы (%)' 'Эозинофилы (лейкоцитарная формула, %)'
#  'Лимфоциты (лейкоцитарная формула, %)'
#  'Моноциты (лейкоцитарная формула, %)' 'Плазматические клетки'
#  'Базофилы (лейкоцитарная формула, %)'
#  'Миелоциты (лейкоцитарная формула, %)' 'Юные' 'Бласты' 'Нормобласты'
#  'Ретикулоциты, относительное количество (%)'
#  'Ретикулоциты, абсолютное количество (#)' 'СОЭ Панч.'
#  'Неклассифицируемые кол-во' 'Неклассифицируемые %'
#  'Пролимфоциты (лейкоцитарная формула, %)' 'MXD' 'P-LCR'
#  'Промиелоциты (лейкоцитарная формула, %)' 'СОЭ по Панченкову'
#  'Нормобласты, относительное количество (%)'
#  'Нормобласты, абсолютное количество (#)' 'Бласты (абс)']

# %% [markdown]
# #### Удаление неинформативных значений

# %% [markdown]
# **СОЭ по Панченкову** - это устаревший метод определения СОЭ, который было решено удалить. Метод Вестергрена одобрен в качестве эталонного Международным комитетом по стандартизации в гематологии (ICSH) и регулируется стандартом Института клинических и лабораторных стандартов (CLSI).
#
# Показатель **смешанной фракции или MXD** отражает суммарно долю базофилов, эозинофилов и моноцитов. И, так как эти показатели у нас есть отдельно, то суммарный вероятно будет с ними коррелировать, в связи с чем его следует удалить.
#
# Удалим также P-LCR, который не очень специфичен в дифф. диагностике лейкозов с другими заболеваниями

# %%
# Список значений для удаления
values_to_remove = ['СОЭ Панч.','СОЭ по Панченкову', 'MXD', 'P-LCR',
                    'Смешанная фракция, абсолютное количество (MXD#)', 
                    'Смешанная фракция, относительное количество (MXD%)'] 

# Удаление строк, где "Кол. лаб. показатель" имеет одно из значений в списке
df = df[~df['Кол. лаб. показатель'].isin(values_to_remove)]
print("Строки с указанными значениями удалены.")
# Out:
# Строки с указанными значениями удалены.

# %%
print(df['Кол. лаб. показатель'].value_counts())
# Out:
# Кол. лаб. показатель
# Тромбоциты (PLT)                                                        1622
# Эритроциты (RBC)                                                        1619
# Средний объем эритроцита (MCV)                                          1619
# Гематокрит (HCT)                                                        1619
# Среднее содержание гемоглобина в эритроците (MCH)                       1619
# Гемоглобин (HGB)                                                        1619
# Средняя концентрация гемоглобина в эритроците (MCHC)                    1619
# Лейкоциты (WBC)                                                         1616
# Лимфоциты, относительное количество (LY%)                               1470
# Лимфоциты, абсолютное количество (LY#)                                  1470
# Нейтрофилы, относительное количество (NE%)                              1332
# Нейтрофилы, абсолютное количество (NE#)                                 1319
# Средний объем тромбоцита (MPV)                                           982
# Тромбокрит (PCT)                                                         925
# Цветовой показатель                                                      832
# Распределение эритроцитов по объему (RDW)                                829
# Эозинофилы, относительное количество (EO%)                               824
# Базофилы, относительное количество (BA%)                                 822
# Моноциты, относительное количество (MO%)                                 815
# Моноциты, абсолютное количество (MO#)                                    784
# Лимфоциты (лейкоцитарная формула, %)                                     743
# Сегментоядерные нейтрофилы (%)                                           740
# Эозинофилы, абсолютное количество (EO#)                                  739
# Палочкоядерные нейтрофилы (%)                                            736
# Моноциты (лейкоцитарная формула, %)                                      734
# Базофилы, абсолютное количество (BA#)                                    732
# Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)     698
# Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)       696
# Распределение тромбоцитов по объему (PDW)                                657
# Эозинофилы (лейкоцитарная формула, %)                                    649
# СОЭ по Вестергрену                                                       569
# Базофилы (лейкоцитарная формула, %)                                      355
# Миелоциты (лейкоцитарная формула, %)                                     316
# Юные                                                                     304
# Неклассифицируемые %                                                     239
# Нормобласты                                                              174
# Бласты                                                                   143
# Неклассифицируемые кол-во                                                117
# Ретикулоциты, абсолютное количество (#)                                   71
# Плазматические клетки                                                     30
# Ретикулоциты, относительное количество (%)                                30
# Промиелоциты (лейкоцитарная формула, %)                                   21
# Нормобласты, абсолютное количество (#)                                    18
# Нормобласты, относительное количество (%)                                 18
# Пролимфоциты (лейкоцитарная формула, %)                                   16
# Бласты (абс)                                                               4
# Name: count, dtype: int64

# %% [markdown]
# ### Этап 5: Обработка значений в столбце 'Ед. изм. кол. показателя'
#
# Задача: Обеспечить, чтобы каждый параметр имел стандартизированную единицу измерения.

# %%
# Смотрим значения в столбце
print(df['Ед. изм. кол. показателя'].value_counts())
# Out:
# Ед. изм. кол. показателя
# %                14518
# 10*9/л            8461
# фл                3666
# г/л               2528
# 10*12/л           1619
# пг                1619
# _                 1011
# г/дл               715
# мм/час             569
# fL                 136
# FL                  59
# кол-во клеток        4
# Name: count, dtype: int64

# %%
# Фильтрация строк, где "Ед. изм. кол. показателя" равно "г/дл"
gdl_df = df[df['Ед. изм. кол. показателя'] == 'г/дл']

# %%
# Подсчет количества для каждого значения "г/дл" в "Кол. лаб. показатель"
count_per_lab = gdl_df['Кол. лаб. показатель'].value_counts()
count_per_lab
# Out:
# Кол. лаб. показатель
# Средняя концентрация гемоглобина в эритроците (MCHC)    715
# Name: count, dtype: int64

# %%
# Фильтрация строк, где "Ед. изм. кол. показателя" равно "г/л"
gl_df = df[df['Ед. изм. кол. показателя'] == 'г/л']

# %%
# Подсчет количества для каждого значения "г/л" в "Кол. лаб. показатель"
count_per_lab = gl_df['Кол. лаб. показатель'].value_counts()
count_per_lab
# Out:
# Кол. лаб. показатель
# Гемоглобин (HGB)                                        1619
# Средняя концентрация гемоглобина в эритроците (MCHC)     904
# Распределение тромбоцитов по объему (PDW)                  5
# Name: count, dtype: int64

# %% [markdown]
# нужно перевести г/дл в г/л, т.к. в интернете написано, что (MCHC) тоже измеряется в г/л

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Средняя концентрация гемоглобина в эритроците (MCHC)'
# и 'Ед. изм. кол. показателя' равен 'г/дл'
mask_hb = (df['Кол. лаб. показатель'] == 'Средняя концентрация гемоглобина в эритроците (MCHC)') & (df['Ед. изм. кол. показателя'] == 'г/дл')

# Умножаем значения в столбце 'Значение кол. показателя' на 10 для выбранных строк
df.loc[mask_hb, 'Значение кол. показателя'] *= 10

# Обновляем единицу измерения на 'г/л' для выбранных строк
df.loc[mask_hb, 'Ед. изм. кол. показателя'] = 'г/л'

print("Единицы измерения для показателя 'Средняя концентрация гемоглобина в эритроците (MCHC)' успешно преобразованы в г/л.")
# Out:
# Единицы измерения для показателя 'Средняя концентрация гемоглобина в эритроците (MCHC)' успешно преобразованы в г/л.

# %%
# Исправляем обозначения единиц для других показателей
# Пример: приводим FL и фл к одному обозначению
df['Ед. изм. кол. показателя'] = df['Ед. изм. кол. показателя'].replace({'FL': 'фл', 'fL': 'фл', 'фЛ': 'фл'})
print("Единицы измерения успешно унифицированы для обозначения 'фл'.")
# Out:
# Единицы измерения успешно унифицированы для обозначения 'фл'.

# %%
print(df['Ед. изм. кол. показателя'].value_counts())
# Out:
# Ед. изм. кол. показателя
# %                14518
# 10*9/л            8461
# фл                3861
# г/л               3243
# 10*12/л           1619
# пг                1619
# _                 1011
# мм/час             569
# кол-во клеток        4
# Name: count, dtype: int64

# %% [markdown]
# ### Этап 6: Обработка значений в столбце 'Норма кол. показателя'
#
# Приводим нормы показателей к стандартным по возрасту и полу

# %%
print(df['Норма кол. показателя'].value_counts())
# Out:
# Норма кол. показателя
# 18:44          2135
# 45:72          2011
# 80:99          1604
# 150:450        1540
# 27:38          1530
#                ...
# 35:48             1
# 17:63,8           1
# 0,59:2,07         1
# Общая норма       1
# 39,0:52,0         1
# Name: count, Length: 115, dtype: int64

# %%
# Функция для вывода необходимой сводной информации
def norm_info(value):
    '''
    Функция принимает на вход одно из значений столбца 'Кол. лаб. показатель',
    то есть тот или иной параметр ОАК и выводит сводную инфу, связанную с ним
    '''
    df_value = df[df['Кол. лаб. показатель'] == value]
    norm_unique = df_value['Норма кол. показателя'].unique()
    print(f"Уникальные значения в столбце 'Норма кол. показателя' для показателя {value}:")
    print(norm_unique)

    measure_unique = df_value['Ед. изм. кол. показателя'].unique()
    print(f"Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя {value}:")
    print(measure_unique)

    value_result= df_value['Значение кол. показателя'].unique()
    print(f"Уникальные значения в столбце 'Значение кол. показателя' для показателя {value}:")
    print(value_result)

    print(f"Всего строк со значением {value}: {df[df['Кол. лаб. показатель'] == value].shape[0]}")

# %%
norm_info('Цветовой показатель')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Цветовой показатель:
# ['0,8:1,05' '0,85:1,15' '_' '0,8:1,5' '0,80:1,05' '0.80:1.05' '0.8:1.05']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Цветовой показатель:
# ['_']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Цветовой показатель:
# [0.9 0.89 0.85 0.77 0.83 0.88 0.87 0.86 0.72 0.91 0.95 0.57 0.94 0.92 1.31
#  1.24 1.28 1.35 0.84 0.82 0.93 0.7 0.74 0.76 0.68 0.75 0.71 0.65 1.04 1.03
#  1.02 1.06 0.78 1.1 1.01 0.79 0.98 0.8 0.81 0.96 1.11 1.08 1.16 0.99 1.15
#  1.12 1.0 0.62 1.14 1.2 0.55 0.73 0.64 0.63 0.6 0.49 1.29 0.61 0.56 0.59
#  0.69 0.66 1.05 1.17 0.58 1.25 1.21 1.27 1.23 1.22 0.97 1.19]
# Всего строк со значением Цветовой показатель: 832

# %%
# Заменяем значения в столбце "Норма кол. показателя" на "0.85:1.00" для строк, где "Кол. лаб. показатель" равен "Цветовой показатель"
df.loc[df['Кол. лаб. показатель'] == 'Цветовой показатель', 'Норма кол. показателя'] = '0.85:1.00'

# Проверка результата
print("Измененные значения в столбце 'Норма кол. показателя' для 'Цветовой показатель':")
print(df[df['Кол. лаб. показатель'] == 'Цветовой показатель']['Норма кол. показателя'].unique())
# Out:
# Измененные значения в столбце 'Норма кол. показателя' для 'Цветовой показатель':
# ['0.85:1.00']

# %%
norm_info('Гемоглобин (HGB)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Гемоглобин (HGB):
# ['117:160' '132:180' '117:180' '117:140' '114:154' '132:160' '122:168']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Гемоглобин (HGB):
# ['г/л']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Гемоглобин (HGB):
# [120.0 109.0 118.0 96.0 101.0 119.0 111.0 72.0 121.0 104.0 113.0 106.0
#  81.0 90.0 145.0 43.0 99.0 128.0 63.0 64.0 68.0 60.0 115.0 55.0 51.0 47.0
#  162.0 91.0 82.0 130.0 103.0 122.0 168.0 172.0 163.0 181.0 158.0 125.0
#  105.0 134.0 151.0 57.0 73.0 48.0 69.0 129.0 126.0 74.0 97.0 83.0 92.0
#  89.0 107.0 154.0 133.0 142.0 153.0 143.0 66.0 87.0 127.0 65.0 131.0 178.0
#  169.0 160.0 56.0 84.0 78.0 94.0 108.0 155.0 139.0 85.0 135.0 117.0 53.0
#  112.0 80.0 100.0 61.0 76.0 123.0 124.0 116.0 98.0 75.0 144.0 93.0 86.0
#  141.0 59.0 88.0 67.0 114.0 79.0 102.0 105.7 136.0 104.7 150.0 62.0 156.0
#  95.0 146.0 37.0 34.0 45.0 54.0 38.0 50.0 42.0 41.0 77.0 110.0 46.0 36.0
#  138.0 140.0 58.0 70.0 137.0 179.0 161.0 149.0 152.0 170.0 106.3 165.0
#  58.6 148.0 147.0 158.4 133.9 143.3 137.9 146.2 149.4 163.3 114.1 92.6
#  177.0 166.0 183.0 164.0 175.0 174.0 132.0 157.0 195.0 138.7 191.0 186.0
#  190.0 199.0 187.0 204.0 52.0 167.0 180.0 220.0 71.0 173.0 211.0 200.0
#  193.0 62.9 189.0 159.0 192.0 171.0 49.0]
# Всего строк со значением Гемоглобин (HGB): 1619

# %%
# Норма взята с сайта: https://gemotest.ru/info/spravochnik/analizy/gemoglobin/
def get_hgb_norm(age, gender):
    """Возвращает норму гемоглобина в зависимости от возраста и пола."""
    if age < 18:
        # Норма для детей
        if age == 0:  # Возраст < 1 месяца (младенцы)
            return "152:235"
        elif 1 <= age <= 13 / 365:  # 2–13 дней
            return "150:240"
        elif 14 / 365 <= age <= 23 / 365:  # 14–23 дня
            return "127:187"
        elif 24 / 365 <= age <= 30 / 365:  # 24–30 дней
            return "103:179"
        elif age < 2 / 12:  # 1 месяц
            return "90:166"
        elif age < 3 / 12:  # 2 месяца
            return "92:150"
        elif age < 4 / 12:  # 3 месяца
            return "96:135"
        elif age < 5 / 12:  # 4 месяца
            return "96:135"
        elif age < 8 / 12:  # 5–7 месяцев
            return "101:132"
        elif age < 11 / 12:  # 8–10 месяцев
            return "105:135"
        elif age < 1:  # 11 месяцев
            return "107:131"
        elif age < 5:  # 12 месяцев — 4 года
            return "108:132"
        elif age < 10:  # 5–9 лет
            return "111:143"
        elif age < 12:  # 10–11 лет
            return "119:147"
        elif age < 15:  # 12–14 лет
            if gender == 1:  # Мальчики
                return "120:160"
            else:  # Девочки
                return "115:150"
        elif age < 18:  # 15–17 лет
            if gender == 1:  # Юноши
                return "117:166"
            else:  # Девушки
                return "117:153"
    else:
        # Норма для взрослых
        if gender == 1:  # Мужчины
            if 18 <= age <= 44:
                return "132:173"
            elif 45 <= age <= 64:
                return "131:172"
            else:  # От 65 лет
                return "126:174"
        else:  # Женщины
            if 18 <= age <= 44:
                return "117:155"
            elif 45 <= age <= 64:
                return "117:160"
            else:  # От 65 лет
                return "117:161"

# %%
# Применяем функцию для строк, где 'Кол. лаб. показатель' равно 'Гемоглобин (HGB)'
mask_hgb = df['Кол. лаб. показатель'] == 'Гемоглобин (HGB)'
df.loc[mask_hgb, 'Норма кол. показателя'] = df[mask_hgb].apply(lambda row: get_hgb_norm(row['Возраст'], row['Пол']), axis=1)

# %%
# Проверка результата
print("Установлены нормы гемоглобина для показателя 'Гемоглобин (HGB)'.")
print(df[mask_hgb][['Возраст', 'Пол', 'Норма кол. показателя']])
# Out:
# Установлены нормы гемоглобина для показателя 'Гемоглобин (HGB)'.
#        Возраст  Пол Норма кол. показателя
# 2           62    0               117:160
# 18          62    0               117:160
# 48          62    0               117:160
# 78          62    0               117:160
# 106         62    0               117:160
# ...        ...  ...                   ...
# 36170       42    1               132:173
# 36197       42    1               132:173
# 36219       42    1               132:173
# 36246       42    1               132:173
# 36268       10    1               119:147
#
# [1619 rows x 3 columns]

# %%
norm_info('Гематокрит (HCT)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Гематокрит (HCT):
# ['35:47' '39:52' '35:52' '34:46' '35,0:47,0' '30.0:49.5' '39,0:52,0']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Гематокрит (HCT):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Гематокрит (HCT):
# [35.1 33.2 36.3 30.2 34.3 35.4 31.8 22.9 37.3 32.6 31.5 23.8 34.9 26.5
#  31.6 35.0 45.4 13.0 31.9 40.6 18.0 19.0 19.6 32.3 34.4 35.5 16.0 14.0
#  57.4 27.4 24.8 40.8 31.1 36.2 56.7 61.8 59.6 66.8 29.8 57.9 39.1 32.7
#  32.5 47.2 53.4 25.0 30.4 20.8 35.6 33.3 24.0 21.7 27.0 22.0 23.0 22.6
#  26.1 29.4 41.1 36.8 41.6 45.6 42.1 33.9 26.6 35.2 18.7 25.6 29.6 34.8
#  18.3 38.2 54.4 21.0 29.0 30.0 50.6 46.6 28.0 17.0 33.0 19.2 22.8 23.4
#  31.0 21.8 46.2 43.9 36.0 43.0 40.0 33.7 17.1 37.0 28.3 23.2 20.1 32.0
#  32.4 24.1 34.0 37.9 38.0 39.0 42.0 40.7 40.4 39.9 23.1 37.2 33.1 37.8
#  28.8 45.9 25.7 31.4 28.2 30.8 28.6 33.8 30.5 31.3 32.8 34.2 33.6 33.4
#  25.8 19.5 40.5 35.7 39.5 36.4 26.2 26.7 29.9 36.9 15.1 17.9 26.9 28.7
#  34.5 41.3 20.0 17.5 20.2 24.6 27.7 20.7 26.3 37.4 39.7 20.6 39.6 38.5
#  42.2 29.7 46.8 45.0 47.8 49.4 30.6 30.9 57.6 47.4 21.3 24.2 24.3 28.1
#  27.2 27.6 43.8 27.3 26.0 25.2 24.7 45.2 48.0 22.4 11.0 9.0 12.0 15.0 37.1
#  27.8 23.6 25.5 29.1 25.4 18.6 17.3 20.5 22.1 22.2 34.6 42.6 42.4 23.9
#  20.4 21.2 17.2 24.4 17.7 21.6 29.2 50.8 27.5 24.5 28.5 22.5 29.3 32.9
#  31.7 26.8 21.1 35.3 41.5 29.5 27.1 25.1 19.9 37.6 55.1 42.5 38.3 39.4
#  33.5 50.0 54.0 63.0 16.1 34.1 49.8 39.2 45.1 15.2 16.9 40.2 48.2 41.7
#  19.4 19.8 15.7 16.3 38.7 41.4 23.7 16.6 49.5 51.7 52.3 48.8 51.3 44.7
#  48.9 44.9 41.0 43.3 42.7 43.4 39.8 48.1 46.0 44.0 47.0 38.9 28.4 48.5
#  30.3 55.3 25.9 28.9 48.3 46.4 53.9 16.5 18.2 49.1 31.2 27.9 21.9 45.8
#  51.0 56.0 42.8 52.7 52.1 53.0 52.0 55.0 40.9 45.5 49.0 49.2 50.1 50.7
#  63.2 49.7 58.0 35.8 41.2 36.1 44.2 62.8 59.9 60.6 64.7 68.8 58.4 68.6
#  16.4 50.5 37.5 51.4 23.3 57.7 69.2 22.3 20.9 22.7 17.4 26.4 57.0 21.5
#  50.9 32.1 71.7 61.7 63.9 57.2 54.6 38.1 43.5 70.6 69.5 47.9 46.9 18.4
#  16.2 44.3 36.7 41.9 30.7 60.3 47.5 46.7 25.3 49.3 53.8 58.9 57.1 30.1
#  54.5 56.4 53.3 17.6 32.2 53.5 70.3 56.3 58.5 20.3 55.6 54.3 48.4 48.6
#  19.3 56.9 60.0]
# Всего строк со значением Гематокрит (HCT): 1619

# %%
# норма взята с сайта: https://gemotest.ru/info/spravochnik/analizy/gematokrit/
def get_hct_norm(age, gender):
    """Возвращает норму гематокрита в зависимости от возраста и пола."""
    if age < 18:
        # Норма для детей
        if age == 0:  # Возраст < 1 месяца (младенцы)
            return "41:65" if age <= 13 / 365 else "33:55"
        elif age < 2 / 12:  # 2 месяца
            return "32:44"
        elif age < 6 / 12:  # 3–5 месяцев
            return "31:41"
        elif age < 9 / 12:  # 6–8 месяцев
            return "32:40"
        elif age < 12 / 12:  # 9–11 месяцев
            return "33:41"
        elif age < 3:  # 12 месяцев — 2 года
            return "32:40"
        elif age < 6:  # 3–5 лет
            return "32:42"
        elif age < 9:  # 6–8 лет
            return "33:41"
        elif age < 12:  # 9–11 лет
            return "34:43"
        else:
            # Норма для подростков
            if gender == 1:  # Мужчины
                if 12 <= age < 15:
                    return "35:45"
                elif 15 <= age < 18:
                    return "37:48"
            else:  # Женщины
                if 12 <= age < 18:
                    return "34:44"
    else:
        # Норма для взрослых
        if gender == 1:  # Мужчины
            if 18 <= age <= 44:
                return "39:49"
            elif 45 <= age <= 64:
                return "39:50"
            else:  # От 65 лет
                return "37:51"
        else:  # Женщины
            if 18 <= age <= 44:
                return "35:45"
            else:  # От 45 лет
                return "35:47"

# %%
# Применяем функцию для строк, где 'Кол. лаб. показатель' равно 'Гематокрит (HCT)'
mask_hct = df['Кол. лаб. показатель'] == 'Гематокрит (HCT)'
df.loc[mask_hct, 'Норма кол. показателя'] = df[mask_hct].apply(lambda row: get_hct_norm(row['Возраст'], row['Пол']), axis=1)

# %%
# Проверка результата
print("Установлены нормы гематокрита для показателя 'Гематокрит (HCT)'.")
print(df[mask_hct][['Возраст', 'Пол', 'Норма кол. показателя']])
# Out:
# Установлены нормы гематокрита для показателя 'Гематокрит (HCT)'.
#        Возраст  Пол Норма кол. показателя
# 3           62    0                 35:47
# 19          62    0                 35:47
# 49          62    0                 35:47
# 79          62    0                 35:47
# 107         62    0                 35:47
# ...        ...  ...                   ...
# 36171       42    1                 39:49
# 36198       42    1                 39:49
# 36220       42    1                 39:49
# 36247       42    1                 39:49
# 36269       10    1                 34:43
#
# [1619 rows x 3 columns]

# %%
norm_info('Средний объем эритроцита (MCV)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Средний объем эритроцита (MCV):
# ['80:99' '80,0:99,0' '78:103']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Средний объем эритроцита (MCV):
# ['фл']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Средний объем эритроцита (MCV):
# [84.0 91.2 90.8 89.6 87.5 83.9 79.5 88.4 87.4 92.4 91.0 86.7 84.5 79.6
#  81.0 80.8 85.4 90.4 74.9 89.0 95.8 83.8 83.0 103.2 86.4 87.3 92.7 82.0
#  80.0 65.9 89.5 91.1 85.9 84.4 66.1 68.9 69.9 90.5 86.1 77.4 65.8 77.6
#  77.1 78.5 85.0 78.0 77.9 81.9 84.1 77.8 79.0 83.1 78.6 77.5 84.9 83.7
#  86.3 78.2 84.6 82.9 78.3 93.3 77.7 92.0 92.1 86.0 128.9 121.3 120.6 126.0
#  85.6 86.8 90.0 77.0 94.1 86.2 86.5 87.2 92.6 88.0 87.0 84.8 76.0 89.8
#  89.2 95.6 81.8 74.0 81.6 94.0 75.0 82.8 87.9 83.4 99.6 99.2 101.0 99.0
#  100.0 104.0 110.6 97.9 92.2 100.1 82.6 98.0 98.4 104.2 81.7 80.1 98.8
#  98.5 82.4 83.3 93.2 93.7 96.1 81.4 81.3 76.6 76.5 76.4 85.5 91.8 76.2
#  84.3 90.6 76.3 94.2 94.6 76.1 89.3 92.8 91.5 91.9 95.2 93.8 82.1 82.3
#  85.3 72.8 119.2 116.7 110.5 111.5 109.5 97.0 122.3 111.3 95.0 97.1 94.4
#  106.6 107.6 114.3 93.0 97.6 98.6 96.0 89.1 92.5 101.7 96.8 102.0 96.6
#  78.7 80.4 80.3 78.4 80.6 79.7 77.2 75.9 88.5 79.1 79.8 79.2 76.9 80.2
#  105.4 85.2 109.8 114.7 109.0 106.7 104.7 114.0 90.1 88.3 93.4 90.3 96.2
#  80.9 88.6 88.1 90.9 86.6 88.7 92.9 91.6 79.3 78.9 90.2 89.4 88.8 96.4
#  104.1 98.9 103.9 85.7 64.0 67.0 81.2 78.8 95.4 101.9 105.6 104.3 80.7
#  82.5 78.1 81.1 103.3 97.5 83.2 82.2 82.7 93.1 85.1 90.7 97.4 95.5 73.0
#  66.5 99.3 67.6 67.2 79.9 96.3 88.2 63.1 59.9 63.3 60.3 75.7 63.7 76.7
#  86.9 136.3 113.8 106.9 112.1 113.1 107.2 103.7 85.8 84.2 66.0 71.0 65.0
#  70.0 69.0 72.0 75.2 80.5 75.1 108.4 119.3 87.7 106.0 76.8 108.1 116.5
#  112.6 77.3 116.6 133.2 72.5 72.6 79.4 71.2 69.6 94.7 67.8 67.5 68.1 89.9
#  95.1 84.7 105.5 70.9 71.9 70.6 94.3 88.9 87.6 69.4 72.2 119.1 123.8 81.5
#  109.4 94.8 93.9 97.3 94.9 96.5 97.8 96.7 74.1 68.2 73.3 91.4 74.5 93.5
#  89.7 87.1 74.7 74.8 70.8 95.3 116.0 120.0 117.0 113.0 119.0 118.0 103.0
#  124.0]
# Всего строк со значением Средний объем эритроцита (MCV): 1619

# %%
# норма взята с сайта: https://www.cmd-online.ru/analizy-i-tseny/katalog-analizov/sredniy-obem-eritrotsita/#:~:text=MCV%20%D1%8F%D0%B2%D0%BB%D1%8F%D0%B5%D1%82%D1%81%D1%8F%20%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D1%8B%D0%BC%20%D0%BF%D0%BE%D0%BA%D0%B0%D0%B7%D0%B0%D1%82%D0%B5%D0%BB%D0%B5%D0%BC%20%D0%B4%D0%B8%D0%B0%D0%BC%D0%B5%D1%82%D1%80%D0%B0,%2C%20%D0%B1%D0%BE%D0%BB%D1%8C%D1%88%D0%B5%20100%20%D1%84%D0%BB%20%2D%20%D0%BC%D0%B0%D0%BA%D1%80%D0%BE%D1%86%D0%B8%D1%82%D0%BE%D0%B7.
def get_mcv_norm(age, gender):
    """Возвращает норму среднего объема эритроцита (MCV) в зависимости от возраста и пола."""
    if age < 2 / 52:  # < 2 недели
        return "88:140"
    elif age < 1 / 12:  # 2 недели - 1 месяц
        return "91:112"
    elif age < 2 / 12:  # 1 - 2 месяца
        return "84:106"
    elif age < 4 / 12:  # 2 - 4 месяца
        return "76:97"
    elif age < 6 / 12:  # 4 - 6 месяцев
        return "68:85"
    elif age < 9 / 12:  # 6 - 9 месяцев
        return "70:85"
    elif age < 2:  # 9 месяцев - 2 года
        return "71:84"
    elif age < 5:  # 2 года - 5 лет
        return "73:85"
    elif age < 9:  # 5 - 9 лет
        return "75:87"
    elif age < 12:  # 9 - 12 лет
        return "76:90"
    elif age < 15:  # 12 - 15 лет
        if gender == 1:  # Мужчины
            return "77:94"
        else:  # Женщины
            return "73:95"
    elif age < 18:  # 15 - 18 лет
        if gender == 1:  # Мужчины
            return "79:95"
        else:  # Женщины
            return "78:98"
    else:
        # Норма для взрослых
        if gender == 1:  # Мужчины
            if 18 <= age <= 45:
                return "80:99"
            elif 45 <= age <= 65:
                return "81:101"
            else:  # > 65 лет
                return "81:103"
        else:  # Женщины
            if 18 <= age <= 45:
                return "81:100"
            elif 45 <= age <= 65:
                return "81:101"
            else:  # > 65 лет
                return "81:102"

# %%
# Применяем функцию для строк, где 'Кол. лаб. показатель' равно 'Средний объем эритроцита (MCV)'
mask_mcv = df['Кол. лаб. показатель'] == 'Средний объем эритроцита (MCV)'
df.loc[mask_mcv, 'Норма кол. показателя'] = df[mask_mcv].apply(lambda row: get_mcv_norm(row['Возраст'], row['Пол']), axis=1)

# Проверка результата
print("Установлены нормы среднего объема эритроцита (MCV) для показателя 'Средний объем эритроцита (MCV)'.")
print(df[mask_mcv][['Возраст', 'Пол', 'Норма кол. показателя']])
# Out:
# Установлены нормы среднего объема эритроцита (MCV) для показателя 'Средний объем эритроцита (MCV)'.
#        Возраст  Пол Норма кол. показателя
# 4           62    0                81:101
# 20          62    0                81:101
# 50          62    0                81:101
# 80          62    0                81:101
# 108         62    0                81:101
# ...        ...  ...                   ...
# 36172       42    1                 80:99
# 36199       42    1                 80:99
# 36221       42    1                 80:99
# 36248       42    1                 80:99
# 36270       10    1                 76:90
#
# [1619 rows x 3 columns]

# %%
# https://www.cmd-online.ru/analizy-i-tseny/katalog-analizov/srednee-soderzhanie-gemoglobina-v-eritrotsite-mch-mean-corpuscular-hemoglobin/
def get_mch_norm(age, gender):
    """Возвращает норму среднего содержания гемоглобина в эритроците (MCH) в зависимости от возраста и пола."""
    if age < 2 / 52:  # < 2 недели
        return "30:37"
    elif age < 1 / 12:  # 2 недели - 1 месяц
        return "29:36"
    elif age < 2 / 12:  # 1 - 2 месяца
        return "27:34"
    elif age < 4 / 12:  # 2 - 4 месяца
        return "25:32"
    elif age < 6 / 12:  # 4 - 6 месяцев
        return "24:30"
    elif age < 9 / 12:  # 6 - 9 месяцев
        return "25:30"
    elif age < 1:  # 9 месяцев - 1 год
        return "24:30"
    elif age < 3:  # 1 - 3 года
        return "22:30"
    elif age < 9:  # 3 - 9 лет
        return "25:31"
    elif age < 15:  # 9 - 15 лет
        return "26:32"
    elif age < 18:  # 15 - 18 лет
        if gender == 1:  # Мужчины
            return "27:32"
        else:  # Женщины
            return "26:34"
    else:
        # Норма для взрослых
        if gender == 1:  # Мужчины
            if 18 <= age <= 45:
                return "27:34"
            elif 45 <= age <= 65:
                return "27:35"
            else:  # > 65 лет
                return "27:34"
        else:  # Женщины
            if 18 <= age <= 45:
                return "27:34"
            elif 45 <= age <= 65:
                return "27:34"
            else:  # > 65 лет
                return "27:35"

# %%
# Применяем функцию для строк, где 'Кол. лаб. показатель' равно 'Среднее содержание гемоглобина в эритроците (MCH)'
mask_mch = df['Кол. лаб. показатель'] == 'Среднее содержание гемоглобина в эритроците (MCH)'
df.loc[mask_mch, 'Норма кол. показателя'] = df[mask_mch].apply(lambda row: get_mch_norm(row['Возраст'], row['Пол']), axis=1)

# Проверка результата
print("Установлены нормы среднего содержания гемоглобина в эритроците (MCH) для показателя 'Среднее содержание гемоглобина в эритроците (MCH)'.")
print(df[mask_mch][['Возраст', 'Пол', 'Норма кол. показателя']])
# Out:
# Установлены нормы среднего содержания гемоглобина в эритроците (MCH) для показателя 'Среднее содержание гемоглобина в эритроците (MCH)'.
#        Возраст  Пол Норма кол. показателя
# 5           62    0                 27:34
# 21          62    0                 27:34
# 51          62    0                 27:34
# 81          62    0                 27:34
# 109         62    0                 27:34
# ...        ...  ...                   ...
# 36173       42    1                 27:34
# 36200       42    1                 27:34
# 36222       42    1                 27:34
# 36249       42    1                 27:34
# 36271       10    1                 26:32
#
# [1619 rows x 3 columns]

# %%
# https://gemotest.ru/info/spravochnik/analizy/eritrotsitarnye-indeksy/#:~:text=%D0%A1%D1%80%D0%B5%D0%B4%D0%BD%D1%8F%D1%8F%20%D0%BA%D0%BE%D0%BD%D1%86%D0%B5%D0%BD%D1%82%D1%80%D0%B0%D1%86%D0%B8%D1%8F%20%D0%B3%D0%B5%D0%BC%D0%BE%D0%B3%D0%BB%D0%BE%D0%B1%D0%B8%D0%BD%D0%B0%20%D0%B2%20%D1%8D%D1%80%D0%B8%D1%82%D1%80%D0%BE%D1%86%D0%B8%D1%82%D0%B5%20(%D0%9C%D0%A1%D0%9D%D0%A1)&text=%D0%9D%D0%B0%D0%B8%D0%B1%D0%BE%D0%BB%D0%B5%D0%B5%20%D0%B2%D1%8B%D1%81%D0%BE%D0%BA%D0%B8%D0%B5%20%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D1%8F%20%E2%80%94%20%D1%83%20%D0%BD%D0%BE%D0%B2%D0%BE%D1%80%D0%BE%D0%B6%D0%B4%D1%91%D0%BD%D0%BD%D1%8B%D1%85,%D0%BF%D0%BE%D1%81%D1%82%D0%B5%D0%BF%D0%B5%D0%BD%D0%BD%D0%BE%20%D1%81%D0%BD%D0%B8%D0%B6%D0%B0%D1%8E%D1%82%D1%81%D1%8F%20%D0%B4%D0%BE%20%D0%BD%D0%BE%D1%80%D0%BC%D1%8B%20%D0%B2%D0%B7%D1%80%D0%BE%D1%81%D0%BB%D1%8B%D1%85.&text=%D0%A3%20%D0%B2%D0%B7%D1%80%D0%BE%D1%81%D0%BB%D1%8B%D1%85%20(%D0%BC%D1%83%D0%B6%D1%87%D0%B8%D0%BD%20%D0%B8%20%D0%B6%D0%B5%D0%BD%D1%89%D0%B8%D0%BD,300%E2%80%93380%20%D0%B3%2F%D0%BB.
def get_mchc_norm(age, gender):
    """Возвращает норму средней концентрации гемоглобина в эритроците (MCHC) в зависимости от возраста и пола."""
    if age < 1 / 12:  # 1 день - 1 месяц
        return "316:375"
    elif age < 5 / 12:  # 2 - 5 месяцев
        return "306:324"
    elif age < 7 / 12:  # 6 - 7 месяцев
        return "307:324"
    elif age < 1:  # 8 месяцев - 1 год
        return "297:324"
    elif age < 3:  # 2 года
        return "307:344"
    elif age < 10:  # 3 - 9 лет
        return "336:344"
    elif age < 15:  # 10 - 14 лет
        return "336:354"
    elif age < 18:  # 15 - 18 лет
        return "300:380"
    else:
        # Норма для взрослых, независимо от пола
        return "300:380"

# %%
# Применяем функцию для строк, где 'Кол. лаб. показатель' равно 'Средняя концентрация гемоглобина в эритроците (MCHC)'
mask_mchc = df['Кол. лаб. показатель'] == 'Средняя концентрация гемоглобина в эритроците (MCHC)'
df.loc[mask_mchc, 'Норма кол. показателя'] = df[mask_mchc].apply(lambda row: get_mchc_norm(row['Возраст'], row['Пол']), axis=1)

# Проверка результата
print("Установлены нормы средней концентрации гемоглобина в эритроците (MCHC) для показателя 'Средняя концентрация гемоглобина в эритроците (MCHC)'.")
print(df[mask_mchc][['Возраст', 'Пол', 'Норма кол. показателя']])
# Out:
# Установлены нормы средней концентрации гемоглобина в эритроците (MCHC) для показателя 'Средняя концентрация гемоглобина в эритроците (MCHC)'.
#        Возраст  Пол Норма кол. показателя
# 6           62    0               300:380
# 22          62    0               300:380
# 52          62    0               300:380
# 82          62    0               300:380
# 110         62    0               300:380
# ...        ...  ...                   ...
# 36174       42    1               300:380
# 36201       42    1               300:380
# 36223       42    1               300:380
# 36250       42    1               300:380
# 36272       10    1               336:354
#
# [1619 rows x 3 columns]

# %%
norm_info('Эритроциты (RBC)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Эритроциты (RBC):
# ['3,8:5,7' '4,3:6,1' '4,30:6,10' '3,8:6,1' '3.5:5.2' '3,5:5,2' '3,80:5,70'
#  '3.8:5,7' '3.1:5.7']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Эритроциты (RBC):
# ['10*12/л']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Эритроциты (RBC):
# [4.18 3.64 4.0 3.37 3.92 4.22 3.53 2.59 4.27 3.89 3.83 3.73 2.99 4.31 3.28
#  3.7 3.87 3.33 6.06 1.45 2.15 4.45 4.19 2.1 2.31 1.9 3.74 3.94 1.93 1.8
#  1.63 8.71 3.1 2.77 4.48 3.62 4.29 8.58 9.35 8.65 9.56 8.28 4.32 3.8 4.2
#  7.14 8.12 1.96 3.02 4.23 2.65 1.51 2.34 4.6 2.93 2.58 3.47 2.8 1.97 2.87
#  3.13 2.88 3.14 3.79 5.23 4.75 5.01 5.37 5.03 3.93 3.41 4.54 2.39 3.5 4.46
#  5.83 2.55 3.51 3.86 5.5 5.06 1.95 2.92 1.49 1.88 1.94 2.21 3.31 2.74 1.73
#  5.4 4.47 3.58 4.52 5.1 3.21 4.94 3.82 3.77 4.34 3.27 2.66 3.61 2.17 3.32
#  3.65 2.76 4.68 4.21 3.69 4.84 5.05 4.36 4.13 3.18 5.02 5.49 5.11 5.22
#  2.56 4.53 5.15 4.63 2.42 4.55 4.04 4.81 4.73 2.83 3.48 4.89 4.85 4.64
#  3.08 3.03 4.72 4.37 2.9 2.97 2.89 2.95 2.84 3.34 3.63 2.86 4.09 3.0 3.85
#  4.15 2.28 4.1 3.46 3.39 4.83 3.45 3.97 4.11 3.95 2.85 4.4 3.43 3.42 3.49
#  3.59 2.63 1.66 3.81 4.57 2.62 3.88 3.29 1.85 2.64 3.06 4.17 2.72 2.22 3.4
#  4.33 3.35 4.99 2.54 4.78 5.0 6.95 5.75 2.75 2.94 3.24 3.57 3.19 5.39 3.55
#  2.26 1.99 1.86 2.02 2.03 4.07 4.66 5.08 2.44 2.23 2.68 1.22 1.17 3.07 2.5
#  1.1 1.37 1.5 1.76 2.67 1.24 2.46 1.56 1.27 1.28 2.73 2.57 3.36 2.19 2.91
#  1.57 3.12 1.26 1.47 1.59 3.17 2.79 1.3 1.69 1.25 1.11 3.09 1.19 3.66 2.43
#  2.96 2.41 3.54 3.25 3.26 5.2 2.47 3.56 3.2 1.64 3.05 4.51 4.08 5.3 3.68
#  2.7 4.02 2.35 4.43 4.16 3.15 4.01 2.38 3.96 4.25 4.14 3.99 3.78 3.01 4.35
#  4.12 3.04 2.36 3.3 3.72 2.98 3.22 2.08 2.14 4.39 5.29 3.91 7.85 8.32 9.33
#  2.4 3.76 5.24 3.71 2.81 6.12 5.93 1.83 2.16 3.11 3.6 2.69 4.74 2.51 3.84
#  2.45 1.89 3.52 4.9 2.53 2.01 2.61 2.82 2.0 1.36 1.87 6.13 6.39 6.47 6.18
#  5.34 6.01 4.05 5.14 5.52 5.36 5.04 5.16 4.97 5.25 4.77 5.73 5.32 5.31
#  5.46 2.32 3.98 5.88 5.8 5.82 3.75 7.29 7.48 8.23 2.49 7.66 7.75 8.52 8.57
#  2.18 9.36 7.76 3.9 5.57 2.33 1.6 1.84 5.27 7.32 6.9 7.55 6.42 7.27 7.11
#  7.21 6.27 4.65 4.3 4.82 4.42 5.38 5.07 5.67 4.38 6.48 5.18 3.23 4.8 6.45
#  6.64 2.52 7.22 7.03 5.91 5.96 7.25 6.38 7.12 7.34 6.23 7.39 6.4 7.9 5.98
#  5.13 2.25 6.36 2.78 4.61 5.09 4.67 4.26 4.59 4.7 8.35 7.88 7.44 7.7 8.11
#  8.41 7.96 7.78 8.55 1.82 6.25 5.9 5.81 2.6 4.92 6.53 4.24 6.05 8.04 5.97
#  6.75 4.5 2.29 1.92 7.31 2.06 6.98 10.58 9.15 9.38 8.48 2.24 4.62 2.48
#  4.06 6.02 6.16 7.54 5.62 6.73 5.28 2.37 3.67 1.91 4.88 2.71 4.58 5.55
#  6.17 5.56 7.95 3.44 7.07 8.08 7.69 7.62 2.04 7.37 9.44 7.3 7.91 2.13 6.76
#  6.87 2.27 3.16 6.08 6.81 5.69 5.54 2.07 5.85 4.28 4.44 4.03 6.86 7.45
#  4.93 4.87 6.41 5.6 5.26 6.03 4.86 4.49 7.0 6.72 4.96 5.33 4.56 2.3 3.38
#  5.58 5.78 6.57 5.95 4.69 4.79 6.92 6.8 5.43 1.18 1.15]
# Всего строк со значением Эритроциты (RBC): 1619

# %%
# https://gemotest.ru/info/spravochnik/analizy/eritrotsity-krasnye-krovyanye-teltsa/
def get_rbc_norm(age, gender):
    """Возвращает норму эритроцитов (RBC) в зависимости от возраста и пола."""
    if age < 1 / 12:  # 1–13 дней
        return "3.9:5.9"
    elif age < 1:  # 14–30 дней, до 1 года
        if age < 2 / 12:
            return "3.3:5.3"
        elif age < 3 / 12:
            return "3.5:5.1"
        elif age < 4 / 12:
            return "3.6:4.8"
        elif age < 5 / 12:
            return "3.8:4.6"
        elif age < 6 / 12:
            return "4.0:4.8"
        elif age < 10 / 12:
            return "3.8:4.6"
        else:
            return "3.9:4.7"
    elif age < 5:  # 1 - 5 лет
        return "4.0:4.4"
    elif age == 6:
        return "4.1:4.5"
    elif age == 7:
        return "4.0:4.4"
    elif age == 8:
        return "4.2:4.6"
    elif age == 9:
        return "4.1:4.5"
    elif age < 12:  # 10 - 11 лет
        return "4.2:4.6"
    elif age < 15:  # 12–14 лет
        if gender == 1:  # Мальчики
            return "4.1:5.2"
        else:  # Девочки
            return "3.8:5.0"
    elif age < 18:  # 15–18 лет
        if gender == 1:  # Юноши
            return "4.2:5.6"
        else:  # Девушки
            return "3.9:5.1"
    else:
        # Норма для взрослых
        if gender == 1:  # Мужчины
            if 18 <= age <= 44:
                return "4.3:5.7"
            elif 45 <= age <= 64:
                return "4.2:5.6"
            else:  # > 65 лет
                return "3.8:5.8"
        else:  # Женщины
            if 18 <= age <= 44:
                return "3.8:5.1"
            elif 45 <= age <= 64:
                return "3.8:5.3"
            else:  # > 65 лет
                return "3.8:5.2"

# %%
# Применяем функцию для строк, где 'Кол. лаб. показатель' равно 'Эритроциты (RBC)'
mask_rbc = df['Кол. лаб. показатель'] == 'Эритроциты (RBC)'
df.loc[mask_rbc, 'Норма кол. показателя'] = df[mask_rbc].apply(lambda row: get_rbc_norm(row['Возраст'], row['Пол']), axis=1)

# Проверка результата
print("Установлены нормы эритроцитов (RBC) для показателя 'Эритроциты (RBC)'.")
print(df[mask_rbc][['Возраст', 'Пол', 'Норма кол. показателя']])
# Out:
# Установлены нормы эритроцитов (RBC) для показателя 'Эритроциты (RBC)'.
#        Возраст  Пол Норма кол. показателя
# 1           62    0               3.8:5.3
# 17          62    0               3.8:5.3
# 47          62    0               3.8:5.3
# 77          62    0               3.8:5.3
# 105         62    0               3.8:5.3
# ...        ...  ...                   ...
# 36169       42    1               4.3:5.7
# 36196       42    1               4.3:5.7
# 36218       42    1               4.3:5.7
# 36245       42    1               4.3:5.7
# 36267       10    1               4.2:4.6
#
# [1619 rows x 3 columns]

# %%
norm_info('Тромбоциты (PLT)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Тромбоциты (PLT):
# ['150:450' nan '150:320']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Тромбоциты (PLT):
# ['10*9/л']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Тромбоциты (PLT):
# [51.0 73.0 205.0 147.0 78.0 186.0 301.0 347.0 271.0 93.0 89.0 313.0 332.0
#  252.0 46.0 173.0 59.0 348.0 24.0 74.0 71.0 70.0 25.0 31.0 126.0 84.0
#  119.0 116.0 19.0 21.0 48.0 224.0 79.0 117.0 50.0 96.0 100.0 232.0 212.0
#  215.0 67.0 204.0 169.0 29.0 124.0 198.0 47.0 32.0 37.0 17.0 35.0 26.0
#  15.0 18.0 20.0 58.0 75.0 77.0 34.0 36.0 11.0 10.0 561.0 513.0 568.0 61.0
#  12.0 91.0 87.0 23.0 52.0 16.0 223.0 105.0 256.0 241.0 86.0 60.0 56.0 65.0
#  41.0 108.0 386.0 341.0 393.0 357.0 81.0 355.0 431.0 577.0 171.0 165.0
#  307.0 142.0 174.0 161.0 274.0 194.0 146.0 210.0 278.0 251.0 260.0 250.0
#  192.0 42.0 82.0 211.0 206.0 193.0 66.0 76.0 182.0 226.0 228.0 229.0 537.0
#  235.0 476.0 484.0 914.0 457.0 219.0 247.0 242.0 437.0 473.0 495.0 239.0
#  196.0 402.0 525.0 190.0 203.0 432.0 501.0 344.0 221.0 311.0 269.0 285.0
#  143.0 151.0 152.0 460.0 403.0 438.0 394.0 113.0 112.0 107.0 335.0 30.0
#  524.0 316.0 118.0 277.0 548.0 132.0 233.0 266.0 359.0 289.0 55.0 33.0
#  22.0 352.0 422.0 287.0 62.0 293.0 265.0 358.0 327.0 391.0 518.0 38.0
#  369.0 395.0 349.0 157.0 216.0 128.0 214.0 15.9 417.0 64.0 40.0 871.0
#  654.0 902.0 236.0 213.0 45.0 13.0 787.0 671.0 420.0 6.0 350.0 170.0 133.0
#  127.0 102.0 98.0 207.0 237.0 123.0 97.0 54.0 14.0 43.0 27.0 261.0 28.0
#  181.0 154.0 111.0 68.0 122.0 110.0 39.0 140.0 137.0 80.0 469.0 478.0
#  492.0 8.0 472.0 645.0 581.0 53.0 547.0 321.0 336.0 362.0 83.0 120.0 168.0
#  131.0 187.0 497.0 570.0 443.0 612.0 44.0 441.0 166.0 178.0 468.0 390.0
#  413.0 401.0 95.0 367.0 373.0 512.0 5.0 57.0 90.0 3.0 7.0 317.0 415.0
#  302.0 404.0 839.0 801.0 1086.0 929.0 1122.0 704.0 896.0 684.0 799.0 785.0
#  748.0 69.0 511.0 535.0 318.0 374.0 99.0 0.0 109.0 475.0 566.0 608.0 320.0
#  324.0 139.0 310.0 342.0 4.0 1124.0 600.0 326.0 389.0 136.0 130.0 134.0
#  103.0 299.0 222.0 272.0 337.0 340.0 255.0 830.0 727.0 238.0 254.0 230.0
#  141.0 115.0 9.0 1213.0 1474.0 1145.0 94.0 72.0 49.0 114.0 308.0 280.0
#  328.3 298.0 385.0 407.0 383.0 461.0 1209.0 1073.0 1016.0 1140.0 975.4
#  1227.0 63.0 814.0 895.0 533.0 1220.0 754.0 1167.0 840.0 1184.0 92.0 237.7
#  317.2 388.0 618.0 379.0 164.0 188.0 371.0 354.0 392.0 398.0 444.0 489.0
#  714.0 746.0 755.0 747.0 697.4 672.0 145.0 650.0 1177.0 891.0 304.0 202.0
#  1181.0 1089.0 703.0 334.0 199.0 91.2 180.0 530.0 488.0 462.0 585.0 515.0
#  200.5 241.6 220.0 243.0 552.0 606.0 572.0 498.0 424.0 573.0 545.0 586.0
#  594.0 520.0 793.0 507.0 387.0 405.0 843.0 451.0 1777.0 917.0 297.0 477.0
#  1243.0 1911.0 419.0 1842.0 2052.0 351.0 264.0 957.0 177.0 201.0 1082.0
#  603.0 1193.0 1182.0 887.0 381.0 471.0 445.0 425.8 325.0 1026.0 558.0
#  306.0 259.0 1286.0 993.0 487.0 456.0 353.0 363.0 400.0 286.0 364.0 227.0
#  711.0 406.0 322.0 675.0 710.0 629.0 319.0 544.0 592.0 262.0 516.0 640.0
#  135.0 138.0 189.0 209.0 963.0 718.0 1148.0 150.0 1003.0 378.0 1010.0
#  961.0 483.0 846.0 803.0 463.0 1202.0 1211.0 582.0 1416.0 1013.0 1066.0
#  624.0 593.0 633.0 1234.0 729.0 560.0 816.0 370.0 567.0 563.0 148.0 104.0
#  162.0 263.0 479.0 448.0 253.0 106.0 305.0 421.0 553.0 447.0 453.0 522.0
#  952.0 176.0 449.0 442.0 240.0 101.0 208.0 485.0 245.0 329.0 338.0 179.0
#  491.0 426.0 88.0 296.0 315.0 496.0 555.0 609.0 331.0 412.0 343.0 877.0
#  663.0 863.0 464.0 290.0 366.0 409.0 408.0 452.0 249.0 303.0 291.0 149.0
#  218.0 796.0 705.0 732.0 646.0 517.0 578.0 466.0 273.0 416.0 282.0 356.0
#  435.0 257.0 450.0 270.0 446.0 857.0 893.0 596.0 557.0 459.0 160.0 155.0
#  156.0 294.0 185.0 800.0 794.0 897.0 715.0 778.0 697.0 690.0 667.0 167.0
#  410.0 275.0 300.0 279.0 509.0 225.0 346.0 372.0 539.0 636.0 502.0 1224.0
#  588.0 569.0 616.0 790.0 1235.0 1126.0 532.0 309.0 418.0 821.0 1118.0
#  1576.0 1847.0 2248.0 2958.0 1565.0 1843.0 1258.0 2352.0 2578.0 1898.0
#  1304.0 1906.0 1728.0 1395.0 1282.0 1296.0 439.0 480.0 276.0 531.0 425.0
#  423.0 234.0 541.0 505.0 454.0 702.0 540.0 500.0 536.0 506.0 85.0 333.0]
# Всего строк со значением Тромбоциты (PLT): 1622

# %%
# https://gemotest.ru/info/spravochnik/analizy/trombotsity/#:~:text=%D0%B2%20%D0%B8%D0%BC%D0%BC%D1%83%D0%BD%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B2%D0%B5%D1%82%D0%B5.-,%D0%9D%D0%BE%D1%80%D0%BC%D0%B0%20%D1%82%D1%80%D0%BE%D0%BC%D0%B1%D0%BE%D1%86%D0%B8%D1%82%D0%BE%D0%B2%20%D0%B2%20%D0%BA%D1%80%D0%BE%D0%B2%D0%B8%20%D1%83%20%D0%BC%D1%83%D0%B6%D1%87%D0%B8%D0%BD%20%D0%B8%20%D0%B6%D0%B5%D0%BD%D1%89%D0%B8%D0%BD,9%20%D0%BA%D0%BB%D0%B5%D1%82%D0%BE%D0%BA%20%D0%BD%D0%B0%20%D0%BB%D0%B8%D1%82%D1%80%20%D0%BA%D1%80%D0%BE%D0%B2%D0%B8.
def get_plt_norm(age):
    """Возвращает норму тромбоцитов (PLT) в зависимости от возраста."""
    # Нормы для детей до 1 года
    if age < 1 / 12:
        return "208:410"
    elif age < 2 / 12:
        return "208:352"
    elif age < 3 / 12:
        return "207:373"
    elif age < 4 / 12:
        return "205:395"
    elif age < 5 / 12:
        return "205:375"
    elif age < 6 / 12:
        return "203:377"
    elif age < 7 / 12:
        return "206:374"
    elif age < 8 / 12:
        return "215:365"
    elif age < 9 / 12:
        return "199:361"
    elif age < 10 / 12:
        return "205:355"
    elif age < 11 / 12:
        return "203:357"
    elif age < 1:
        return "207:353"
    
    # Нормы для детей старше 1 года
    elif age < 2:
        return "218:362"
    elif age < 3:
        return "214:366"
    elif age < 4:
        return "209:351"
    elif age < 5:
        return "196:344"
    elif age < 6:
        return "208:332"
    elif age < 7:
        return "220:360"
    elif age < 8:
        return "205:355"
    elif age < 9:
        return "205:375"
    elif age < 10:
        return "217:343"
    elif age < 11:
        return "211:349"
    elif age < 12:
        return "198:342"
    elif age < 13:
        return "202:338"
    elif age < 14:
        return "192:328"
    elif age < 15:
        return "198:342"
    elif age < 16:
        return "200:360"
    elif age < 17:
        return "180:320"
    
    # Норма для взрослых (с 18 лет и старше)
    return "180:320"

# %%
# Применяем функцию для строк, где 'Кол. лаб. показатель' равно 'Тромбоциты (PLT)'
mask_plt = df['Кол. лаб. показатель'] == 'Тромбоциты (PLT)'
df.loc[mask_plt, 'Норма кол. показателя'] = df[mask_plt].apply(lambda row: get_plt_norm(row['Возраст']), axis=1)

# Проверка результата
print("Установлены нормы тромбоцитов (PLT) для показателя 'Тромбоциты (PLT)'.")
print(df[mask_plt][['Возраст', 'Пол', 'Норма кол. показателя']])
# Out:
# Установлены нормы тромбоцитов (PLT) для показателя 'Тромбоциты (PLT)'.
#        Возраст  Пол Норма кол. показателя
# 7           62    0               180:320
# 24          62    0               180:320
# 54          62    0               180:320
# 84          62    0               180:320
# 112         62    0               180:320
# ...        ...  ...                   ...
# 36176       42    1               180:320
# 36202       42    1               180:320
# 36225       42    1               180:320
# 36251       42    1               180:320
# 36273       10    1               211:349
#
# [1622 rows x 3 columns]

# %%
norm_info('Лейкоциты (WBC)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Лейкоциты (WBC):
# ['4:11' '4,00:11,00' '4.0:8.8' '4:8,8']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Лейкоциты (WBC):
# ['10*9/л']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Лейкоциты (WBC):
# [1.8 1.07 1.89 4.97 1.64 3.8 6.2 6.63 5.71 1.62 5.03 16.7 1.7 5.3 6.3 4.3
#  17.8 1.35 14.88 9.36 1.82 2.74 4.4 41.56 2.3 2.6 25.2 27.34 3.1 2.2 5.8
#  9.7 21.9 3.81 5.1 5.2 6.1 6.5 6.18 4.82 4.63 1.69 1.5 4.5 1.3 3.48 1.2
#  0.3 1.6 1.11 4.1 0.9 1.0 0.2 1.4 2.5 4.2 5.5 1.9 0.94 1.46 8.67 9.1 9.43
#  0.4 10.42 8.7 10.1 0.71 10.45 5.9 7.0 8.51 15.83 5.51 7.2 15.9 18.54
#  19.76 6.4 6.9 8.1 7.3 7.88 8.8 6.7 9.8 12.86 6.8 2.8 3.24 3.56 4.24 3.66
#  13.47 108.0 4.7 4.22 5.28 4.15 4.6 4.57 43.52 8.69 8.47 3.9 6.27 10.65
#  12.27 12.94 6.6 4.8 10.17 10.66 11.25 9.39 5.7 6.07 4.08 10.98 4.21 25.6
#  7.4 11.2 11.4 9.28 9.15 10.6 14.48 10.0 7.93 7.49 7.25 11.12 11.7 10.5
#  9.94 10.08 13.91 10.3 7.32 6.02 4.65 4.87 0.87 2.58 12.2 14.0 9.6 5.0 2.1
#  1.75 2.55 6.0 4.43 1.79 1.87 1.15 5.06 1.1 5.39 6.13 0.7 5.4 0.8 2.99 3.7
#  4.88 4.25 4.78 5.23 8.38 5.09 1.36 6.78 5.79 7.71 10.12 2.4 4.9 4.45 1.38
#  8.33 4.05 5.6 22.72 11.9 6.41 4.53 11.1 4.61 32.58 65.74 6.72 86.97 86.06
#  1.65 34.97 89.24 19.05 25.98 43.72 2.0 76.21 1.23 75.93 36.01 26.48 77.67
#  2.44 4.39 1.55 1.19 8.9 13.42 1.99 3.0 1.91 12.72 12.5 15.2 13.0 10.7
#  1.97 1.26 14.84 8.6 9.4 0.6 10.4 11.8 0.5 10.8 13.8 14.13 11.57 8.4 5.48
#  4.77 90.6 120.3 11.71 14.3 72.9 12.3 179.1 11.3 11.5 294.77 154.97 213.1
#  197.8 11.0 9.2 217.48 170.0 182.1 6.58 5.08 3.91 2.92 5.11 9.3 1.63 12.6
#  12.0 4.96 0.41 7.1 5.82 7.5 14.64 0.76 20.37 9.85 0.0 13.25 11.89 0.91
#  7.99 7.9 0.52 0.24 0.66 6.15 0.58 8.75 0.42 0.47 4.0 0.32 4.68 0.35 0.45
#  13.9 17.49 0.33 0.36 0.23 20.9 16.2 9.91 0.25 0.28 0.26 7.7 7.8 0.84 5.47
#  23.5 2.46 5.12 9.03 2.64 1.06 1.32 12.54 9.0 10.57 9.82 1.48 8.5 1.76
#  2.01 1.78 14.8 14.6 2.25 2.14 15.04 7.63 7.48 13.4 7.16 8.2 0.43 9.5 0.44
#  0.61 0.37 0.59 0.48 0.34 0.56 0.93 0.64 3.46 2.9 2.98 3.2 3.36 3.3 2.59
#  2.97 1.18 10.25 10.51 12.34 2.16 1.96 2.7 15.6 15.0 0.1 14.4 7.55 16.6
#  0.68 0.62 0.39 4.62 13.6 9.62 8.26 18.01 3.92 9.17 6.76 6.39 7.76 8.85
#  104.93 117.3 17.04 21.16 21.82 30.59 78.31 57.6 6.47 55.4 13.82 13.63
#  1.94 1.85 5.19 10.35 28.02 6.14 1.33 12.68 14.52 13.1 3.4 14.93 10.77 3.5
#  8.64 8.95 8.0 8.39 6.19 7.6 1.22 19.3 8.52 17.51 19.5 19.6 6.31 8.84 16.8
#  17.7 16.0 3.96 12.9 4.38 5.13 4.42 5.27 5.92 5.59 8.93 4.54 7.23 9.38
#  15.09 37.2 33.8 9.88 11.16 19.26 31.3 10.87 27.78 6.65 32.43 4.09 8.42
#  5.36 5.33 11.44 8.3 7.51 10.2 9.13 6.11 5.93 9.9 10.28 14.47 16.1 5.68
#  13.5 14.1 8.41 4.92 11.13 5.64 6.33 26.6 10.64 12.1 22.9 41.6 46.3 46.86
#  9.92 53.5 37.22 8.28 45.35 26.88 46.4 41.3 52.0 45.1 62.3 21.1 43.18
#  53.55 14.2 18.56 23.2 24.6 24.03 13.2 4.72 8.27 9.63 33.1 10.02 8.02
#  15.89 15.61 18.32 10.92 7.43 10.82 5.78 10.9 1.73 2.13 5.45 6.74 7.39
#  163.3 106.0 4.47 49.3 29.3 22.5 57.1 95.5 62.2 7.18 8.79 11.93 5.02 4.59
#  8.09 8.45 6.26 9.57 23.3 7.53 11.91 11.99 8.35 9.68 7.84 9.87 14.17 12.7
#  12.4 4.81 3.69 3.23 9.47 6.05 6.93 2.77 3.67 3.83 3.15 3.04 3.28 11.54
#  14.31 9.79 9.33 8.14 8.77 16.04 12.46 10.43 7.94 12.79 12.8 6.28 5.41
#  8.21 10.26 10.62 7.05 18.92 19.45 17.64 17.62 16.55 8.55 7.83 6.64 5.89
#  5.76 7.97 12.43 14.75 11.76 11.09 10.49 11.19 9.77 6.52 5.56 5.75 4.41
#  3.6 5.63 10.33 12.42 15.24 12.16 21.74 11.24 15.48 18.18 18.1 17.81 18.88
#  21.49 15.1 21.77 23.1 22.6 23.0 17.6 17.5 18.7 9.53 9.25 6.42 5.96 12.37
#  18.4 10.23 14.45 13.54 16.91 18.9 20.1 8.53 7.89 6.71 20.26 20.7 11.52
#  10.81 8.74 31.32 25.92 24.7 6.32 6.48 5.72 19.99 13.77 9.65]
# Всего строк со значением Лейкоциты (WBC): 1616

# %%
# https://gemotest.ru/info/spravochnik/analizy/obshchiy-analiz-krovi/
def get_wbc_norm(age, gender):
    """Возвращает норму лейкоцитов (WBC) в зависимости от возраста и пола."""
    # Нормы для детей
    if age < 10 / 12:
        return "6.0:17.5"
    elif age < 8:
        return "5.5:15.5"
    elif age < 12:
        return "4.5:13.5"
    elif age < 15:
        return "4.5:13.0"
    elif age < 18:
        return "4.5:11.3"
    
    # Нормы для мужчин
    if gender == 1:  # Мужчины
        if 12 <= age <= 16:
            return "4.5:13.0"
        else:
            return "4.5:11.3"
    
    # Нормы для женщин
    else:  # Женщины
        if 12 <= age <= 16:
            return "4.5:13.0"
        else:
            return "4.5:11.3"

# %%
# Применяем функцию для строк, где 'Кол. лаб. показатель' равно 'Лейкоциты (WBC)'
mask_wbc = df['Кол. лаб. показатель'] == 'Лейкоциты (WBC)'
df.loc[mask_wbc, 'Норма кол. показателя'] = df[mask_wbc].apply(lambda row: get_wbc_norm(row['Возраст'], row['Пол']), axis=1)

# Проверка результата
print("Установлены нормы лейкоцитов (WBC) для показателя 'Лейкоциты (WBC)'.")
print(df[mask_wbc][['Возраст', 'Пол', 'Норма кол. показателя']])
# Out:
# Установлены нормы лейкоцитов (WBC) для показателя 'Лейкоциты (WBC)'.
#        Возраст  Пол Норма кол. показателя
# 0           62    0              4.5:11.3
# 16          62    0              4.5:11.3
# 46          62    0              4.5:11.3
# 76          62    0              4.5:11.3
# 104         62    0              4.5:11.3
# ...        ...  ...                   ...
# 36168       42    1              4.5:11.3
# 36195       42    1              4.5:11.3
# 36217       42    1              4.5:11.3
# 36244       42    1              4.5:11.3
# 36266       10    1              4.5:13.5
#
# [1616 rows x 3 columns]

# %%
norm_info('Тромбокрит (PCT)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Тромбокрит (PCT):
# ['0,19:0,36' '0,14:0,28']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Тромбокрит (PCT):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Тромбокрит (PCT):
# [0.09 0.23 0.14 0.07 0.21 0.32 0.38 0.3 0.11 0.1 0.31 0.34 0.26 0.18 0.03
#  0.02 0.13 0.08 0.04 0.05 0.01 0.06 0.25 0.2 0.19 0.39 0.35 0.37 0.36 0.44
#  0.54 0.15 0.17 0.12 0.22 0.51 0.48 0.45 0.49 0.56 0.16 0.41 0.5 0.33 0.28
#  0.46 0.4 0.27 0.67 0.6 0.86 0.24 0.66 0.55 0.52 0.61 0.42 1.26 0.99 0.79
#  0.0 0.29 0.68 0.43 1.14 0.93 1.08 1.13 0.73 1.15 0.65 1.09 0.75 1.1 0.71
#  0.59 0.47 0.57 0.53 0.58 1.76 2.15 1.87 2.06 0.88 1.01 1.25 0.62 1.03 0.8
#  0.92 1.33 0.95 0.98 1.22 0.69 0.77 0.76 0.78 0.7 0.63 0.89 1.18 0.64 1.19
#  0.97 1.34 1.92 1.53 2.18 2.63 2.83 1.79 2.12 2.04 2.09 1.52 1.47 1.04]
# Всего строк со значением Тромбокрит (PCT): 925

# %%
# https://medlineservice.ru/articles/trombokrit/#:~:text=%D0%9D%D0%BE%D1%80%D0%BC%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5%20%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D1%8F%20%D1%82%D1%80%D0%BE%D0%BC%D0%B1%D0%BE%D0%BA%D1%80%D0%B8%D1%82%D0%B0,%D0%B2%D0%B7%D1%80%D0%BE%D1%81%D0%BB%D1%8B%D1%85%20%D0%B6%D0%B5%D0%BD%D1%89%D0%B8%D0%BD%2C%20%D0%BC%D1%83%D0%B6%D1%87%D0%B8%D0%BD%20%D0%B8%20%D0%B4%D0%B5%D1%82%D0%B5%D0%B9.
def get_pct_norm(age):
    """Возвращает норму тромбокрита (PCT) в зависимости от возраста."""
    # Нормы для детей до 18 лет
    if age < 18:
        return "0.15:0.35"
    # Норма для взрослых
    else:
        return "0.15:0.4"

# %%
# Применяем функцию для строк, где 'Кол. лаб. показатель' равно 'Тромбокрит (PCT)'
mask_pct = df['Кол. лаб. показатель'] == 'Тромбокрит (PCT)'
df.loc[mask_pct, 'Норма кол. показателя'] = df[mask_pct].apply(lambda row: get_pct_norm(row['Возраст']), axis=1)

# Проверка результата
print("Установлены нормы тромбокрита (PCT) для показателя 'Тромбокрит (PCT)'.")
print(df[mask_pct][['Возраст', 'Пол', 'Норма кол. показателя']])
# Out:
# Установлены нормы тромбокрита (PCT) для показателя 'Тромбокрит (PCT)'.
#        Возраст  Пол Норма кол. показателя
# 25          62    0              0.15:0.4
# 55          62    0              0.15:0.4
# 85          62    0              0.15:0.4
# 113         62    0              0.15:0.4
# 144         62    0              0.15:0.4
# ...        ...  ...                   ...
# 36154       42    1              0.15:0.4
# 36177       42    1              0.15:0.4
# 36203       42    1              0.15:0.4
# 36226       42    1              0.15:0.4
# 36252       42    1              0.15:0.4
#
# [925 rows x 3 columns]

# %%
norm_info('Средний объем тромбоцита (MPV)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Средний объем тромбоцита (MPV):
# ['9,1:12,6' '6,5:10' '6,5:12,6' '7.5:10.0' '7,5:10' '8,7:9,6' '6,5:10,0'
#  '_']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Средний объем тромбоцита (MPV):
# ['фл' '_']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Средний объем тромбоцита (MPV):
# [12.3 11.1 9.3 9.5 11.2 10.6 10.9 11.0 10.0 10.3 10.7 8.9 11.9 7.9 9.7 8.1
#  9.1 11.6 9.6 8.5 8.3 10.4 7.7 10.8 10.2 8.8 8.6 9.4 8.2 7.5 8.0 11.3 7.8
#  12.4 10.5 10.1 8.4 9.0 7.6 0.0 7.1 9.9 8.7 7.4 7.3 9.2 9.8 7.2 7.0 11.8
#  6.1 6.6 5.5 6.4 12.6 5.7 12.1 11.5 12.0 11.4 12.7 12.9 12.5 11.7 12.8
#  13.2]
# Всего строк со значением Средний объем тромбоцита (MPV): 982

# %%
# Фильтруем строки, где 'Кол. лаб. показатель' равен 'Средний объем тромбоцита (MPV)'
mpv_mask = df['Кол. лаб. показатель'] == 'Средний объем тромбоцита (MPV)'

# Считаем количество '_' в столбце 'Норма кол. показателя' для фильтрованных строк
norma_underscore_count = df[mpv_mask]['Норма кол. показателя'].value_counts().get('_', 0)

# Считаем количество '_' в столбце 'Ед. изм. кол. показателя' для фильтрованных строк
unit_underscore_count = df[mpv_mask]['Ед. изм. кол. показателя'].value_counts().get('_', 0)

# Выводим результаты
print(f"Количество значений '_' в столбце 'Норма кол. показателя' для 'Средний объем тромбоцита (MPV)': {norma_underscore_count}")
print(f"Количество значений '_' в столбце 'Ед. изм. кол. показателя' для 'Средний объем тромбоцита (MPV)': {unit_underscore_count}")
# Out:
# Количество значений '_' в столбце 'Норма кол. показателя' для 'Средний объем тромбоцита (MPV)': 9
# Количество значений '_' в столбце 'Ед. изм. кол. показателя' для 'Средний объем тромбоцита (MPV)': 5

# %%
mpv_norma_underscore_df = df[(df['Кол. лаб. показатель'] == 'Средний объем тромбоцита (MPV)') & (df['Норма кол. показателя'] == '_')]
mpv_norma_underscore_df
# Out:
#                          ID истории болезни  \
# 9836   f8b6efc7-215c-11ee-ab69-0050568844e6
# 9837   f8b6efc7-215c-11ee-ab69-0050568844e6
# 9838   f8b6efc7-215c-11ee-ab69-0050568844e6
# 9970   f8b6efc7-215c-11ee-ab69-0050568844e6
# 14895  a6cc0de1-ac03-11ec-ab54-0050568844e6
# 14980  a6cc0de1-ac03-11ec-ab54-0050568844e6
# 16109  e150616f-b636-11ec-ab54-0050568844e6
# 17750  7b9025cb-ae7c-11ec-ab54-0050568844e6
# 17779  7b9025cb-ae7c-11ec-ab54-0050568844e6
#
#       Осн. диаг. при выписке МКБ10 (текст)            Кол. лаб. показатель  \
# 9836              Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
# 9837              Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
# 9838              Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
# 9970              Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
# 14895             Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
# 14980             Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
# 16109             Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
# 17750             Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
# 17779             Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
#
#       Значение кол. показателя Ед. изм. кол. показателя Норма кол. показателя  \
# 9836                       9.1                       фл                     _
# 9837                       9.1                       фл                     _
# 9838                       9.1                       фл                     _
# 9970                      10.6                       фл                     _
# 14895                     10.0                        _                     _
# 14980                      9.7                        _                     _
# 16109                     11.2                        _                     _
# 17750                     10.6                        _                     _
# 17779                     10.8                        _                     _
#
#       Флаг нормы кол. показателя Кач. лаб. показатель  \
# 9836                        Норм           Анизоцитоз
# 9837                        Норм         Пойкилоцитоз
# 9838                        Норм          Комментарий
# 9970                        Норм          Комментарий
# 14895                       Норм                  NaN
# 14980                       Норм                  NaN
# 16109                       Норм                  NaN
# 17750                       Норм                  NaN
# 17779                       Норм                  NaN
#
#                                 Значение кач. показателя  \
# 9836                                                   +
# 9837                                                  ++
# 9838   тромбоциты по мазку периферичекой крови 62х10*9,л
# 9970                       тромбоциты проверены по мазку
# 14895                                                NaN
# 14980                                                NaN
# 16109                                                NaN
# 17750                                                NaN
# 17779                                                NaN
#
#       Норма кач. показателя  Пол  Возраст
# 9836                     +-    1       71
# 9837                     +-    1       71
# 9838                      _    1       71
# 9970                      _    1       71
# 14895                   NaN    1       66
# 14980                   NaN    1       66
# 16109                   NaN    0       39
# 17750                   NaN    0       72
# 17779                   NaN    0       72

# %%
mpv_ed_underscore_df = df[(df['Кол. лаб. показатель'] == 'Средний объем тромбоцита (MPV)') & (df['Ед. изм. кол. показателя'] == '_')]
mpv_ed_underscore_df
# Out:
#                          ID истории болезни  \
# 14895  a6cc0de1-ac03-11ec-ab54-0050568844e6
# 14980  a6cc0de1-ac03-11ec-ab54-0050568844e6
# 16109  e150616f-b636-11ec-ab54-0050568844e6
# 17750  7b9025cb-ae7c-11ec-ab54-0050568844e6
# 17779  7b9025cb-ae7c-11ec-ab54-0050568844e6
#
#       Осн. диаг. при выписке МКБ10 (текст)            Кол. лаб. показатель  \
# 14895             Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
# 14980             Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
# 16109             Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
# 17750             Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
# 17779             Другой уточненный лейкоз  Средний объем тромбоцита (MPV)
#
#       Значение кол. показателя Ед. изм. кол. показателя Норма кол. показателя  \
# 14895                     10.0                        _                     _
# 14980                      9.7                        _                     _
# 16109                     11.2                        _                     _
# 17750                     10.6                        _                     _
# 17779                     10.8                        _                     _
#
#       Флаг нормы кол. показателя Кач. лаб. показатель  \
# 14895                       Норм                  NaN
# 14980                       Норм                  NaN
# 16109                       Норм                  NaN
# 17750                       Норм                  NaN
# 17779                       Норм                  NaN
#
#       Значение кач. показателя Норма кач. показателя  Пол  Возраст
# 14895                      NaN                   NaN    1       66
# 14980                      NaN                   NaN    1       66
# 16109                      NaN                   NaN    0       39
# 17750                      NaN                   NaN    0       72
# 17779                      NaN                   NaN    0       72

# %% [markdown]
# делаем вывод что просто надо заменить '_' на 'фл'

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Средний объем тромбоцита (MPV)' и 'Ед. изм. кол. показателя' равно '_'
mpv_mask = (df['Кол. лаб. показатель'] == 'Средний объем тромбоцита (MPV)') & (df['Ед. изм. кол. показателя'] == '_')

# Заменяем значения '_' на 'фл' в отфильтрованных строках
df.loc[mpv_mask, 'Ед. изм. кол. показателя'] = 'фл'

# %%
new_MPV_df = df[df['Кол. лаб. показатель'] == 'Средний объем тромбоцита (MPV)']

# %%
new_unique_ed_MPV = new_MPV_df['Ед. изм. кол. показателя'].unique()
print("Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя 'Средний объем тромбоцита (MPV)':")
print(new_unique_ed_MPV)
# Out:
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя 'Средний объем тромбоцита (MPV)':
# ['фл']

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Средний объем тромбоцита (MPV)'
mpv_mask = df['Кол. лаб. показатель'] == 'Средний объем тромбоцита (MPV)'

# Задаем норму '7.8:11.0' в отфильтрованных строках в столбце 'Норма кол. показателя'
df.loc[mpv_mask, 'Норма кол. показателя'] = '7.8:11.0'

# %%
# Проверка изменений
print("Изменения в столбце 'Норма кол. показателя' для 'Средний объем тромбоцита (MPV)':")
print(df[mpv_mask][['Кол. лаб. показатель', 'Норма кол. показателя']])
# Out:
# Изменения в столбце 'Норма кол. показателя' для 'Средний объем тромбоцита (MPV)':
#                  Кол. лаб. показатель Норма кол. показателя
# 26     Средний объем тромбоцита (MPV)              7.8:11.0
# 56     Средний объем тромбоцита (MPV)              7.8:11.0
# 86     Средний объем тромбоцита (MPV)              7.8:11.0
# 114    Средний объем тромбоцита (MPV)              7.8:11.0
# 145    Средний объем тромбоцита (MPV)              7.8:11.0
# ...                               ...                   ...
# 36165  Средний объем тромбоцита (MPV)              7.8:11.0
# 36178  Средний объем тромбоцита (MPV)              7.8:11.0
# 36214  Средний объем тромбоцита (MPV)              7.8:11.0
# 36227  Средний объем тромбоцита (MPV)              7.8:11.0
# 36263  Средний объем тромбоцита (MPV)              7.8:11.0
#
# [982 rows x 2 columns]

# %%
norm_info('Распределение эритроцитов по объему (RDW)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Распределение эритроцитов по объему (RDW):
# ['10,5:18' '10:18' '10,5:18,0' '11:16' '11:18']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Распределение эритроцитов по объему (RDW):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Распределение эритроцитов по объему (RDW):
# [20.0 20.5 18.9 17.6 18.6 21.2 20.2 13.9 17.0 20.3 19.9 22.9 20.6 24.6
#  25.4 24.7 20.7 12.8 14.0 13.1 13.4 13.8 13.0 18.8 14.9 11.5 11.4 22.0
#  15.8 20.8 16.0 13.3 13.2 15.0 20.4 26.1 18.0 21.0 26.4 21.3 22.7 11.0
#  12.0 16.1 17.2 23.0 15.9 17.1 17.3 14.4 14.7 14.3 15.3 19.2 14.8 15.4
#  27.0 16.2 15.5 15.1 14.1 18.7 18.5 16.6 13.5 14.2 17.4 15.2 14.6 19.8
#  19.0 26.0 19.5 18.1 19.4 15.7 15.6 16.3 17.7 18.2 16.5 17.5 14.5 11.7
#  13.6 16.8 19.3 17.8 23.3 18.3 21.9 19.1 24.0 16.9 19.6 21.8 16.07 11.8
#  19.7 23.6 25.2 24.1 12.6 22.8 28.5 16.7 12.9 12.7 25.0 17.9 20.1 24.4
#  22.1 24.2 23.9 23.5 21.7 21.1 20.9 10.9 30.2 16.4 29.2 34.9 22.6 30.6
#  22.2 23.2 18.4 23.8 26.6 30.0 31.0 10.0 28.0]
# Всего строк со значением Распределение эритроцитов по объему (RDW): 829

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Распределение эритроцитов по объему (RDW)'
rdw_mask = df['Кол. лаб. показатель'] == 'Распределение эритроцитов по объему (RDW)'

# Задаем норму '10:18' в отфильтрованных строках в столбце 'Норма кол. показателя'
df.loc[rdw_mask, 'Норма кол. показателя'] = '10:18'

# Проверка изменений
print("Изменения в столбце 'Норма кол. показателя' для 'Распределение эритроцитов по объему (RDW)':")
print(df[rdw_mask][['Кол. лаб. показатель', 'Норма кол. показателя']])
# Out:
# Изменения в столбце 'Норма кол. показателя' для 'Распределение эритроцитов по объему (RDW)':
#                             Кол. лаб. показатель Норма кол. показателя
# 23     Распределение эритроцитов по объему (RDW)                 10:18
# 53     Распределение эритроцитов по объему (RDW)                 10:18
# 83     Распределение эритроцитов по объему (RDW)                 10:18
# 111    Распределение эритроцитов по объему (RDW)                 10:18
# 194    Распределение эритроцитов по объему (RDW)                 10:18
# ...                                          ...                   ...
# 35969  Распределение эритроцитов по объему (RDW)                 10:18
# 36113  Распределение эритроцитов по объему (RDW)                 10:18
# 36175  Распределение эритроцитов по объему (RDW)                 10:18
# 36224  Распределение эритроцитов по объему (RDW)                 10:18
# 36284  Распределение эритроцитов по объему (RDW)                 10:18
#
# [829 rows x 2 columns]

# %%
norm_info('Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Распределение эритроцитов по объему, стандартное отклонение (RDW-SD):
# ['37:54' '35.3:48.9' '35:48' '33.4:49.2' '33:49']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Распределение эритроцитов по объему, стандартное отклонение (RDW-SD):
# ['фл']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Распределение эритроцитов по объему, стандартное отклонение (RDW-SD):
# [58.7 59.6 50.4 63.2 49.6 51.3 49.4 59.1 61.4 58.8 49.0 58.6 62.5 51.0
#  47.0 61.2 66.8 57.0 52.0 53.6 53.4 59.2 37.0 51.2 52.7 42.0 37.5 36.5
#  38.9 38.7 38.5 36.3 44.5 40.3 41.0 43.0 44.0 39.2 38.8 39.0 39.1 37.9
#  65.8 39.5 39.3 58.2 54.0 38.0 53.0 48.0 41.4 46.0 69.9 58.9 65.5 69.5
#  62.0 67.1 58.1 55.0 56.0 53.2 54.3 58.0 78.0 73.2 57.8 50.1 55.2 50.7
#  55.4 59.3 57.1 53.8 85.4 61.0 79.7 65.0 83.1 81.5 50.0 49.9 55.1 45.7
#  44.4 45.8 45.2 45.1 49.3 50.2 51.1 52.5 50.5 65.2 63.0 60.4 59.9 63.3
#  55.8 60.8 56.3 54.6 49.2 49.1 51.9 56.5 46.9 60.7 36.0 35.0 40.0 34.0
#  52.8 50.6 51.6 52.9 51.4 51.5 50.9 43.2 44.7 42.6 57.2 55.7 47.3 44.3
#  43.4 44.1 54.9 58.5 54.8 53.5 56.7 56.9 62.9 69.3 62.8 57.4 45.0 48.6
#  49.8 44.2 41.3 40.9 42.7 42.8 43.3 41.6 43.1 54.4 55.5 53.3 48.4 46.1
#  43.8 43.9 47.7 43.7 47.6 44.8 70.0 60.0 75.0 62.2 42.9 48.9 64.0 48.3
#  49.7 47.2 47.8 97.6 42.5 43.5 52.1 54.7 49.5 60.1 57.7 61.1 71.0 82.0
#  67.0 47.4 86.0 69.0 72.0 59.0 66.0 77.0 73.0 84.0 76.0]
# Всего строк со значением Распределение эритроцитов по объему, стандартное отклонение (RDW-SD): 698

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'RDW-SD'
rdw_sd_mask = df['Кол. лаб. показатель'] == 'Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)'

# Задаем норму '35:60 фл' в отфильтрованных строках в столбце 'Норма кол. показателя'
df.loc[rdw_sd_mask, 'Норма кол. показателя'] = '35:60'

# Проверка изменений
print("Изменения в столбце 'Норма кол. показателя' для 'Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)':")
print(df[rdw_sd_mask][['Кол. лаб. показатель', 'Норма кол. показателя']])
# Out:
# Изменения в столбце 'Норма кол. показателя' для 'Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)':
#                                     Кол. лаб. показатель Норма кол. показателя
# 15     Распределение эритроцитов по объему, стандартн...                 35:60
# 142    Распределение эритроцитов по объему, стандартн...                 35:60
# 170    Распределение эритроцитов по объему, стандартн...                 35:60
# 297    Распределение эритроцитов по объему, стандартн...                 35:60
# 326    Распределение эритроцитов по объему, стандартн...                 35:60
# ...                                                  ...                   ...
# 36099  Распределение эритроцитов по объему, стандартн...                 35:60
# 36138  Распределение эритроцитов по объему, стандартн...                 35:60
# 36167  Распределение эритроцитов по объему, стандартн...                 35:60
# 36216  Распределение эритроцитов по объему, стандартн...                 35:60
# 36265  Распределение эритроцитов по объему, стандартн...                 35:60
#
# [698 rows x 2 columns]

# %%
norm_info('Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Распределение эритроцитов по объему, коэффициент вариации (RDW-CV):
# ['10,5:18' '10:18']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Распределение эритроцитов по объему, коэффициент вариации (RDW-CV):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Распределение эритроцитов по объему, коэффициент вариации (RDW-CV):
# [20.3 17.5 21.2 17.4 17.3 19.8 20.8 20.6 17.0 19.6 16.0 20.4 22.8 20.1
#  19.7 23.7 23.8 24.6 13.3 22.9 23.1 15.0 13.0 14.0 13.5 13.1 13.7 13.2
#  13.9 12.5 22.1 13.6 12.9 19.9 20.0 18.0 19.0 21.0 25.3 24.3 23.4 20.2
#  18.7 19.2 25.5 24.2 16.8 16.1 16.3 17.1 17.7 18.3 21.5 23.0 22.0 15.9
#  16.7 15.7 15.1 15.2 18.4 18.1 17.9 17.2 18.8 16.9 17.6 17.8 14.6 18.9
#  18.6 14.5 14.3 15.3 14.2 16.2 15.4 15.6 20.7 19.4 19.1 21.4 26.9 25.0
#  19.3 14.1 12.8 13.4 13.8 14.8 23.2 23.9 15.5 16.5 24.0 26.0 33.2 34.2
#  31.3 34.0 15.8 21.3 21.1 16.4 28.3 28.8 14.7 19.5 32.0 28.0 30.0 16.6
#  33.0 29.0 31.0 27.0]
# Всего строк со значением Распределение эритроцитов по объему, коэффициент вариации (RDW-CV): 696

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)'
rdw_cv_mask = df['Кол. лаб. показатель'] == 'Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)'

# Задаем норму '10:18' в отфильтрованных строках в столбце 'Норма кол. показателя'
df.loc[rdw_cv_mask, 'Норма кол. показателя'] = '10:18'

# Проверка изменений
print("Изменения в столбце 'Норма кол. показателя' для 'Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)':")
print(df[rdw_cv_mask][['Кол. лаб. показатель', 'Норма кол. показателя']])
# Out:
# Изменения в столбце 'Норма кол. показателя' для 'Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)':
#                                     Кол. лаб. показатель Норма кол. показателя
# 14     Распределение эритроцитов по объему, коэффицие...                 10:18
# 141    Распределение эритроцитов по объему, коэффицие...                 10:18
# 169    Распределение эритроцитов по объему, коэффицие...                 10:18
# 296    Распределение эритроцитов по объему, коэффицие...                 10:18
# 327    Распределение эритроцитов по объему, коэффицие...                 10:18
# ...                                                  ...                   ...
# 36062  Распределение эритроцитов по объему, коэффицие...                 10:18
# 36074  Распределение эритроцитов по объему, коэффицие...                 10:18
# 36086  Распределение эритроцитов по объему, коэффицие...                 10:18
# 36098  Распределение эритроцитов по объему, коэффицие...                 10:18
# 36137  Распределение эритроцитов по объему, коэффицие...                 10:18
#
# [696 rows x 2 columns]

# %%
norm_info('Распределение тромбоцитов по объему (PDW)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Распределение тромбоцитов по объему (PDW):
# ['9,3:16,7' '9:17' '15.0:17.0' '15:17' '_']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Распределение тромбоцитов по объему (PDW):
# ['фл' '%' 'г/л']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Распределение тромбоцитов по объему (PDW):
# [13.5 12.9 17.3 15.0 13.0 18.5 13.1 13.6 14.3 12.5 11.5 12.6 10.1 10.5
#  14.4 13.3 15.6 10.7 9.4 16.7 14.0 10.8 12.1 11.3 11.4 13.4 10.0 14.9 11.0
#  9.9 10.6 10.2 14.5 16.4 15.1 13.8 12.7 11.1 14.6 14.1 9.3 14.8 13.2 10.3
#  9.5 11.7 12.8 9.8 11.8 11.9 10.9 13.9 14.7 0.0 12.3 9.6 17.2 12.0 11.6
#  12.4 10.4 12.2 8.8 17.1 11.2 18.7 18.9 19.9 9.0 14.2 8.2 15.5 8.5 7.0 9.1
#  5.8 15.2 6.7 5.2 6.0 6.4 5.1 5.7 9.7 15.3 18.4 19.5 9.2 18.3 16.6 7.4
#  15.4 23.5 17.4 17.0 19.1 13.7 15.8 19.7 16.0 28.4 20.9 24.0 21.1 20.7
#  16.5 16.8]
# Всего строк со значением Распределение тромбоцитов по объему (PDW): 657

# %%
PDW_ed_fl_df = df[(df['Кол. лаб. показатель'] == 'Распределение тромбоцитов по объему (PDW)') & (df['Ед. изм. кол. показателя'] == 'фл')]
PDW_ed_fl_df.head()
# Out:
#                        ID истории болезни  \
# 27   2e1d0b3f-488a-11ed-ab5a-0050568844e6
# 57   2e1d0b3f-488a-11ed-ab5a-0050568844e6
# 146  2e1d0b3f-488a-11ed-ab5a-0050568844e6
# 171  24612d4d-c466-11ec-ab54-0050568844e6
# 182  24612d4d-c466-11ec-ab54-0050568844e6
#
#     Осн. диаг. при выписке МКБ10 (текст)  \
# 27                Плазмоклеточный лейкоз
# 57                Плазмоклеточный лейкоз
# 146               Плазмоклеточный лейкоз
# 171             Другой уточненный лейкоз
# 182             Другой уточненный лейкоз
#
#                           Кол. лаб. показатель Значение кол. показателя  \
# 27   Распределение тромбоцитов по объему (PDW)                     13.5
# 57   Распределение тромбоцитов по объему (PDW)                     12.9
# 146  Распределение тромбоцитов по объему (PDW)                     17.3
# 171  Распределение тромбоцитов по объему (PDW)                     15.0
# 182  Распределение тромбоцитов по объему (PDW)                     13.0
#
#     Ед. изм. кол. показателя Норма кол. показателя Флаг нормы кол. показателя  \
# 27                        фл              9,3:16,7                       Норм
# 57                        фл              9,3:16,7                       Норм
# 146                       фл                  9:17                      Повыш
# 171                       фл                  9:17                       Норм
# 182                       фл              9,3:16,7                       Норм
#
#     Кач. лаб. показатель Значение кач. показателя Норма кач. показателя  Пол  \
# 27                   NaN                      NaN                   NaN    0
# 57                   NaN                      NaN                   NaN    0
# 146                  NaN                      NaN                   NaN    0
# 171                  NaN                      NaN                   NaN    0
# 182                  NaN                      NaN                   NaN    0
#
#      Возраст
# 27        62
# 57        62
# 146       62
# 171       85
# 182       85

# %%
PDW_ed_gl_df = df[(df['Кол. лаб. показатель'] == 'Распределение тромбоцитов по объему (PDW)') & (df['Ед. изм. кол. показателя'] == 'г/л')]
PDW_ed_gl_df.head()
# Out:
#                          ID истории болезни  \
# 14882  a6cc0de1-ac03-11ec-ab54-0050568844e6
# 14931  a6cc0de1-ac03-11ec-ab54-0050568844e6
# 16096  e150616f-b636-11ec-ab54-0050568844e6
# 17738  7b9025cb-ae7c-11ec-ab54-0050568844e6
# 17766  7b9025cb-ae7c-11ec-ab54-0050568844e6
#
#       Осн. диаг. при выписке МКБ10 (текст)  \
# 14882             Другой уточненный лейкоз
# 14931             Другой уточненный лейкоз
# 16096             Другой уточненный лейкоз
# 17738             Другой уточненный лейкоз
# 17766             Другой уточненный лейкоз
#
#                             Кол. лаб. показатель Значение кол. показателя  \
# 14882  Распределение тромбоцитов по объему (PDW)                     10.8
# 14931  Распределение тромбоцитов по объему (PDW)                      9.8
# 16096  Распределение тромбоцитов по объему (PDW)                     13.0
# 17738  Распределение тромбоцитов по объему (PDW)                     12.0
# 17766  Распределение тромбоцитов по объему (PDW)                     11.1
#
#       Ед. изм. кол. показателя Норма кол. показателя  \
# 14882                      г/л                     _
# 14931                      г/л                     _
# 16096                      г/л                     _
# 17738                      г/л                     _
# 17766                      г/л                     _
#
#       Флаг нормы кол. показателя Кач. лаб. показатель  \
# 14882                       Норм                  NaN
# 14931                       Норм                  NaN
# 16096                       Норм                  NaN
# 17738                       Норм                  NaN
# 17766                       Норм                  NaN
#
#       Значение кач. показателя Норма кач. показателя  Пол  Возраст
# 14882                      NaN                   NaN    1       66
# 14931                      NaN                   NaN    1       66
# 16096                      NaN                   NaN    0       39
# 17738                      NaN                   NaN    0       72
# 17766                      NaN                   NaN    0       72

# %% [markdown]
# Судя по флагу -- это просто ошибка заполняющего и везде долждны быть проценты (норма в интернете указана в процентах)

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Распределение тромбоцитов по объему (PDW)'
pdw_mask = df['Кол. лаб. показатель'] == 'Распределение тромбоцитов по объему (PDW)'

# Заменяем единицы измерения на '%'
df.loc[pdw_mask, 'Ед. изм. кол. показателя'] = '%'

# Проверка изменений
print("Обновленные значения в столбце 'Ед. изм. кол. показателя' для показателя 'Распределение тромбоцитов по объему (PDW)':")
print(df[pdw_mask][['Кол. лаб. показатель', 'Ед. изм. кол. показателя']].head())
# Out:
# Обновленные значения в столбце 'Ед. изм. кол. показателя' для показателя 'Распределение тромбоцитов по объему (PDW)':
#                           Кол. лаб. показатель Ед. изм. кол. показателя
# 27   Распределение тромбоцитов по объему (PDW)                        %
# 57   Распределение тромбоцитов по объему (PDW)                        %
# 146  Распределение тромбоцитов по объему (PDW)                        %
# 171  Распределение тромбоцитов по объему (PDW)                        %
# 182  Распределение тромбоцитов по объему (PDW)                        %

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)'
pdw_mask = df['Кол. лаб. показатель'] == 'Распределение тромбоцитов по объему (PDW)'

# Задаем норму '10:18' в отфильтрованных строках в столбце 'Норма кол. показателя'
df.loc[pdw_mask, 'Норма кол. показателя'] = '9.0:17.0'

# Проверка изменений
print("Изменения в столбце 'Норма кол. показателя' для 'Распределение тромбоцитов по объему (PDW)':")
print(df[pdw_mask][['Кол. лаб. показатель', 'Норма кол. показателя']])
# Out:
# Изменения в столбце 'Норма кол. показателя' для 'Распределение тромбоцитов по объему (PDW)':
#                             Кол. лаб. показатель Норма кол. показателя
# 27     Распределение тромбоцитов по объему (PDW)              9.0:17.0
# 57     Распределение тромбоцитов по объему (PDW)              9.0:17.0
# 146    Распределение тромбоцитов по объему (PDW)              9.0:17.0
# 171    Распределение тромбоцитов по объему (PDW)              9.0:17.0
# 182    Распределение тромбоцитов по объему (PDW)              9.0:17.0
# ...                                          ...                   ...
# 35796  Распределение тромбоцитов по объему (PDW)              9.0:17.0
# 36166  Распределение тромбоцитов по объему (PDW)              9.0:17.0
# 36179  Распределение тромбоцитов по объему (PDW)              9.0:17.0
# 36215  Распределение тромбоцитов по объему (PDW)              9.0:17.0
# 36264  Распределение тромбоцитов по объему (PDW)              9.0:17.0
#
# [657 rows x 2 columns]

# %%
norm_info('Лимфоциты, относительное количество (LY%)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Лимфоциты, относительное количество (LY%):
# ['18:44' '18,0:44,0 ' '18,0:44,0' '20:45']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Лимфоциты, относительное количество (LY%):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Лимфоциты, относительное количество (LY%):
# [50.0 54.2 32.8 8.4 58.8 19.6 17.5 9.2 11.6 40.7 20.3 7.9 17.2 13.7 16.7
#  47.0 4.2 64.4 21.5 27.5 35.6 55.8 41.9 33.5 26.8 22.1 37.5 20.6 26.3 32.7
#  25.2 27.0 62.7 24.1 23.8 20.5 26.9 45.1 23.6 49.7 39.1 71.7 29.5 25.3
#  46.7 57.1 64.6 12.0 39.8 61.8 54.1 100.0 67.1 38.5 21.1 29.1 16.8 76.7
#  52.1 72.3 19.5 25.8 25.0 26.4 58.3 79.6 16.6 17.8 59.1 64.8 24.3 33.2
#  21.6 34.1 32.2 28.5 37.3 24.4 31.9 79.4 80.9 84.7 35.4 12.1 85.1 30.5
#  11.0 11.3 11.2 30.4 10.3 11.1 12.2 29.7 25.5 28.6 24.2 32.1 64.2 28.0
#  30.6 15.2 53.5 18.8 53.4 30.8 29.6 27.3 63.0 50.3 25.4 35.1 42.5 48.6
#  55.3 34.0 25.9 29.4 33.8 39.5 41.6 40.9 40.8 29.0 43.8 36.3 37.0 13.4
#  41.5 43.2 34.5 12.9 13.1 11.4 49.8 49.2 51.1 14.7 10.6 47.9 54.0 57.2 9.5
#  13.3 56.9 47.4 44.4 38.4 41.2 49.6 12.8 11.7 18.5 15.1 14.0 62.4 23.3
#  52.0 14.4 16.4 20.0 14.2 21.4 54.5 54.7 87.0 34.9 68.8 18.6 11.5 13.6
#  14.6 83.0 82.3 82.0 78.6 8.5 48.7 73.4 15.0 14.1 17.4 83.5 18.1 16.0 76.8
#  82.5 77.5 83.7 19.3 20.4 16.5 50.7 28.8 49.3 35.9 38.42 41.4 81.1 86.2
#  69.5 82.9 38.0 77.9 69.4 13.9 67.8 66.8 77.4 70.5 69.0 72.7 40.3 47.6
#  46.4 75.1 67.6 76.1 42.7 23.7 28.1 45.2 31.0 24.9 14.5 40.2 24.5 41.0
#  18.3 23.2 15.7 27.6 31.7 29.3 37.6 34.6 33.0 31.8 43.3 11.8 74.6 26.2
#  84.5 34.8 39.7 43.6 92.8 52.2 32.4 37.2 33.9 46.6 32.0 36.1 32.5 24.0
#  45.5 39.3 38.9 26.7 87.7 93.1 73.1 36.7 23.5 95.1 20.1 88.1 92.5 97.5 9.7
#  13.5 85.9 91.6 22.4 76.0 6.2 10.9 10.4 7.5 10.1 8.0 13.2 19.2 12.7 12.6
#  15.4 69.7 18.4 17.6 24.8 36.5 85.2 25.1 60.5 81.0 6.4 21.9 75.0 36.6 28.7
#  67.5 16.2 15.3 71.4 65.8 14.8 61.6 73.9 67.0 0.0 13.0 56.2 79.2 19.0 15.8
#  80.6 81.7 76.2 21.2 22.2 79.9 33.1 30.9 7.1 91.7 85.7 7.0 9.4 91.1 90.4
#  90.5 88.9 88.5 88.2 10.5 26.5 68.0 64.3 46.2 51.2 60.0 64.7 23.9 22.0
#  13.8 38.1 46.0 30.0 16.3 23.1 15.9 12.5 16.1 15.82 13.73 10.2 10.8 18.2
#  19.9 17.1 14.9 9.0 7.8 31.1 9.8 18.7 22.7 11.9 33.7 86.8 37.9 74.9 80.5
#  72.1 56.4 36.4 27.8 23.0 34.7 31.6 54.3 63.3 48.1 38.6 28.2 71.3 48.0
#  61.7 36.2 65.3 62.8 10.0 66.4 26.1 23.4 33.3 32.3 30.3 35.8 65.6 10.16
#  8.3 34.4 31.5 19.7 22.5 15.26 63.4 61.3 62.3 69.3 22.3 30.1 34.48 27.1
#  18.9 25.66 24.87 38.2 19.8 25.7 19.4 9.1 15.6 5.3 17.3 5.0 4.7 5.2 28.9
#  20.9 21.21 22.44 48.3 45.9 51.9 58.1 29.2 22.6 66.2 22.89 25.6 35.0 24.7
#  14.15 9.12 20.2 16.9 31.3 17.9 17.7 24.6 20.7 22.9 57.3 21.7 18.0 63.5
#  43.9 26.6 51.7 57.0 30.2 9.3 27.7 7.4 6.1 6.0 7.3 20.8 7.6 29.9 18.55
#  12.3 6.8 37.4 8.8 30.7 31.2 28.3 40.5 38.3 21.8 2.6 28.52 7.7 3.9 27.2
#  29.8 44.6 6.6 33.4 3.8 5.9 14.3 21.0 15.5 46.1 26.0 12.4 6.9 27.9 40.6
#  64.1 59.9 32.6 42.4 21.3 8.2 71.8 87.5 32.9 42.2 77.7 12.82 4.5 53.1 77.2
#  57.5 87.4 42.9 91.4 48.8 90.7 36.8 8.7 45.7 40.0 19.1 37.8 45.0 35.2 9.6
#  10.7 27.4 28.4 39.0 31.4 6.3 83.1 75.5]
# Всего строк со значением Лимфоциты, относительное количество (LY%): 1470

# %%
# Функция для определения нормы лимфоцитов на основе возраста и пола
def get_ly_otn_norm(age, gender):
    if age <= 1 / 12:  # до 1 месяца
        return '25:60'
    elif 1 / 12 < age <= 1:  # 2–12 месяцев
        return '40:70'
    elif 1 < age <= 5:  # 1–5 лет
        return '35:60'
    elif 5 < age <= 10:  # 5–10 лет
        return '30:50'
    elif 10 < age <= 14:  # 10–14 лет
        return '30:48'
    elif age > 14:  # > 14 лет
        return '22:45'
    else:
        return None  # В случае, если возраст не попадает ни в одну категорию

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Лимфоциты, относительное количество (LY%)'
ly_otn_mask = df['Кол. лаб. показатель'] == 'Лимфоциты, относительное количество (LY%)'

# Применяем функцию к нужным строкам и обновляем столбец 'Норма кол. показателя'
df.loc[ly_otn_mask, 'Норма кол. показателя'] = df[ly_otn_mask].apply(lambda row: get_ly_otn_norm(row['Возраст'], row['Пол']), axis=1)

# Проверка результатов
print("Обновленные значения 'Норма кол. показателя' для показателя 'Лимфоциты, относительное количество (LY%)':")
print(df[ly_otn_mask][['Возраст', 'Пол', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Лимфоциты, относительное количество (LY%)':
#      Возраст  Пол Норма кол. показателя
# 9         62    0                 22:45
# 29        62    0                 22:45
# 59        62    0                 22:45
# 93        62    0                 22:45
# 121       62    0                 22:45

# %%
norm_info('Лимфоциты, абсолютное количество (LY#)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Лимфоциты, абсолютное количество (LY#):
# ['1:3,7' '1,00:3,70' '1,00:3.70' '_' '1,0:3,7']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Лимфоциты, абсолютное количество (LY#):
# ['10*9/л']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Лимфоциты, абсолютное количество (LY#):
# [0.9 0.58 0.62 0.42 0.96 0.7 1.1 0.61 0.66 1.02 1.3 0.8 0.87 2.01 0.5 5.29
#  1.53 1.8 0.6 9.18 1.6 5.62 2.39 1.4 1.5 2.3 1.46 1.2 0.43 1.0 0.2 0.92
#  0.68 2.24 2.49 0.85 1.73 0.46 2.5 3.47 2.74 1.99 2.4 1.34 12.57 12.86
#  15.7 2.0 16.81 2.23 0.89 2.04 1.57 1.9 0.81 0.83 0.72 0.91 1.18 8.64 0.64
#  57.8 0.99 2.21 2.35 1.25 27.44 4.38 1.22 3.6 5.18 6.79 5.11 4.23 4.36
#  4.59 1.26 1.63 4.11 4.07 11.5 3.1 4.01 2.99 1.65 4.56 3.9 3.82 5.38 5.76
#  7.92 1.93 2.86 2.07 2.03 1.87 0.36 1.28 0.4 0.3 0.32 1.03 0.93 1.76 1.12
#  0.69 1.52 1.88 1.55 2.11 2.77 2.2 1.06 2.48 1.77 2.1 1.05 1.14 3.77 7.05
#  2.9 1.85 0.45 6.03 0.48 0.39 8.94 1.82 1.15 1.31 0.53 4.6 5.48 4.06 3.7
#  5.5 4.2 4.9 0.77 0.49 3.96 1.7 1.56 1.07 0.73 42.72 18.34 137.9 30.58
#  1.59 1.44 1.32 1.09 0.15 0.54 0.51 0.19 0.97 0.47 0.25 0.41 0.29 0.21
#  0.44 0.35 1.04 0.17 0.18 0.12 0.27 3.2 1.91 2.09 0.33 2.7 2.02 1.78 1.35
#  0.16 1.68 2.38 1.69 0.94 0.38 0.24 0.23 0.22 0.56 1.24 0.67 0.78 0.75 2.6
#  5.15 2.8 3.0 2.47 4.48 0.76 1.72 1.45 5.55 2.94 3.16 3.44 3.33 3.92 2.68
#  1.66 2.87 3.99 2.93 3.06 1.48 2.92 1.42 2.28 2.16 2.05 4.4 4.3 3.5 1.83
#  1.92 4.1 3.4 5.65 2.78 2.25 2.29 1.74 1.13 0.86 1.71 2.76 2.33 1.38 1.27
#  2.45 2.12 0.57 1.98 1.21 1.62 3.03 5.3 4.0 2.84 5.59 2.75 15.2 2.57 2.44
#  0.26 1.81 1.79 53.2 25.6 6.7 12.4 7.6 7.8 7.7 1.11 0.1 1.94 2.36 8.1 2.83
#  2.18 5.8 1.67 1.29 2.88 1.43 1.54 1.23 3.72 5.41 4.32 4.29 3.81 3.59 3.56
#  4.25 1.97 5.0 0.88 2.13 2.61 2.32 2.17 2.66 1.58 2.19 2.95 3.48 4.78 4.43
#  3.52 1.16 1.75 1.95 3.69 3.67 1.51 2.52 3.26 3.25 1.86 2.53 1.33 2.65
#  1.37 5.6 3.3 4.35 2.55 8.01]
# Всего строк со значением Лимфоциты, абсолютное количество (LY#): 1470

# %%
# Функция для определения нормы абсолютного количества лимфоцитов на основе возраста и пола
def get_ly_abs_norm(age, gender):
    if age <= 1 / 12:  # до 1 месяца
        return '1.25:12.6'
    elif 1 / 12 < age <= 1:  # 2–12 месяцев
        return '2.2:12.3'
    elif 1 < age <= 5:  # 1–5 лет
        return '1.9:9.3'
    elif 5 < age <= 10:  # 5–10 лет
        return '1.3:7.3'
    elif 10 < age <= 14:  # 10–14 лет
        return '1.3:6.2'
    elif age > 14:  # > 14 лет (взрослые)
        return '1.0:4.0'
    else:
        return None  # В случае, если возраст не попадает ни в одну категорию

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Лимфоциты, абсолютное количество (LY#)'
ly_abs_mask = df['Кол. лаб. показатель'] == 'Лимфоциты, абсолютное количество (LY#)'

# Применяем функцию к нужным строкам и обновляем столбец 'Норма кол. показателя'
df.loc[ly_abs_mask, 'Норма кол. показателя'] = df[ly_abs_mask].apply(lambda row: get_ly_abs_norm(row['Возраст'], row['Пол']), axis=1)

# Проверка результатов
print("Обновленные значения 'Норма кол. показателя' для показателя 'Лимфоциты, абсолютное количество (LY#)':")
print(df[ly_abs_mask][['Возраст', 'Пол', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Лимфоциты, абсолютное количество (LY#)':
#      Возраст  Пол Норма кол. показателя
# 11        62    0               1.0:4.0
# 34        62    0               1.0:4.0
# 64        62    0               1.0:4.0
# 88        62    0               1.0:4.0
# 116       62    0               1.0:4.0

# %%
norm_info('Нейтрофилы, относительное количество (NE%)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Нейтрофилы, относительное количество (NE%):
# ['45:72' '45,0:72,0' '41:75']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Нейтрофилы, относительное количество (NE%):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Нейтрофилы, относительное количество (NE%):
# [27.9 21.5 50.3 85.4 20.0 68.6 77.6 71.6 40.8 59.8 82.8 68.2 70.5 69.2
#  23.5 92.9 23.0 74.3 62.1 9.4 20.9 24.8 55.8 4.3 29.2 5.8 58.7 41.4 14.5
#  32.8 49.7 70.8 71.9 71.2 63.3 26.1 65.8 63.2 17.3 44.8 17.2 62.9 67.6
#  11.1 26.0 32.3 66.4 35.6 27.4 0.0 29.1 20.8 36.5 12.8 60.2 63.8 25.9 62.7
#  57.3 22.5 53.4 52.0 75.9 59.7 41.2 55.2 57.6 57.4 69.3 13.1 11.3 13.0
#  60.6 58.0 59.9 72.2 11.7 58.8 75.4 73.5 70.0 59.2 74.7 68.5 38.4 45.2
#  70.6 73.6 68.8 73.3 48.3 41.0 33.1 64.1 80.9 6.0 75.7 34.9 35.9 66.7 51.9
#  15.4 72.1 61.8 73.9 50.5 44.6 58.4 67.4 61.6 55.3 52.6 53.9 53.7 69.0
#  72.3 50.8 61.0 56.0 43.5 51.6 48.9 57.9 72.0 68.3 77.1 41.8 43.1 40.2
#  74.5 72.7 39.0 34.4 82.1 77.7 37.7 57.8 38.1 32.2 39.9 53.6 37.6 61.4
#  82.0 85.2 81.0 77.9 81.9 66.9 66.3 64.5 69.7 32.6 71.5 67.9 70.1 71.0
#  40.3 9.2 54.1 64.9 26.8 67.0 75.3 65.9 8.9 13.3 79.9 76.6 66.6 27.0 41.3
#  19.0 10.3 68.7 69.9 16.4 9.8 65.4 38.7 38.2 53.8 45.62 76.22 48.8 21.7
#  48.4 55.5 17.0 55.7 75.6 82.5 23.6 22.6 23.4 38.8 53.3 42.1 43.3 20.5
#  24.0 18.1 44.0 9.0 2.6 33.4 43.7 47.0 47.1 52.5 29.7 50.4 48.2 33.6 42.6
#  47.5 47.3 28.0 45.4 11.0 56.2 7.1 39.2 4.7 28.4 23.7 52.9 22.1 5.7 3.4
#  21.8 61.1 63.6 59.6 64.3 62.8 60.1 7.6 65.6 70.2 3.7 76.2 65.7 7.0 74.8
#  56.1 5.1 47.7 52.2 33.9 19.9 80.0 72.4 77.5 74.6 70.7 81.3 4.0 3.8 77.2
#  79.7 78.9 66.1 62.6 55.9 30.8 11.2 53.0 64.7 67.8 21.2 65.3 69.1 67.1
#  68.4 73.4 27.2 31.1 33.8 19.2 12.5 12.2 12.0 66.2 63.0 14.3 8.5 62.2 58.5
#  14.2 54.3 59.1 81.2 8.6 80.5 86.0 84.2 86.3 4.5 5.6 8.0 44.9 51.4 25.0
#  53.2 31.7 25.7 29.6 66.5 65.0 74.0 50.0 37.0 76.4 44.7 80.2 64.8 81.4
#  50.9 71.3 68.15 63.1 58.3 70.96 73.1 80.4 72.5 75.8 81.7 74.9 77.3 86.4
#  88.3 62.3 82.7 40.0 8.8 30.1 44.1 16.7 15.0 39.1 38.6 72.6 64.6 35.2 46.0
#  40.7 59.3 58.1 74.4 18.9 42.7 34.3 28.6 31.3 61.3 79.0 23.8 50.1 56.8
#  54.8 49.4 50.7 41.7 25.5 48.02 45.9 36.6 70.9 73.0 77.84 32.1 36.3 35.0
#  57.32 66.0 77.4 67.43 69.41 68.46 48.0 51.1 69.8 64.4 69.5 62.5 90.1 67.5
#  81.1 86.2 52.4 57.5 57.1 86.7 70.55 71.37 32.0 31.2 57.2 60.5 57.7 28.8
#  55.4 56.7 71.1 80.7 75.0 72.8 78.8 67.7 59.53 59.0 49.5 72.9 56.9 66.8
#  79.5 81.97 87.2 87.04 76.3 89.1 65.5 71.8 68.0 16.8 71.4 41.6 21.3 21.0
#  35.1 60.9 36.0 59.5 61.9 68.1 67.3 91.4 79.1 81.8 55.6 90.0 74.1 77.32
#  86.5 77.63 71.7 82.6 77.8 78.0 60.3 60.0 79.3 76.5 63.9 76.1 52.1 55.1
#  76.7 80.8 76.8 78.2 78.6 62.0 76.9 70.4 48.7 37.2 40.4 68.9 55.0 56.3
#  73.2 51.99 78.5 87.1 59.4 58.9 84.7 78.3 78.1 45.8 81.6 85.5 69.4 64.0
#  82.4 65.2 82.3 61.5 62.4 73.7 35.5 78.7 54.9 76.0 84.6 39.4 83.7 6.9 77.0
#  67.2 0.4 0.5 10.8 61.2 60.7 13.4 15.3 24.9 54.6 14.8 17.7 6.4 56.6 46.3
#  13.6 74.05 30.5 2.8 44.2 40.1 17.5 0.8 1.0 1.8 36.8 45.7 4.1 34.8 51.0
#  54.2 69.6 53.5 48.6 61.7 47.6 57.0 46.6 64.2 52.8 46.9 50.2 75.5 47.9
#  83.1 63.7 48.5 35.8 33.5 52.3 74.2 60.8 56.4 73.8 65.1 79.8 60.4 83.3
#  81.5 83.2 70.3 79.4 80.6 63.5 85.7 87.0 49.2 56.5 1.6 1.7 0.1]
# Всего строк со значением Нейтрофилы, относительное количество (NE%): 1332

# %%
# Функция для определения нормы NE на основе возраста
def get_ne_otn_norm(age, gender):
    if age <= 1 / 12:  # до 1 месяца
        return '31:55'
    elif 1 / 12 < age <= 1:  # 2–12 месяцев
        return '17:50'
    elif 1 < age <= 5:  # 1–5 лет
        return '30:60'
    elif 5 < age <= 10:  # 5–10 лет
        return '40:62'
    elif 10 < age <= 14:  # 10–14 лет
        return '44:65'
    elif age > 14:  # > 14 лет (взрослые)
        return '47:77'
    else:
        return None  # В случае, если возраст не попадает ни в одну категорию

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Нейтрофилы, относительное количество (NE%)'
ne_otn_mask = df['Кол. лаб. показатель'] == 'Нейтрофилы, относительное количество (NE%)'

# Применяем функцию к нужным строкам и обновляем столбец 'Норма кол. показателя'
df.loc[ne_otn_mask, 'Норма кол. показателя'] = df[ne_otn_mask].apply(lambda row: get_ne_otn_norm(row['Возраст'], row['Пол']), axis=1)

# Проверка результатов
print("Обновленные значения 'Норма кол. показателя' для показателя 'Нейтрофилы, относительное количество (NE%)':")
print(df[ne_otn_mask][['Возраст', 'Пол', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Нейтрофилы, относительное количество (NE%)':
#      Возраст  Пол Норма кол. показателя
# 8         62    0                 47:77
# 28        62    0                 47:77
# 58        62    0                 47:77
# 92        62    0                 47:77
# 120       62    0                 47:77

# %%
norm_info('Нейтрофилы, абсолютное количество (NE#)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Нейтрофилы, абсолютное количество (NE#):
# ['1,5:7' '1,50:7,00' '_' '1,5:7,0']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Нейтрофилы, абсолютное количество (NE#):
# ['10*9/л']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Нейтрофилы, абсолютное количество (NE#):
# [0.5 0.23 0.95 4.25 0.33 2.7 4.2 5.15 4.09 0.66 3.01 13.8 3.6 4.4 3.0 0.4
#  16.6 0.31 6.97 1.13 1.41 0.57 1.1 1.27 1.77 1.3 1.0 1.62 0.55 1.7 2.5 4.1
#  4.3 4.7 3.29 4.06 3.05 0.8 0.76 0.3 2.9 0.2 2.3 0.0 0.25 0.7 0.12 5.22
#  5.8 5.96 0.38 6.53 5.0 0.16 5.3 5.42 4.5 4.04 3.8 3.81 2.06 1.81 2.41 3.4
#  2.33 4.29 6.1 5.79 3.96 5.4 6.7 9.29 1.09 1.46 1.72 4.8 3.12 1.49 4.46
#  3.1 3.2 3.42 6.47 4.0 1.45 2.48 3.9 2.36 6.69 3.54 2.4 4.64 4.27 4.75
#  4.71 3.3 7.15 5.34 5.75 6.04 4.12 3.68 4.77 2.49 6.3 11.1 7.7 4.54 5.02
#  8.2 7.2 11.17 3.82 3.41 6.9 8.28 8.5 3.25 3.87 3.47 8.6 8.0 5.24 4.23
#  2.29 1.51 1.94 0.47 0.97 10.0 12.0 7.8 0.9 1.6 1.8 1.29 0.83 3.17 0.72
#  2.8 5.1 2.99 0.75 0.11 2.74 2.47 0.1 4.6 4.9 3.7 1.16 2.92 1.83 2.81 2.23
#  6.39 3.28 3.21 7.65 6.0 2.1 1.96 5.9 0.6 2.16 2.38 1.4 3.38 6.43 0.69
#  0.67 34.5 0.27 0.45 0.05 0.91 0.54 0.87 0.44 3.27 5.5 6.4 10.6 9.79 7.9
#  8.37 3.08 3.49 9.36 10.66 9.6 7.6 8.8 2.93 9.4 11.76 5.78 8.87 2.19 2.2
#  0.19 2.71 9.5 3.51 0.17 4.28 3.5 5.2 11.2 5.72 0.15 0.08 0.03 4.22 0.07
#  5.7 5.52 0.06 6.2 0.04 2.54 0.02 7.5 11.7 15.11 0.01 4.79 0.13 0.18 3.55
#  0.42 0.37 17.4 6.13 1.88 1.9 0.77 2.15 8.95 0.64 6.5 1.2 5.6 7.0 1.21
#  1.32 1.52 12.8 12.9 1.11 11.4 12.5 12.41 1.74 2.12 0.14 0.22 6.8 1.73
#  1.87 1.67 1.61 0.81 1.5 4.72 5.27 5.93 0.99 12.1 10.9 1.06 7.1 5.88 2.65
#  8.4 6.48 5.73 12.33 10.4 7.01 4.11 6.6 4.85 105.7 10.61 14.27 14.82 24.81
#  65.9 49.69 3.72 48.09 2.98 8.9 9.76 9.72 0.62 0.58 3.23 6.95 9.02 10.89
#  10.3 11.29 8.61 2.6 6.41 5.47 4.55 3.86 1.31 2.0 6.23 13.3 10.62 14.2 7.3
#  14.0 10.59 10.8 0.93 1.59 2.95 3.52 4.05 6.67 3.06 4.67 8.83 9.7 11.91
#  30.9 6.09 6.81 13.97 7.13 25.9 21.94 4.08 2.84 6.29 4.36 26.54 2.96 4.87
#  8.84 4.17 7.4 8.31 11.56 13.0 5.89 10.5 10.1 6.92 3.34 3.79 22.0 5.53 9.2
#  10.2 13.5 18.0 36.3 37.7 32.82 45.3 29.13 5.97 34.76 20.98 33.4 42.4 38.5
#  35.59 44.16 9.0 14.99 15.1 15.8 17.97 5.14 6.33 7.39 5.57 12.51 12.17
#  14.42 8.62 4.07 7.73 2.28 1.15 1.26 8.1 8.24 4.97 6.62 2.79 3.64 23.8
#  5.39 3.95 4.89 3.84 2.13 5.99 8.3 3.73 2.51 4.82 3.88 3.63 6.84 4.44 5.12
#  7.72 7.02 2.57 1.71 1.58 2.14 3.18 4.02 2.62 2.17 2.46 1.84 1.57 7.56
#  4.68 6.17 6.63 10.52 5.49 5.63 5.23 6.94 7.32 7.25 7.89 4.42 15.44 16.16
#  14.51 13.88 6.08 4.03 3.93 3.58 6.02 1.99 8.68 5.71 6.44 6.38 8.15 7.26
#  4.59 7.83 8.66 10.63 9.15 17.83 8.86 12.57 14.13 15.34 12.97 11.12 5.69
#  17.7 18.6 16.3 14.3 13.7 10.7 7.81 6.79 6.59 4.51 6.58 8.56 8.65 10.44
#  11.47 10.38 10.43 4.62 3.85 5.83 5.74 8.19 26.84 21.35 21.5 4.14 5.04
#  10.79 4.19 0.21]
# Всего строк со значением Нейтрофилы, абсолютное количество (NE#): 1319

# %%
# Функция для определения нормы NE# на основе возраста
def get_ne_abs_norm(age, gender):
    if age <= 1 / 12:  # до 1 месяца
        return '1.5:11.5'
    elif 1 / 12 < age <= 1:  # 2–12 месяцев
        return '0.9:8.8'
    elif 1 < age <= 5:  # 1–5 лет
        return '1.5:9.3'
    elif 5 < age <= 10:  # 5–10 лет
        return '1.8:8.1'
    elif 10 < age <= 14:  # 10–14 лет
        return '1.9:7.5'
    elif age > 14:  # > 14 лет (взрослые)
        return '1.8:7.2'
    else:
        return None  # В случае, если возраст не попадает ни в одну категорию

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Нейтрофилы, абсолютное количество (NE#)'
ne_abs_mask = df['Кол. лаб. показатель'] == 'Нейтрофилы, абсолютное количество (NE#)'

# Применяем функцию к нужным строкам и обновляем столбец 'Норма кол. показателя'
df.loc[ne_abs_mask, 'Норма кол. показателя'] = df[ne_abs_mask].apply(lambda row: get_ne_abs_norm(row['Возраст'], row['Пол']), axis=1)

# Проверка результатов
print("Обновленные значения 'Норма кол. показателя' для показателя 'Нейтрофилы, абсолютное количество (NE#)':")
print(df[ne_abs_mask][['Возраст', 'Пол', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Нейтрофилы, абсолютное количество (NE#)':
#      Возраст  Пол Норма кол. показателя
# 10        62    0               1.8:7.2
# 33        62    0               1.8:7.2
# 63        62    0               1.8:7.2
# 87        62    0               1.8:7.2
# 115       62    0               1.8:7.2

# %%
norm_info('Эозинофилы, относительное количество (EO%)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Эозинофилы, относительное количество (EO%):
# ['0:5' '0,0:5,0']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Эозинофилы, относительное количество (EO%):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Эозинофилы, относительное количество (EO%):
# [0.0 0.5 0.4 1.2 0.7 3.0 0.2 0.3 1.9 2.9 2.3 2.6 0.8 1.1 5.0 3.4 3.6 3.3
#  1.3 2.1 1.8 0.6 0.1 1.6 1.0 2.7 2.5 0.9 2.0 1.4 2.8 4.5 1.5 1.7 3.7 2.4
#  3.2 5.3 4.9 8.9 8.7 5.7 3.9 4.0 3.93 0.06 4.4 4.2 8.2 2.2 6.7 3.8 4.8 4.1
#  3.5 3.1 4.6 1.97 2.56 4.7 4.33 2.77 1.85 3.16 1.79 5.1 4.58 3.13 2.36
#  0.35 7.0 4.3 5.6 9.2 10.4 5.9 5.2 7.3 5.5 6.2 1.08 2.34 0.66 0.85 6.1
#  10.9]
# Всего строк со значением Эозинофилы, относительное количество (EO%): 824

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Эозинофилы, относительное количество (EO%)'
eo_otn_mask = df['Кол. лаб. показатель'] == 'Эозинофилы, относительное количество (EO%)'

# Задаем норму '0,8:6,2' для всех выбранных строк
df.loc[eo_otn_mask, 'Норма кол. показателя'] = '0.0:5.0'

# Проверка результата
print("Обновленные значения 'Норма кол. показателя' для показателя 'Эозинофилы, относительное количество (EO%)':")
print(df[eo_otn_mask][['Кол. лаб. показатель', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Эозинофилы, относительное количество (EO%)':
#                            Кол. лаб. показатель Норма кол. показателя
# 31   Эозинофилы, относительное количество (EO%)               0.0:5.0
# 61   Эозинофилы, относительное количество (EO%)               0.0:5.0
# 95   Эозинофилы, относительное количество (EO%)               0.0:5.0
# 123  Эозинофилы, относительное количество (EO%)               0.0:5.0
# 186  Эозинофилы, относительное количество (EO%)               0.0:5.0

# %%
norm_info('Эозинофилы, абсолютное количество (EO#)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Эозинофилы, абсолютное количество (EO#):
# ['0:0,4' '0,00:0,40']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Эозинофилы, абсолютное количество (EO#):
# ['10*9/л']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Эозинофилы, абсолютное количество (EO#):
# [0.0 0.01 0.02 0.03 0.11 0.18 0.07 0.08 0.1 0.14 0.43 0.3 0.34 0.36 0.15
#  0.05 0.09 0.13 0.2 0.04 0.06 0.81 0.12 0.55 0.39 0.16 0.29 0.19 0.21 0.23
#  0.41 0.28 0.32 0.33 0.67 0.71 0.27 0.56 0.47 0.68 0.59 5.09 0.24 0.4 0.22
#  0.17 0.25 0.46 0.9 0.26 0.58 0.49 0.53 0.6 0.7 0.82 2.23 0.84 0.92 0.63
#  0.44 0.37 0.77 0.86 1.16 0.76 0.64 1.62 2.04 2.01 0.31 0.5 0.38 2.0 0.42
#  0.45 0.51 0.57 0.88 0.73 0.93]
# Всего строк со значением Эозинофилы, абсолютное количество (EO#): 739

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Эозинофилы, абсолютное количество (EO#)   '
eo_abs_mask = df['Кол. лаб. показатель'] == 'Эозинофилы, абсолютное количество (EO#)'

# Задаем норму '0,8:6,2' для всех выбранных строк
df.loc[eo_abs_mask, 'Норма кол. показателя'] = '0.00:0.40'

# Проверка результата
print("Обновленные значения 'Норма кол. показателя' для показателя 'Эозинофилы, абсолютное количество (EO#)':")
print(df[eo_abs_mask][['Кол. лаб. показатель', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Эозинофилы, абсолютное количество (EO#)':
#                         Кол. лаб. показатель Норма кол. показателя
# 36   Эозинофилы, абсолютное количество (EO#)             0.00:0.40
# 66   Эозинофилы, абсолютное количество (EO#)             0.00:0.40
# 90   Эозинофилы, абсолютное количество (EO#)             0.00:0.40
# 118  Эозинофилы, абсолютное количество (EO#)             0.00:0.40
# 192  Эозинофилы, абсолютное количество (EO#)             0.00:0.40

# %%
norm_info('Базофилы, относительное количество (BA%)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Базофилы, относительное количество (BA%):
# ['0:2' '0,0:2,0']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Базофилы, относительное количество (BA%):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Базофилы, относительное количество (BA%):
# [1.9 0.5 1.1 3.8 1.8 3.5 0.6 1.5 0.8 0.0 0.1 1.3 2.3 2.4 1.2 0.4 2.6 3.2
#  0.7 4.4 1.4 0.2 3.0 2.7 2.9 0.9 3.3 6.3 6.1 1.0 1.7 2.0 2.8 5.2 2.1 2.2
#  4.8 0.73 0.53 0.3 13.7 7.6 4.5 9.6 3.9 1.6 7.2 4.0 5.03 2.76 2.5 3.7 3.6
#  6.54 1.03 0.92 1.46 1.28 8.4 8.5 7.9 8.3 3.1 4.2 1.23 0.79 0.51 0.69 0.63
#  3.4 7.66 5.1 3.09 4.3 4.6 6.4 5.3]
# Всего строк со значением Базофилы, относительное количество (BA%): 822

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Эозинофилы, относительное количество (EO%)'
baz_otn_mask = df['Кол. лаб. показатель'] == 'Базофилы, относительное количество (BA%)'

# Задаем норму '0,8:6,2' для всех выбранных строк
df.loc[baz_otn_mask, 'Норма кол. показателя'] = '0.0:2.0'

# Проверка результата
print("Обновленные значения 'Норма кол. показателя' для показателя 'Базофилы, относительное количество (BA%)':")
print(df[baz_otn_mask][['Кол. лаб. показатель', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Базофилы, относительное количество (BA%)':
#                          Кол. лаб. показатель Норма кол. показателя
# 32   Базофилы, относительное количество (BA%)               0.0:2.0
# 62   Базофилы, относительное количество (BA%)               0.0:2.0
# 96   Базофилы, относительное количество (BA%)               0.0:2.0
# 124  Базофилы, относительное количество (BA%)               0.0:2.0
# 187  Базофилы, относительное количество (BA%)               0.0:2.0

# %%
norm_info('Базофилы, абсолютное количество (BA#)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Базофилы, абсолютное количество (BA#):
# ['0:0,1' '0,00:0,10' '0:0.1']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Базофилы, абсолютное количество (BA#):
# ['10*9/л']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Базофилы, абсолютное количество (BA#):
# [0.02 0.01 0.05 0.06 0.12 0.09 0.2 0.07 0.0 0.03 0.15 0.1 0.46 0.14 0.13
#  0.24 0.08 0.04 0.11 0.43 2.64 0.5 0.4 0.58 0.26 1.14 0.21 0.35 0.34 0.48
#  0.39 3.42 0.16 0.18 0.22 0.31 0.52 0.23 0.27 0.19 0.72 0.3 0.53 0.81 9.9
#  1.45 1.67 1.8 1.07 2.45 2.43 2.03 0.38 0.41 0.29 0.32 0.44 0.42 0.51 0.17
#  0.82 1.39 0.92 1.1 0.99 7.0 0.76 1.0 8.6 4.0 0.6 0.8 1.4 0.36 0.25 0.28
#  0.33 0.37 0.69 0.45 0.68 0.66]
# Всего строк со значением Базофилы, абсолютное количество (BA#): 732

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Базофилы, абсолютное количество (BA#)  '
baz_abs_mask = df['Кол. лаб. показатель'] == 'Базофилы, абсолютное количество (BA#)'

# Задаем норму '0,8:6,2' для всех выбранных строк
df.loc[baz_abs_mask, 'Норма кол. показателя'] = '0.00:0.10'

# Проверка результата
print("Обновленные значения 'Норма кол. показателя' для показателя 'Базофилы, абсолютное количество (BA#)':")
print(df[baz_abs_mask][['Кол. лаб. показатель', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Базофилы, абсолютное количество (BA#)':
#                       Кол. лаб. показатель Норма кол. показателя
# 37   Базофилы, абсолютное количество (BA#)             0.00:0.10
# 67   Базофилы, абсолютное количество (BA#)             0.00:0.10
# 91   Базофилы, абсолютное количество (BA#)             0.00:0.10
# 119  Базофилы, абсолютное количество (BA#)             0.00:0.10
# 193  Базофилы, абсолютное количество (BA#)             0.00:0.10

# %%
norm_info('Моноциты, относительное количество (MO%)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Моноциты, относительное количество (MO%):
# ['2:12' '2,0:12,0' '2,0:12,0 ']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Моноциты, относительное количество (MO%):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Моноциты, относительное количество (MO%):
# [22.4 15.9 4.7 16.9 10.9 12.8 16.7 17.7 10.4 2.2 53.7 21.5 13.8 73.3 73.2
#  21.0 5.6 5.3 5.0 31.1 14.9 18.9 19.4 0.0 1.7 10.6 8.4 5.2 6.2 14.1 13.1
#  11.3 10.1 9.6 9.9 3.4 7.1 7.0 1.8 3.0 9.7 11.7 9.0 12.2 26.9 24.1 3.5
#  28.3 21.8 1.6 2.0 39.6 6.4 22.0 16.8 14.2 3.7 4.3 4.9 4.4 4.0 9.2 3.8 4.2
#  7.5 3.6 8.1 4.6 9.3 5.1 2.6 3.1 10.0 8.8 15.3 15.6 0.9 11.2 2.1 5.5 1.0
#  4.5 7.8 9.1 6.0 3.9 5.4 2.9 6.6 10.5 4.69 6.5 2.7 2.8 35.1 32.1 66.1 39.5
#  20.1 29.1 33.8 14.8 13.2 31.6 11.5 13.3 22.8 34.0 41.8 16.0 26.2 48.8 2.3
#  5.9 1.5 13.7 11.4 12.5 34.8 37.7 11.8 7.4 81.4 84.3 81.8 6.7 8.3 14.6
#  12.9 7.7 15.1 9.5 8.5 9.4 6.1 5.7 2.4 29.3 10.7 15.4 17.1 14.3 15.2 8.03
#  9.99 3.3 4.8 6.8 6.3 8.0 54.7 13.9 8.2 38.2 34.9 30.95 18.2 2.67 1.9 0.7
#  4.51 3.96 8.57 10.2 12.0 14.5 7.2 10.8 7.9 49.2 2.06 1.96 18.0 40.2 56.3
#  17.8 21.3 24.4 13.99 14.0 14.4 4.1 2.74 1.48 2.5 18.4 13.6 8.7 1.64 1.2
#  7.6 3.2 22.7 8.9 7.3 12.1 9.8 11.17 15.5 23.3 11.0 13.0 5.8 6.9 20.0 18.5
#  11.6 17.0 12.3 27.6 24.8 26.4 54.1 9.19 64.7 60.0 16.3 0.6 17.2 1.4 23.8
#  12.4 20.8 0.4 19.1 20.7 0.3 19.7 19.8 28.0 19.3 11.9 25.5 28.8 0.8 31.0
#  17.6 8.6 20.9 18.7 31.7 57.3 79.8 66.5 63.0]
# Всего строк со значением Моноциты, относительное количество (MO%): 815

# %%
# Функция для определения нормы относительного количества моноцитов на основе возраста
def get_mono_otn_norm(age):
    if age <= 1 / 12:  # до 1 месяца
        return '5:15'
    elif 1 / 12 < age <= 1:  # 2–12 месяцев
        return '4:10'
    elif 1 < age <= 14:  # 1–14 лет
        return '3:11'
    elif age > 14:  # > 14 лет (взрослые)
        return '2:12'
    else:
        return None  # В случае, если возраст не попадает ни в одну категорию

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Моноциты, относительное количество (MO%))'
mono_otn_mask = df['Кол. лаб. показатель'] == 'Моноциты, относительное количество (MO%)'

# Применяем функцию к нужным строкам и обновляем столбец 'Норма кол. показателя'
df.loc[mono_otn_mask, 'Норма кол. показателя'] = df[mono_otn_mask].apply(lambda row: get_mono_otn_norm(row['Возраст']), axis=1)

# Проверка результатов
print("Обновленные значения 'Норма кол. показателя' для показателя 'Моноциты, относительное количество (MO%)':")
print(df[mono_otn_mask][['Возраст', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Моноциты, относительное количество (MO%)':
#      Возраст Норма кол. показателя
# 30        62                  2:12
# 60        62                  2:12
# 94        62                  2:12
# 122       62                  2:12
# 185       85                  2:12

# %%
norm_info('Моноциты, абсолютное количество (MO#)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Моноциты, абсолютное количество (MO#):
# ['0,1:0,7' '0,10:0,70' '0:0,7']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Моноциты, абсолютное количество (MO#):
# ['10*9/л']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Моноциты, абсолютное количество (MO#):
# [0.24 0.3 0.23 0.28 0.72 0.73 0.27 0.89 0.14 0.2 0.19 7.99 0.59 0.32 30.48
#  20.0 0.8 0.29 0.33 1.44 0.25 0.66 0.22 0.0 0.02 0.1 0.5 0.58 0.21 1.36
#  0.08 1.06 0.81 0.69 1.13 1.11 0.34 0.6 0.71 0.92 1.56 0.75 0.78 1.01 0.15
#  42.8 0.18 0.26 1.52 0.77 6.2 0.42 0.53 0.52 0.45 0.4 0.41 0.56 0.36 0.17
#  0.39 1.9 0.35 0.31 1.18 0.49 0.37 1.03 0.44 0.76 0.01 0.06 0.03 0.46 0.55
#  0.43 0.07 0.47 1.42 2.67 15.01 2.53 0.54 0.91 1.96 6.43 0.16 23.98 0.74
#  4.56 5.31 7.24 1.93 1.32 0.68 2.54 1.79 1.38 1.49 239.93 130.69 177.84
#  0.12 0.09 0.11 0.7 1.0 0.13 2.3 0.05 0.84 0.04 0.79 1.02 2.9 1.2 1.1 0.85
#  0.98 3.92 3.67 3.82 0.9 0.38 0.65 1.28 7.42 5.3 1.23 0.94 0.99 3.81 6.8
#  4.16 0.86 15.77 0.61 0.63 1.51 1.21 1.15 1.7 1.6 1.64 1.46 1.34 1.72 0.64
#  2.7 1.5 1.19 1.3 2.0 2.31 3.24 5.91 2.23 4.91 3.32 6.0 1.47 1.25 0.87
#  0.57 1.09 1.4 0.82 0.96 8.4 3.6 4.1 9.8 12.5 12.1 2.59 1.88 2.18 6.45 7.8
#  11.7 2.01 1.83 2.35 1.43 1.92 0.95 3.97 0.62 1.04 2.78 3.68 0.48 2.65
#  4.57 0.97 1.35 1.16 3.78 6.17 1.39 3.85 1.91 3.69 3.06 2.51 6.34 1.81
#  6.19 10.99 4.98]
# Всего строк со значением Моноциты, абсолютное количество (MO#): 784

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Моноциты, абсолютное количество (MO#)'
mono_abs_mask = df['Кол. лаб. показатель'] == 'Моноциты, абсолютное количество (MO#)'

# Задаем норму '0,8:6,2' для всех выбранных строк
df.loc[mono_abs_mask, 'Норма кол. показателя'] = '0.10:0.70'

# Проверка результата
print("Обновленные значения 'Норма кол. показателя' для показателя 'Моноциты, абсолютное количество (MO#)':")
print(df[mono_abs_mask][['Кол. лаб. показатель', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Моноциты, абсолютное количество (MO#)':
#                       Кол. лаб. показатель Норма кол. показателя
# 35   Моноциты, абсолютное количество (MO#)             0.10:0.70
# 65   Моноциты, абсолютное количество (MO#)             0.10:0.70
# 89   Моноциты, абсолютное количество (MO#)             0.10:0.70
# 117  Моноциты, абсолютное количество (MO#)             0.10:0.70
# 191  Моноциты, абсолютное количество (MO#)             0.10:0.70

# %%
norm_info('СОЭ по Вестергрену')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя СОЭ по Вестергрену:
# ['2:20' 'Общая норма' nan]
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя СОЭ по Вестергрену:
# ['мм/час']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя СОЭ по Вестергрену:
# [87.0 88.0 112.0 52.0 44.0 100.0 18.0 96.0 3.0 140.0 107.0 72.0 120.0 29.0
#  70.0 91.0 40.0 79.0 130.0 118.0 80.0 74.0 2.0 10.0 78.0 20.0 8.0 4.0 31.0
#  5.0 33.0 16.0 21.0 9.0 6.0 43.0 19.0 75.0 14.0 42.0 51.0 50.0 41.0 32.0
#  30.0 28.0 47.0 24.0 45.0 22.0 13.0 26.0 25.0 11.0 23.0 101.0 105.0 110.0
#  17.0 38.0 39.0 60.0 7.0 137.0 115.0 121.0 139.0 131.0 12.0 102.0 48.0
#  81.0 138.0 36.0 113.0 86.0 15.0 63.0 66.0 58.0 55.0 64.0 59.0 62.0 104.0
#  67.0 68.0 73.0 84.0 61.0 56.0 35.0 46.0 57.0 65.0 94.0 92.0 53.0 69.0
#  83.0 85.0 129.0 127.0 106.0 98.0 111.0 27.0 34.0 77.0]
# Всего строк со значением СОЭ по Вестергрену: 569

# %%
# Функция для определения нормы СОЭ по Вестергрену на основе возраста и пола
def get_soe_norm(age, gender):
    if age < 10:  # Дети до 10 лет
        return '2:10'
    elif gender == 1:  # Мужчины
        if age < 50:
            return '1:15'
        else:
            return '2:20'
    elif gender == 0:  # Женщины
        if age < 50:
            return '2:20'
        else:
            return '2:30'
    else:
        return None  # В случае, если возраст или пол не указаны

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'СОЭ по Вестергрену'
soe_mask = df['Кол. лаб. показатель'] == 'СОЭ по Вестергрену'

# Применяем функцию к нужным строкам и обновляем столбец 'Норма кол. показателя'
df.loc[soe_mask, 'Норма кол. показателя'] = df[soe_mask].apply(lambda row: get_soe_norm(row['Возраст'], row['Пол']), axis=1)

# Проверка результатов
print("Обновленные значения 'Норма кол. показателя' для показателя 'СОЭ по Вестергрену':")
print(df[soe_mask][['Возраст', 'Пол', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'СОЭ по Вестергрену':
#      Возраст  Пол Норма кол. показателя
# 39        62    0                  2:30
# 69        62    0                  2:30
# 98        62    0                  2:30
# 126       62    0                  2:30
# 196       85    0                  2:30

# %%
norm_info('Сегментоядерные нейтрофилы (%)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Сегментоядерные нейтрофилы (%):
# ['45:72']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Сегментоядерные нейтрофилы (%):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Сегментоядерные нейтрофилы (%):
# [20.0 50.0 90.0 18.0 59.0 54.0 22.0 76.0 6.0 24.0 39.0 3.0 17.0 57.0 67.0
#  62.0 25.0 32.0 13.0 28.0 55.0 56.0 15.0 64.0 14.0 52.0 61.0 60.0 49.0
#  27.0 11.0 65.0 51.0 72.0 5.0 26.0 45.0 10.0 41.0 43.0 36.0 81.0 48.0 30.0
#  79.0 73.0 35.0 38.0 68.0 77.0 7.0 4.0 12.0 58.0 52.5 37.0 71.0 46.0 8.0
#  84.0 23.0 9.0 1.0 0.0 19.0 47.0 75.0 21.0 40.0 16.0 80.0 4.5 29.0 63.0
#  86.0 70.0 69.0 34.0 42.0 44.0 31.0 74.0 33.0 78.0 53.0 66.0 33.5 36.5
#  85.0 88.0 87.0 82.0 58.5 65.5 71.5 39.5 1.5 83.0 2.0 89.0]
# Всего строк со значением Сегментоядерные нейтрофилы (%): 740

# %%
# Норма взята с сайта: https://gemotest.ru/info/spravochnik/analizy/neytrofily/

def get_segmented_neutrophils_norm(age):
    """Возвращает норму сегментоядерных нейтрофилов в зависимости от возраста и пола."""
    if age < 16:
        # Норма для детей до 16 лет
        if 0 <= age <= 13 / 365:  # до 13 дней
            return "17:39"
        elif age < 1:  # дети до 1 года
            return "30:50"
        elif age < 2:  # дети 1 год 
            return "23:43"
        elif age < 3:  # дети 2 лет
            return "28:48"
        elif 2 < age < 5:  # дети 3-4 лет
            return "32:54"
        elif 4 < age < 8:  # дети 5-7 лет
            return "35:58"
        elif 7 < age < 12:  # дети 8-11 лет 
            return "41:59"
        else:  # все дети до 16 лет
            return "44:61"
    else: # норма для всех взрослых и детей старше 16
        return "47:72"

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'СОЭ по Вестергрену'
segmented_neutrophils_mask = df['Кол. лаб. показатель'] == 'Сегментоядерные нейтрофилы (%)'

# Применяем функцию к нужным строкам и обновляем столбец 'Норма кол. показателя'
df.loc[segmented_neutrophils_mask, 'Норма кол. показателя'] = df[segmented_neutrophils_mask].apply(lambda row: get_segmented_neutrophils_norm(row['Возраст']), axis=1)

# Проверка результатов
print("Обновленные значения 'Норма кол. показателя' для показателя 'Сегментоядерные нейтрофилы (%)':")
print(df[segmented_neutrophils_mask][['Возраст', 'Пол', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Сегментоядерные нейтрофилы (%)':
#      Возраст  Пол Норма кол. показателя
# 41        62    0                 47:72
# 71        62    0                 47:72
# 100       62    0                 47:72
# 128       62    0                 47:72
# 200       85    0                 47:72

# %%
norm_info('Палочкоядерные нейтрофилы (%)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Палочкоядерные нейтрофилы (%):
# ['1:6']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Палочкоядерные нейтрофилы (%):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Палочкоядерные нейтрофилы (%):
# [3.0 1.0 0.0 18.0 10.0 5.0 2.0 9.0 4.0 12.0 7.0 6.0 11.0 13.0 8.0 19.0
#  17.0 15.0 14.0 16.0 25.0 23.0 20.0 30.0 3.5 8.5 4.5 1.5 22.0 27.0 11.5
#  10.5 0.2 0.7 0.5]
# Всего строк со значением Палочкоядерные нейтрофилы (%): 736

# %%
norm_info('Лимфоциты (лейкоцитарная формула, %)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Лимфоциты (лейкоцитарная формула, %):
# ['18:44']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Лимфоциты (лейкоцитарная формула, %):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Лимфоциты (лейкоцитарная формула, %):
# [64.0 34.0 6.0 58.0 9.0 43.0 22.0 15.0 18.0 25.0 16.0 56.0 32.0 91.0 80.0
#  63.0 31.0 40.0 49.0 23.0 50.0 66.0 28.0 35.0 62.0 29.0 21.0 75.0 30.0
#  65.0 83.0 5.0 13.0 20.0 17.0 86.0 41.0 33.0 82.0 51.0 45.0 36.0 54.0 37.0
#  53.0 19.0 7.0 55.0 10.0 42.0 59.0 47.0 94.0 85.0 27.0 14.5 88.0 14.0 81.0
#  95.0 24.0 39.0 93.0 87.0 68.0 90.0 44.0 79.0 89.0 77.0 98.0 100.0 11.0
#  94.5 12.0 1.0 3.0 2.0 74.0 67.0 60.0 38.0 8.0 26.0 11.5 46.0 52.0 40.5
#  22.5 6.5 57.0 4.0 13.5 2.5 70.0 41.9 20.5 48.0]
# Всего строк со значением Лимфоциты (лейкоцитарная формула, %): 743

# %%
norm_info('Пролимфоциты (лейкоцитарная формула, %)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Пролимфоциты (лейкоцитарная формула, %):
# ['0:0']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Пролимфоциты (лейкоцитарная формула, %):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Пролимфоциты (лейкоцитарная формула, %):
# [2.0 1.0 0.0 12.0]
# Всего строк со значением Пролимфоциты (лейкоцитарная формула, %): 16

# %%
norm_info('Миелоциты (лейкоцитарная формула, %)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Миелоциты (лейкоцитарная формула, %):
# ['0:0']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Миелоциты (лейкоцитарная формула, %):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Миелоциты (лейкоцитарная формула, %):
# [4.0 5.0 2.0 1.0 8.0 6.0 12.0 3.0 4.5 9.0 7.0 3.5 10.0 13.0 10.5 14.0 0.0
#  7.5 5.5 11.0 1.5 0.5 16.0 20.0 18.0 35.0 6.5 14.5 0.3 15.0 19.0]
# Всего строк со значением Миелоциты (лейкоцитарная формула, %): 316

# %%
norm_info('Промиелоциты (лейкоцитарная формула, %)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Промиелоциты (лейкоцитарная формула, %):
# ['0:0']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Промиелоциты (лейкоцитарная формула, %):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Промиелоциты (лейкоцитарная формула, %):
# [0.0 1.0]
# Всего строк со значением Промиелоциты (лейкоцитарная формула, %): 21

# %%
norm_info('Моноциты (лейкоцитарная формула, %)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Моноциты (лейкоцитарная формула, %):
# ['2:12' '2:10']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Моноциты (лейкоцитарная формула, %):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Моноциты (лейкоцитарная формула, %):
# [2.0 9.0 3.0 4.0 6.0 11.0 7.0 34.0 14.0 8.0 10.0 5.0 18.0 24.0 1.0 28.0
#  23.0 16.0 19.0 13.0 0.0 12.0 38.0 35.0 46.0 15.0 45.0 21.0 26.0 17.0 50.0
#  31.0 44.0 5.5 27.0 20.0 52.0 32.0 10.5 41.0 54.0 56.0 37.0 9.5 25.0 6.5
#  7.5 3.5 36.0 43.0 0.5 49.0 40.0 55.0 63.5 22.0]
# Всего строк со значением Моноциты (лейкоцитарная формула, %): 734

# %%
# Создаем маску для строк, где 'Кол. лаб. показатель' равен 'Моноциты (лейкоцитарная формула, %)'
leico_mono_mask = df['Кол. лаб. показатель'] == 'Моноциты (лейкоцитарная формула, %)'

# Задаем норму '0,8:6,2' для всех выбранных строк
df.loc[leico_mono_mask, 'Норма кол. показателя'] = '2:12'

# Проверка результата
print("Обновленные значения 'Норма кол. показателя' для показателя 'Моноциты (лейкоцитарная формула, %)':")
print(df[leico_mono_mask][['Кол. лаб. показатель', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Моноциты (лейкоцитарная формула, %)':
#                     Кол. лаб. показатель Норма кол. показателя
# 44   Моноциты (лейкоцитарная формула, %)                  2:12
# 74   Моноциты (лейкоцитарная формула, %)                  2:12
# 103  Моноциты (лейкоцитарная формула, %)                  2:12
# 132  Моноциты (лейкоцитарная формула, %)                  2:12
# 204  Моноциты (лейкоцитарная формула, %)                  2:12

# %%
norm_info('Эозинофилы (лейкоцитарная формула, %)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Эозинофилы (лейкоцитарная формула, %):
# ['0:5']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Эозинофилы (лейкоцитарная формула, %):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Эозинофилы (лейкоцитарная формула, %):
# [0.0 2.0 1.0 3.0 4.0 6.0 7.0 5.0 8.0 13.0 0.5 2.5 0.2 12.0 22.0]
# Всего строк со значением Эозинофилы (лейкоцитарная формула, %): 649

# %%
norm_info('Базофилы (лейкоцитарная формула, %)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Базофилы (лейкоцитарная формула, %):
# ['0:2']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Базофилы (лейкоцитарная формула, %):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Базофилы (лейкоцитарная формула, %):
# [2.0 1.0 4.0 0.0 5.0 3.0 13.0 11.0 8.0 5.5 0.5 4.5 1.5]
# Всего строк со значением Базофилы (лейкоцитарная формула, %): 355

# %%
norm_info('Ретикулоциты, абсолютное количество (#)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Ретикулоциты, абсолютное количество (#):
# ['17:70' '0,2:2,0' '0,2:2' '17:63,8']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Ретикулоциты, абсолютное количество (#):
# ['10*9/л' '%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Ретикулоциты, абсолютное количество (#):
# [21.1 61.0 92.3 2.99 86.4 3.51 103.5 2.88 81.8 33.6 1.7 34.3 14.5 0.94
#  28.7 86.8 186.6 48.8 0.24 6.8 58.3 125.5 107.0 11.8 10.0 29.0 2.79 71.1
#  128.0 114.9 74.4 157.6 180.2 107.9 103.6 1.34 45.6 3.7 68.8 1.2 24.8 3.02
#  123.2 0.7 0.4 0.1 3.81 134.9 3.88 83.0]
# Всего строк со значением Ретикулоциты, абсолютное количество (#): 71

# %% [markdown]
# В некоторых столбцах с пометкой Ретикулоциты, абсолютное количество (#) попали относительные значения, измеряемые в процентах. Такие результаты показателей нужно отнести к категории 'Ретикулоциты, относительное количество (%)'

# %%
# Смотрим, сколько всего таких значений
print('Всего таких строк')
print(df[(df['Кол. лаб. показатель'] == 'Ретикулоциты, абсолютное количество (#)')
    & (df['Ед. изм. кол. показателя'] == '%')].shape[0])
display(df[(df['Кол. лаб. показатель'] == 'Ретикулоциты, абсолютное количество (#)')
    & (df['Ед. изм. кол. показателя'] == '%')].head())
# Out:
# Всего таких строк
# 27
#                         ID истории болезни  \
# 4182  a6aad3bc-8f5f-11ee-ab6f-0050568844e6
# 4208  a6aad3bc-8f5f-11ee-ab6f-0050568844e6
# 4270  3047e21e-6655-11ed-ab5f-0050568844e6
# 6551  4e40fb46-536e-11ed-ab5a-0050568844e6
# 8862  3e9fae92-1fba-11ee-ab69-0050568844e6
#
#      Осн. диаг. при выписке МКБ10 (текст)  \
# 4182     Хронический лимфоцитарный лейкоз
# 4208     Хронический лимфоцитарный лейкоз
# 4270             Волосатоклеточный лейкоз
# 6551             Другой уточненный лейкоз
# 8862             Другой уточненный лейкоз
#
#                          Кол. лаб. показатель Значение кол. показателя  \
# 4182  Ретикулоциты, абсолютное количество (#)                     2.99
# 4208  Ретикулоциты, абсолютное количество (#)                     3.51
# 4270  Ретикулоциты, абсолютное количество (#)                     2.88
# 6551  Ретикулоциты, абсолютное количество (#)                      1.7
# 8862  Ретикулоциты, абсолютное количество (#)                     0.94
#
#      Ед. изм. кол. показателя Норма кол. показателя  \
# 4182                        %               0,2:2,0
# 4208                        %                 0,2:2
# 4270                        %                 0,2:2
# 6551                        %                 0,2:2
# 8862                        %                 0,2:2
#
#      Флаг нормы кол. показателя Кач. лаб. показатель  \
# 4182                      Повыш                  NaN
# 4208                      Повыш                  NaN
# 4270                      Повыш                  NaN
# 6551                       Норм          Комментарий
# 8862                       Норм                  NaN
#
#                          Значение кач. показателя Норма кач. показателя  Пол  \
# 4182                                          NaN                   NaN    1
# 4208                                          NaN                   NaN    1
# 4270                                          NaN                   NaN    1
# 6551  среди моноцитоидных элементов 2 промоноцита                     _    1
# 8862                                          NaN                   NaN    0
#
#       Возраст
# 4182       82
# 4208       82
# 4270       73
# 6551       66
# 8862       85

# %%
# Условия для замены значений
condition = (df['Кол. лаб. показатель'] == 'Ретикулоциты, абсолютное количество (#)') & (df['Ед. изм. кол. показателя'] == '%')

# Замена значений в столбце 'Кол. лаб. показатель'
df.loc[condition, 'Кол. лаб. показатель'] = 'Ретикулоциты, относительное количество (%)'

# Проверка изменений
print("Проверем, сколько остлось таких неправильных значений после очистки")
print(df[(df['Кол. лаб. показатель'] == 'Ретикулоциты, абсолютное количество (#)')
    & (df['Ед. изм. кол. показателя'] == '%')].shape[0])
# Out:
# Проверем, сколько остлось таких неправильных значений после очистки
# 0

# %%
# Функция для определения нормы 'Ретикулоциты, абсолютное количество (#)' на основе возраста и пола
def get_retic_abs_norm(age, gender):
    if gender == 0:  # Женский
        if age < 2 / 52:  # Меньше 2 недель
            return '0.15:1.5'
        elif 2 / 52 <= age < 1 / 12:  # 2 недели – 1 месяц
            return '0.45:1.4'
        elif 1 / 12 <= age < 2 / 12:  # 1–2 месяца
            return '0.45:2.1'
        elif 2 / 12 <= age < 6 / 12:  # 2–6 месяцев
            return '0.25:0.9'
        elif 6 / 12 <= age < 2:  # 6 месяцев – 2 года
            return '0.2:1'
        elif 2 <= age < 6:  # 2–6 лет
            return '0.2:0.7'
        elif 6 <= age < 12:  # 6–12 лет
            return '0.2:1.3'
        elif 12 <= age < 18:  # 12–18 лет
            return '0.12:2.05'
        elif age >= 18:  # Больше 18 лет
            return '0.59:2.07'
    elif gender == 1:  # Мужской
        if age < 2 / 52:  # Меньше 2 недель
            return '0.15:1.5'
        elif 2 / 52 <= age < 1 / 12:  # 2 недели – 1 месяц
            return '0.45:1.4'
        elif 1 / 12 <= age < 2 / 12:  # 1–2 месяца
            return '0.45:2.1'
        elif 2 / 12 <= age < 6 / 12:  # 2–6 месяцев
            return '0.25:0.9'
        elif 6 / 12 <= age < 2:  # 6 месяцев – 2 года
            return '0.2:1'
        elif 2 <= age < 6:  # 2–6 лет
            return '0.2:0.7'
        elif 6 <= age < 12:  # 6–12 лет
            return '0.2:1.3'
        elif 12 <= age < 18:  # 12–18 лет
            return '0.24:1.7'
        elif age >= 18:  # Больше 18 лет
            return '0.67:1.92'
    return None  # Если возраст или пол не попадают ни в одну категорию

# %%
# Маска для строк с показателем 'Ретикулоциты, абсолютное количество (#)'
retic_abs_mask = df['Кол. лаб. показатель'] == 'Ретикулоциты, абсолютное количество (#)'

# Применяем функцию к нужным строкам и обновляем столбец 'Норма кол. показателя'
df.loc[retic_abs_mask, 'Норма кол. показателя'] = df[retic_abs_mask].apply(
    lambda row: get_retic_abs_norm(row['Возраст'], row['Пол']), axis=1
)

# Проверка результатов
print("Обновленные значения 'Норма кол. показателя' для показателя 'Ретикулоциты, абсолютное количество (#)':")
print(df[retic_abs_mask][['Возраст', 'Пол', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Ретикулоциты, абсолютное количество (#)':
#       Возраст  Пол Норма кол. показателя
# 632        62    0             0.59:2.07
# 1756       62    0             0.59:2.07
# 3737       85    0             0.59:2.07
# 4183       82    1             0.67:1.92
# 4209       82    1             0.67:1.92

# %%
norm_info('Ретикулоциты, относительное количество (%)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Ретикулоциты, относительное количество (%):
# ['0,2:2' '0,2:2,0' '0,59:2,07' '0,2:1,2']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Ретикулоциты, относительное количество (%):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Ретикулоциты, относительное количество (%):
# [1.11 1.18 3.26 2.99 3.51 2.88 1.82 1.7 0.75 0.94 3.46 7.08 2.19 0.24 3.02
#  2.67 0.58 0.55 0.99 0.0 2.79 1.61 1.55 3.98 0.36 3.78 4.21 2.55 3.69 0.98
#  3.5 5.06 3.53 3.94 1.34 3.7 1.67 1.2 0.7 0.4 0.1 3.81 3.88]
# Всего строк со значением Ретикулоциты, относительное количество (%): 57

# %%
# Функция для определения нормы "Ретикулоциты, относительное количество (%)" на основе возраста и пола
def get_retic_otn_norm(gender):
    if gender == 0:  # Женский
        return '3:15.9'
    elif gender == 1:  # Мужской
        return '2.3:13.4'
    else:
        return None  # Если возраст или пол не попадают ни в одну категорию

# %%
# Маска для строк с показателем "Ретикулоциты, относительное количество (%)"
retic_otn_mask = df['Кол. лаб. показатель'] == 'Ретикулоциты, относительное количество (%)'

# Применяем функцию к нужным строкам и обновляем столбец 'Норма кол. показателя'
df.loc[retic_otn_mask, 'Норма кол. показателя'] = df[retic_otn_mask].apply(
    lambda row: get_retic_otn_norm(row['Пол']), axis=1
)

# Проверка результатов
print("Обновленные значения 'Норма кол. показателя' для показателя 'Ретикулоциты, относительное количество (%)':")
print(df[retic_otn_mask][['Возраст', 'Пол', 'Норма кол. показателя']].head())
# Out:
# Обновленные значения 'Норма кол. показателя' для показателя 'Ретикулоциты, относительное количество (%)':
#       Возраст  Пол Норма кол. показателя
# 631        62    0                3:15.9
# 1755       62    0                3:15.9
# 3712       85    0                3:15.9
# 4182       82    1              2.3:13.4
# 4208       82    1              2.3:13.4

# %%
norm_info('Нормобласты, относительное количество (%)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Нормобласты, относительное количество (%):
# ['_']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Нормобласты, относительное количество (%):
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Нормобласты, относительное количество (%):
# [0.0]
# Всего строк со значением Нормобласты, относительное количество (%): 18

# %% [markdown]
# Нормобласты не информативный признак, так как он везде равен 0

# %%
# Удаляем строки, где 'Кол. лаб. показатель' равен 'Нормобласты, относительное количество (%)'
df = df[df['Кол. лаб. показатель'] != 'Нормобласты, относительное количество (%)']

# Проверяем, что строки успешно удалены
print("Строки с показателем 'Нормобласты, относительное количество (%)' удалены.")
# Out:
# Строки с показателем 'Нормобласты, относительное количество (%)' удалены.

# %%
norm_info('Нормобласты, абсолютное количество (#)')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Нормобласты, абсолютное количество (#):
# ['_']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Нормобласты, абсолютное количество (#):
# ['10*9/л']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Нормобласты, абсолютное количество (#):
# [0.0]
# Всего строк со значением Нормобласты, абсолютное количество (#): 18

# %%
# Удаляем строки, где 'Кол. лаб. показатель' равен 'Нормобласты, абсолютное количество (#)'
df = df[df['Кол. лаб. показатель'] != 'Нормобласты, абсолютное количество (#)']

# Проверяем, что строки успешно удалены
print("Строки с показателем 'Нормобласты, абсолютное количество (#)' удалены.")
# Out:
# Строки с показателем 'Нормобласты, абсолютное количество (#)' удалены.

# %%
norm_info('Нормобласты')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Нормобласты:
# ['0:2' '0:1']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Нормобласты:
# ['_']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Нормобласты:
# [7.0 2.0 1.0 42.0 11.0 4.0 6.0 5.0 8.0 12.0 14.0 3.0 20.0 21.0 13.0 0.0
#  10.0 18.0 61.0 104.0 27.0]
# Всего строк со значением Нормобласты: 174

# %%
# Заменяем значения в столбце 'Норма кол. показателя' на '0:2' для строк, где 'Кол. лаб. показатель' == 'Нормобласты'
df.loc[df['Кол. лаб. показатель'] == 'Нормобласты', 'Норма кол. показателя'] = '0:2'

# Переименовываем 'Нормобласты' в 'Кол. лаб. показатель' на 'Нормобласты, абсолютное значение'
df.loc[df['Кол. лаб. показатель'] == 'Нормобласты', 'Кол. лаб. показатель'] = 'Нормобласты, абсолютное значение'

# Задаем значение в 'Ед. изм. кол. показателя' у показателя 'Нормобласты, абсолютное значение'
df.loc[df['Кол. лаб. показатель'] == 'Нормобласты, абсолютное значение', 'Ед. изм. кол. показателя'] = 'кл/100 лейкоцитов'

# Проверка изменений
print(f"Количество строк со значением Нормобласты: {df[df['Кол. лаб. показатель'] == 'Нормобласты'].shape[0]}")
df[df['Кол. лаб. показатель'] == 'Нормобласты, абсолютное значение'].head()
# Out:
# Количество строк со значением Нормобласты: 0
#                         ID истории болезни  \
# 317   24612d4d-c466-11ec-ab54-0050568844e6
# 1789  86475e95-6a40-11ed-ab5f-0050568844e6
# 1868  eb8b7ced-2860-11ed-ab56-0050568844e6
# 2061  c6ecb784-05e2-11ee-8604-005056880ecb
# 2293  6020d71a-e34f-11ed-ab67-0050568844e6
#
#      Осн. диаг. при выписке МКБ10 (текст)              Кол. лаб. показатель  \
# 317              Другой уточненный лейкоз  Нормобласты, абсолютное значение
# 1789             Другой уточненный лейкоз  Нормобласты, абсолютное значение
# 1868          Острый лимфобластный лейкоз  Нормобласты, абсолютное значение
# 2061             Другой уточненный лейкоз  Нормобласты, абсолютное значение
# 2293             Другой уточненный лейкоз  Нормобласты, абсолютное значение
#
#      Значение кол. показателя Ед. изм. кол. показателя Норма кол. показателя  \
# 317                       7.0        кл/100 лейкоцитов                   0:2
# 1789                      2.0        кл/100 лейкоцитов                   0:2
# 1868                      2.0        кл/100 лейкоцитов                   0:2
# 2061                      2.0        кл/100 лейкоцитов                   0:2
# 2293                      1.0        кл/100 лейкоцитов                   0:2
#
#      Флаг нормы кол. показателя Кач. лаб. показатель Значение кач. показателя  \
# 317                       Повыш                  NaN                      NaN
# 1789                       Норм         Пойкилоцитоз                       ++
# 1868                       Норм                  NaN                      NaN
# 2061                       Норм                  NaN                      NaN
# 2293                       Норм                  NaN                      NaN
#
#      Норма кач. показателя  Пол  Возраст
# 317                    NaN    0       85
# 1789                    +-    0       72
# 1868                   NaN    1       75
# 2061                   NaN    1       71
# 2293                   NaN    0       85

# %%
norm_info('Плазматические клетки')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Плазматические клетки:
# ['0:0' '0:1']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Плазматические клетки:
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Плазматические клетки:
# [11.0 4.0 17.0 3.0 71.0 9.0 10.0 29.0 1.0 0.0 2.0]
# Всего строк со значением Плазматические клетки: 30

# %%
# Заменяем значения в столбце 'Норма кол. показателя' на '0:1' для строк, где 'Кол. лаб. показатель' == 'Плазматические клетки'
df.loc[df['Кол. лаб. показатель'] == 'Плазматические клетки', 'Норма кол. показателя'] = '0:1'
print(f"Уникальные значения в столбце 'Норма кол. показателя' для показателя 'Плазматические клетки': {df[df['Кол. лаб. показатель'] == 'Плазматические клетки']['Норма кол. показателя'].unique()}")
display(df[df['Кол. лаб. показатель'] == 'Плазматические клетки'].head())
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя 'Плазматические клетки': ['0:1']
#                        ID истории болезни  \
# 45   2e1d0b3f-488a-11ed-ab5a-0050568844e6
# 75   2e1d0b3f-488a-11ed-ab5a-0050568844e6
# 133  2e1d0b3f-488a-11ed-ab5a-0050568844e6
# 278  2e1d0b3f-488a-11ed-ab5a-0050568844e6
# 429  2e1d0b3f-488a-11ed-ab5a-0050568844e6
#
#     Осн. диаг. при выписке МКБ10 (текст)   Кол. лаб. показатель  \
# 45                Плазмоклеточный лейкоз  Плазматические клетки
# 75                Плазмоклеточный лейкоз  Плазматические клетки
# 133               Плазмоклеточный лейкоз  Плазматические клетки
# 278               Плазмоклеточный лейкоз  Плазматические клетки
# 429               Плазмоклеточный лейкоз  Плазматические клетки
#
#     Значение кол. показателя Ед. изм. кол. показателя Норма кол. показателя  \
# 45                      11.0                        %                   0:1
# 75                       4.0                        %                   0:1
# 133                     17.0                        %                   0:1
# 278                      3.0                        %                   0:1
# 429                      4.0                        %                   0:1
#
#     Флаг нормы кол. показателя Кач. лаб. показатель Значение кач. показателя  \
# 45                       Повыш                  NaN                      NaN
# 75                       Повыш                  NaN                      NaN
# 133                      Повыш                  NaN                      NaN
# 278                      Повыш                  NaN                      NaN
# 429                      Повыш                  NaN                      NaN
#
#     Норма кач. показателя  Пол  Возраст
# 45                    NaN    0       62
# 75                    NaN    0       62
# 133                   NaN    0       62
# 278                   NaN    0       62
# 429                   NaN    0       62

# %%
norm_info('Юные')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Юные:
# ['0:0']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Юные:
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Юные:
# [6.0 1.0 4.0 2.0 0.0 3.0 8.0 4.5 9.0 5.0 7.0 12.0 11.0 1.5 13.0 26.0 15.0
#  14.0 10.0 17.0 3.5 0.5 6.5 2.5 0.2 19.0]
# Всего строк со значением Юные: 304

# %%
norm_info('Бласты')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Бласты:
# ['0:0']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Бласты:
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Бласты:
# [1.0 0.5 2.0 43.0 81.0 53.0 5.0 7.0 4.0 97.0 98.0 10.0 0.0 12.0 11.0 3.0
#  3.5 6.0 1.5 93.0 92.5 25.0 9.5 11.5 84.0 88.0 59.0 76.0 90.0 82.0 15.0
#  68.0 9.0 27.0]
# Всего строк со значением Бласты: 143

# %%
norm_info('Неклассифицируемые кол-во')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Неклассифицируемые кол-во:
# ['0:0,4']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Неклассифицируемые кол-во:
# ['10*9/л']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Неклассифицируемые кол-во:
# [0.2 0.9 0.4 0.3 0.5 0.25 0.1 0.6 1.2 1.7 0.8 1.4 0.7 1.1 0.12 25.9 9.9
#  9.8 29.4 49.3 31.7]
# Всего строк со значением Неклассифицируемые кол-во: 117

# %%
# Заменяем значения в столбце 'Норма кол. показателя' на '0:0.4' для строк, где 'Кол. лаб. показатель' == 'Неклассифицируемые кол-во'
df.loc[df['Кол. лаб. показатель'] == 'Неклассифицируемые кол-во', 'Норма кол. показателя'] = '0:0.4'
print(f"Уникальные значения в столбце 'Норма кол. показателя' для показателя 'Неклассифицируемые кол-во': {df[df['Кол. лаб. показатель'] == 'Неклассифицируемые кол-во']['Норма кол. показателя'].unique()}")
display(df[df['Кол. лаб. показатель'] == 'Неклассифицируемые кол-во'].head())
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя 'Неклассифицируемые кол-во': ['0:0.4']
#                         ID истории болезни  \
# 1646  f52255a4-f9b6-11eb-bb97-2cea7fe73f75
# 3556  1c63c1e6-6b70-11eb-80ea-901b0e63368a
# 3557  1c63c1e6-6b70-11eb-80ea-901b0e63368a
# 3994  3a624a2c-2816-11ec-bb98-2cea7fe73f75
# 4038  3a624a2c-2816-11ec-bb98-2cea7fe73f75
#
#      Осн. диаг. при выписке МКБ10 (текст)       Кол. лаб. показатель  \
# 1646             Другой уточненный лейкоз  Неклассифицируемые кол-во
# 3556             Другой уточненный лейкоз  Неклассифицируемые кол-во
# 3557             Другой уточненный лейкоз  Неклассифицируемые кол-во
# 3994             Другой уточненный лейкоз  Неклассифицируемые кол-во
# 4038             Другой уточненный лейкоз  Неклассифицируемые кол-во
#
#      Значение кол. показателя Ед. изм. кол. показателя Норма кол. показателя  \
# 1646                      0.2                   10*9/л                 0:0.4
# 3556                      0.9                   10*9/л                 0:0.4
# 3557                      0.9                   10*9/л                 0:0.4
# 3994                      0.2                   10*9/л                 0:0.4
# 4038                      0.2                   10*9/л                 0:0.4
#
#      Флаг нормы кол. показателя Кач. лаб. показатель  \
# 1646                       Норм                  NaN
# 3556                      Повыш          Комментарий
# 3557                      Повыш           Анизоцитоз
# 3994                       Норм                  NaN
# 4038                       Норм           Анизоцитоз
#
#                            Значение кач. показателя Норма кач. показателя  \
# 1646                                            NaN                   NaN
# 3556  макроциты,тельца Жолли, гигантские тромбоциты                     _
# 3557                                            +++           Общая норма
# 3994                                            NaN                   NaN
# 4038                                              +                    +-
#
#       Пол  Возраст
# 1646    0       62
# 3556    1       70
# 3557    1       70
# 3994    0       69
# 4038    0       69

# %%
norm_info('Неклассифицируемые %')
# Out:
# Уникальные значения в столбце 'Норма кол. показателя' для показателя Неклассифицируемые %:
# ['0:4']
# Уникальные значения в столбце 'Ед. изм. кол. показателя' для показателя Неклассифицируемые %:
# ['%']
# Уникальные значения в столбце 'Значение кол. показателя' для показателя Неклассифицируемые %:
# [2.0 3.4 1.9 1.8 7.2 5.8 6.5 5.5 3.3 3.0 4.7 3.8 2.6 2.5 6.7 2.1 2.7 6.9
#  2.3 4.3 3.6 1.4 3.9 2.4 3.5 1.3 1.6 4.6 1.5 4.5 2.8 1.2 1.7 6.0 9.9 9.1
#  5.3 6.6 9.7 2.2 5.9 1.1 0.7 0.6 7.5 6.3 5.2 8.6 10.8 7.7 0.9 1.0 3.2 3.7
#  7.0 6.2 6.8 14.7 10.1 10.7 13.3 7.6 8.4 10.2 6.4 4.1 4.2 4.0 7.4 4.8 2.9
#  3.1 4.4 5.4 8.9 4.9 26.9 44.3 23.9 28.6 65.8 5.7 70.4 45.8 52.5 33.9 43.6
#  51.5 51.6 51.0 31.7 43.5 6.1 0.8 15.5 10.5 56.4 62.4 51.9 7.8 12.5 13.4]
# Всего строк со значением Неклассифицируемые %: 239

# %%
# Проверяем еще оставшиеся пропуски
print(f"Пропуски в столбце 'Кол. лаб. показатель':  {df['Кол. лаб. показатель'].isna().sum()}")
print(f"Пропуски в столбце 'Норма кол. показателя':  {df['Норма кол. показателя'].isna().sum()}")
# Out:
# Пропуски в столбце 'Кол. лаб. показатель':  0
# Пропуски в столбце 'Норма кол. показателя':  0

# %% [markdown]
# ### Этап 7: Удаление излишних лаб. показателей.
#
# Лабораторные показатели мы сократили по причине того, что задача стоит сделать диагностику для всех людей (по большому счету обычных, не больных страшными заболеваниями по типу лейкозов), и потому мы оставили только те показатели, которые могут повстречаться в ОАКе обычного человека (как расширенном, так и обычном анализе крови).

# %%
print(df['Кол. лаб. показатель'].value_counts())
# Out:
# Кол. лаб. показатель
# Тромбоциты (PLT)                                                        1622
# Эритроциты (RBC)                                                        1619
# Гематокрит (HCT)                                                        1619
# Гемоглобин (HGB)                                                        1619
# Среднее содержание гемоглобина в эритроците (MCH)                       1619
# Средний объем эритроцита (MCV)                                          1619
# Средняя концентрация гемоглобина в эритроците (MCHC)                    1619
# Лейкоциты (WBC)                                                         1616
# Лимфоциты, относительное количество (LY%)                               1470
# Лимфоциты, абсолютное количество (LY#)                                  1470
# Нейтрофилы, относительное количество (NE%)                              1332
# Нейтрофилы, абсолютное количество (NE#)                                 1319
# Средний объем тромбоцита (MPV)                                           982
# Тромбокрит (PCT)                                                         925
# Цветовой показатель                                                      832
# Распределение эритроцитов по объему (RDW)                                829
# Эозинофилы, относительное количество (EO%)                               824
# Базофилы, относительное количество (BA%)                                 822
# Моноциты, относительное количество (MO%)                                 815
# Моноциты, абсолютное количество (MO#)                                    784
# Лимфоциты (лейкоцитарная формула, %)                                     743
# Сегментоядерные нейтрофилы (%)                                           740
# Эозинофилы, абсолютное количество (EO#)                                  739
# Палочкоядерные нейтрофилы (%)                                            736
# Моноциты (лейкоцитарная формула, %)                                      734
# Базофилы, абсолютное количество (BA#)                                    732
# Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)     698
# Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)       696
# Распределение тромбоцитов по объему (PDW)                                657
# Эозинофилы (лейкоцитарная формула, %)                                    649
# СОЭ по Вестергрену                                                       569
# Базофилы (лейкоцитарная формула, %)                                      355
# Миелоциты (лейкоцитарная формула, %)                                     316
# Юные                                                                     304
# Неклассифицируемые %                                                     239
# Нормобласты, абсолютное значение                                         174
# Бласты                                                                   143
# Неклассифицируемые кол-во                                                117
# Ретикулоциты, относительное количество (%)                                57
# Ретикулоциты, абсолютное количество (#)                                   44
# Плазматические клетки                                                     30
# Промиелоциты (лейкоцитарная формула, %)                                   21
# Пролимфоциты (лейкоцитарная формула, %)                                   16
# Бласты (абс)                                                               4
# Name: count, dtype: int64

# %%
# Список значений для удаления
kol_lab_pak_to_delete = [
    'Миелоциты (лейкоцитарная формула, %)', 'Юные', 'Неклассифицируемые %', 
    'Нормобласты, абсолютное значение', 'Бласты', 'Неклассифицируемые кол-во', 
    'Ретикулоциты, относительное количество (%)', 'Ретикулоциты, абсолютное количество (#)', 
    'Плазматические клетки', 'Промиелоциты (лейкоцитарная формула, %)', 
    'Пролимфоциты (лейкоцитарная формула, %)', 'Бласты (абс)'
]

# Удаление строк, где 'Кол. лаб. показатель' содержит одно из значений в списке
df = df[~df['Кол. лаб. показатель'].isin(kol_lab_pak_to_delete)]

# %%
print(df['Кол. лаб. показатель'].value_counts())
# Out:
# Кол. лаб. показатель
# Тромбоциты (PLT)                                                        1622
# Эритроциты (RBC)                                                        1619
# Гематокрит (HCT)                                                        1619
# Гемоглобин (HGB)                                                        1619
# Среднее содержание гемоглобина в эритроците (MCH)                       1619
# Средний объем эритроцита (MCV)                                          1619
# Средняя концентрация гемоглобина в эритроците (MCHC)                    1619
# Лейкоциты (WBC)                                                         1616
# Лимфоциты, относительное количество (LY%)                               1470
# Лимфоциты, абсолютное количество (LY#)                                  1470
# Нейтрофилы, относительное количество (NE%)                              1332
# Нейтрофилы, абсолютное количество (NE#)                                 1319
# Средний объем тромбоцита (MPV)                                           982
# Тромбокрит (PCT)                                                         925
# Цветовой показатель                                                      832
# Распределение эритроцитов по объему (RDW)                                829
# Эозинофилы, относительное количество (EO%)                               824
# Базофилы, относительное количество (BA%)                                 822
# Моноциты, относительное количество (MO%)                                 815
# Моноциты, абсолютное количество (MO#)                                    784
# Лимфоциты (лейкоцитарная формула, %)                                     743
# Сегментоядерные нейтрофилы (%)                                           740
# Эозинофилы, абсолютное количество (EO#)                                  739
# Палочкоядерные нейтрофилы (%)                                            736
# Моноциты (лейкоцитарная формула, %)                                      734
# Базофилы, абсолютное количество (BA#)                                    732
# Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)     698
# Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)       696
# Распределение тромбоцитов по объему (PDW)                                657
# Эозинофилы (лейкоцитарная формула, %)                                    649
# СОЭ по Вестергрену                                                       569
# Базофилы (лейкоцитарная формула, %)                                      355
# Name: count, dtype: int64

# %%
# Вывод уникальных значений в столбце 'Флаг нормы кол. показателя'
unique_flags = df['Флаг нормы кол. показателя'].unique()
print("Уникальные значения в столбце 'Флаг нормы кол. показателя':")
print(unique_flags)
# Out:
# Уникальные значения в столбце 'Флаг нормы кол. показателя':
# ['Пониж' 'Норм' 'Повыш' nan 'Норма']

# %% [markdown]
# ### Этап 8: Обработка значений в столбце 'Флаг нормы кол. показателя'
#
# Для того, чтобы правильно проставить флаги повышенного/нормального/пониженного показателя необходимо создать столбцы с верхней и нижней нормой показателя.

# %%
# Вывод уникальных значений в столбце 'Флаг нормы кол. показателя'
unique_flags = df['Флаг нормы кол. показателя'].unique()
print("Уникальные значения в столбце 'Флаг нормы кол. показателя':")
print(unique_flags)
# Out:
# Уникальные значения в столбце 'Флаг нормы кол. показателя':
# ['Пониж' 'Норм' 'Повыш' nan 'Норма']

# %%
# Замена значения 'Норма' на 'Норм' в столбце 'Флаг нормы кол. показателя'
df['Флаг нормы кол. показателя'] = df['Флаг нормы кол. показателя'].replace('Норма', 'Норм')

# Проверка результата
print("Обновленные значения в столбце 'Флаг нормы кол. показателя':")
print(df['Флаг нормы кол. показателя'].unique())
# Out:
# Обновленные значения в столбце 'Флаг нормы кол. показателя':
# ['Пониж' 'Норм' 'Повыш' nan]

# %%
# Функция для безопасного разделения значений и логирования ошибок
def split_norma(row):
    try:
        lower, upper = row['Норма кол. показателя'].split(':')
        return pd.Series([lower, upper])
    except Exception as e:
        print(f"Ошибка при разделении строки: {row['Норма кол. показателя']}, Ошибка: {e}")
        return pd.Series([np.nan, np.nan])

# Применение функции к DataFrame
df[['Нижняя граница', 'Верхняя граница']] = df.apply(split_norma, axis=1)

# Функция для безопасного преобразования значений и логирования ошибок
def safe_convert_to_float(value, column_name):
    try:
        return float(value)
    except Exception as e:
        print(f"Ошибка при преобразовании значения в столбце '{column_name}': {value}, Ошибка: {e}")
        return np.nan

# Преобразуем столбцы в числовые значения (float)
df['Значение кол. показателя'] = df['Значение кол. показателя'].apply(safe_convert_to_float, column_name='Значение кол. показателя')
df['Нижняя граница'] = df['Нижняя граница'].apply(safe_convert_to_float, column_name='Нижняя граница')
df['Верхняя граница'] = df['Верхняя граница'].apply(safe_convert_to_float, column_name='Верхняя граница')

# %%
# Заполним столбец 'Флаг нормы кол. показателя' в зависимости от значений
def get_flag_str(row):
    if row['Значение кол. показателя'] < row['Нижняя граница']:
        return 'Пониж'
    elif row['Значение кол. показателя'] > row['Верхняя граница']:
        return 'Повыш'
    else:
        return 'Норм'

df['Флаг нормы кол. показателя'] = df.apply(get_flag_str, axis=1)

# %%
# Проверка изменений
df.head()
# Out:
#                      ID истории болезни Осн. диаг. при выписке МКБ10 (текст)  \
# 0  2e1d0b3f-488a-11ed-ab5a-0050568844e6               Плазмоклеточный лейкоз
# 1  2e1d0b3f-488a-11ed-ab5a-0050568844e6               Плазмоклеточный лейкоз
# 2  2e1d0b3f-488a-11ed-ab5a-0050568844e6               Плазмоклеточный лейкоз
# 3  2e1d0b3f-488a-11ed-ab5a-0050568844e6               Плазмоклеточный лейкоз
# 4  2e1d0b3f-488a-11ed-ab5a-0050568844e6               Плазмоклеточный лейкоз
#
#              Кол. лаб. показатель  Значение кол. показателя  \
# 0                 Лейкоциты (WBC)                      1.80
# 1                Эритроциты (RBC)                      4.18
# 2                Гемоглобин (HGB)                    120.00
# 3                Гематокрит (HCT)                     35.10
# 4  Средний объем эритроцита (MCV)                     84.00
#
#   Ед. изм. кол. показателя Норма кол. показателя Флаг нормы кол. показателя  \
# 0                   10*9/л              4.5:11.3                      Пониж
# 1                  10*12/л               3.8:5.3                       Норм
# 2                      г/л               117:160                       Норм
# 3                        %                 35:47                       Норм
# 4                       фл                81:101                       Норм
#
#   Кач. лаб. показатель Значение кач. показателя Норма кач. показателя  Пол  \
# 0                  NaN                      NaN                   NaN    0
# 1                  NaN                      NaN                   NaN    0
# 2                  NaN                      NaN                   NaN    0
# 3                  NaN                      NaN                   NaN    0
# 4                  NaN                      NaN                   NaN    0
#
#    Возраст  Нижняя граница  Верхняя граница
# 0       62             4.5             11.3
# 1       62             3.8              5.3
# 2       62           117.0            160.0
# 3       62            35.0             47.0
# 4       62            81.0            101.0

# %% [markdown]
# ### Этап 9: Удаление неинформативных столбцов.

# %%
# Вывод уникальных значений в колонке 'Кач. лаб. показатель'
unique_kach_lab_pok = df['Кач. лаб. показатель'].unique()
print("Уникальные значения в колонке 'Кач. лаб. показатель':")
print(unique_kach_lab_pok)
# Out:
# Уникальные значения в колонке 'Кач. лаб. показатель':
# [nan 'Комментарий' 'Анизоцитоз' 'Гипохромия' 'Пойкилоцитоз' 'Нормобласты'
#  'Микроцитоз' 'Макроцитоз']

# %%
# Вывод уникальных значений в колонке 'Значение кач. показателя'
unique_znach_kach_pok = df['Значение кач. показателя'].unique()
print("Уникальные значения в колонке 'Значение кач. показателя':")
print(unique_znach_kach_pok)
# Out:
# Уникальные значения в колонке 'Значение кач. показателя':
# [nan 'плазматические клетки с омоложением ядра'
#  'из 34 моноцитоидных элементов 9 промоноцитов'
#  'микроагрегаты тромбоцитов отсутствуют. тромбоциты при подсчете по мазку - 75х10*9/л'
#  'из 14 моноцитоидных элементов 8 промоноциты, тромбоциты по мазку  соответствуют счету анализатора.'
#  'микроагрегаты тромбоцитов не обнаружены. тромбоциты при подсчете по мазку - 51х10*9/л'
#  '+' '++' 'мишеневидные эритроциты'
#  'встречаются плазматические клетки с омоложенными ядрами'
#  'тромбоциты по мазку 62х10*9/л,'
#  'из 24 моноцитоидных элементов 16 промоноцитов' 'проверено'
#  'тромбоциты проверены по мазку' 'клетки лейколиза в умеренном количестве'
#  'встречаются микросгустки тромбоцитов'
#  'микроагрегаты тромбоцитов отсутствуют, тромбоциты при подсчете по мазку - 70х10*9/л'
#  'тромбоциты по мазку 81х10*9/л'
#  'встречаются полихроматофильные эритроциты.'
#  'плазматизация части лимфоцитов'
#  'макроциты,тельца Жолли, гигантские тромбоциты' '+++'
#  'Тромбоциты распределены по препарату венозной крови равномерно. Микроагрегаты тромбоцитов отсутствуют. Тромбоциты при подсчете по мазку-  90  х10*8/л'
#  ' тромбоциты по мазку 23*10*9/л' 'тромбоциты по мазку 21'
#  'Тромбоциты проверены' 'СОЭ - 21 мм/ч'
#  'из 9 моноцитоидных элементов 6 промоноцитов'
#  'среди моноцитоидных элементов 2 промоноцита'
#  'среди моноцитоидных  клеток 2,5 промоноцита.'
#  'Из 19 моноцитов 6 промоноцитов.Тромбоциты проверены,микроагрегаты не бонаружены.'
#  'СРЕДИ 35 МОНОЦИТОВ 13 ПРОМОНОЦИТОВ'
#  'среди моноцитоидных элементов 15 промоноцитов'
#  'среди моноцитоидных элементов 4 промоноцита'
#  'Бластные клетки двух видов, среднего размера с правильной формой ядра и крупные с неправильной (раздвоеной) формой ядер. '
#  'из 15 моноцитов 2 промоноцита'
#  'из 45 моноцитоидных элементов 13 промоноцитов'
#  'Из 21 моноцита 10 промоноцитов.Тромбоциты по мазку переферической крови 28х10*9/л'
#  'из 26 моноцитоидных элементов 5 промоноцитов' '3:100'
#  'Из 15 моноцитов 3 промоноцита' 'Из 24 моноцитов 12 промоноцитов '
#  'моноциты 21, из низ промоноциты 5. прислан покрашенный мазок от 10.06.22'
#  'из 50 моноцитов промоноцитов 13'
#  'Из 21 моноцитоидного элемента 2 промоноцита. '
#  'среди моноцитоидных элементов 6 промоноцитов'
#  'среди моноцитоидныз элементов 5 промоноцитов'
#  'тромболциты проверены по мазку' 'тромбоциты по мазку 19*10*9/л'
#  'тромбоциты проверены'
#  'тромбоциты по мазку периферичекой крови 62х10*9,л'
#  'тромбоциты единичные в препарате'
#  'тромбоциты по мазку соответствуют анализатору. встречаются единичные лимфоидные элементы со сглаженной структурой хроматина и остатками нуклеол'
#  '+-' 'лейкоциты не определяются'
#  'тромбоциты соответствуют данным анализатора' 'подсчет л/ф невозможен'
#  'при просмотре мазка тромбоциты единичные в препарате,подсчет формулы невозможен'
#  'счет л/ф невозможен'
#  'подсчет л/ф невозможен, тромбоциты соответствуют счету анализатора.'
#  'Подсчет л/ф невозможен,тромбоциты соотвнтствуют счету анализатора.'
#  'Подсчёт л/ф невозможен, тромбоциты единичные.'
#  'Подсчет л/ф невозможен, единичные тромбоциты'
#  'Подсчёт л/ф нефозможен, тромбоциты по мазку  11х10*9/л'
#  'Подсчет л/ф невозможен, тромбоциты по мазку соотверствуют счету анализатора'
#  'Тромбоциты по мазку из пробирки К3ЭДТА(фиолетовая) соответструют счету анализатора.'
#  'Тромбоциты по мазку из пробирки К3 ЭДТА(фиолетовая )- 29х10*9/л'
#  'Тромбоциты по мазку из пробирки К3ЭДТА(фиолетовая) 28х10*9/л'
#  'Тромбоциты по мазку из пробирки К3 ЭДТА(фиолетовая) распределены равномерно, соответствуют счету анализатора.'
#  'Тромбоциты по мазку из пробирки К3 ЭДТА (фиолетовая) распределены равномерно, 41х10*9/л'
#  'Тромбоциты по мазку из пробирки К3 ЭДТА (фиолетовая ) распределены равномерно,соответствуют счету анализатора.'
#  'Тромбоциты по мазку из пробирки К3 ЭДТА (фиолетовая) соответствуют счету анализатора'
#  'Тромбоциты в пересчете (мазок) соответствуют счету анализатора'
#  'Тромбоциты в пересчете (мазок) 42х10*9/л'
#  'Тромбоциты в пресчете (мазок) соответствуют счету анализатора'
#  'Тромбоциты в пересчете (мазок) соотверствубт счету анализатора'
#  'тромбоциты соответсвуют счету анализатора.'
#  'формулу подсчитать невозможно'
#  'из 26 моноцитоидных элементов 12 промоноцитов'
#  'СОЭ проверено. из 15 моноцитов 3 промоноцита, тромбоциты соответсуют счету анализатора.'
#  'Тромбоциты проверены. Тромбоциты по мазку крови - 23.0х10*9/л'
#  'СОЭ - 3 мм/час' 'тромбоциты по мазку 20*10*9/л'
#  'тромбоциты по мазку 30*10*9/л'
#  'подсчет лейкоцитарной формулы невозможен' 'исследование в 8,30'
#  'из44 моноцитов с омоложением ядра 11'
#  'Единичные микроагрегаты тромбоцитов'
#  'Из 54 моноцитов с омоложением ядра 10'
#  'тромбоциты при подсчете по мазку 102'
#  'Тромбоциты по мазку периферической крови 73х10*9/л'
#  'Трлмбоциты по мазку 56*10*9/л' 'рекомендуется консультация гематолога'
#  'остатки ядер мегакариоцитов' 'Признаки миелодисплазии.' 'Проверен!'
#  'встречаются активированные лимфоциты и гигантские тромбоциты'
#  'Встречаются гигантские тромбоциты.'
#  'тромбоциты по мазку 84х10*9/л, встречаются единичные микросгустки'
#  'Встрецаются гигантские тромбоциты.' 'Тромбоциты по мазку 81х10*9/л'
#  'Встречаются полихроматофильные эритроциты. Тромбоциты распределены по препарату равномерно, при подсчете по мазку венозной крови составляют - 74.0х10*9/л. '
#  'тромб.пров' 'тр пров' 'тромбоциты по мазку 64*10*9/Л'
#  'Тромбоциты проверены. Встречаются сакроформы тромбоцитов.'
#  'Тромбоциты по мазку 59*10*9/л' 'истиное число лейкоцитов 20,6'
#  'Встречаются макроформы тромбоцитов. ' 'тромб проверены' 'СОЭ - 7 мм/ч'
#  '3.0:100.0' 'Тромбоциты проверены\t'
#  'Тромбоциты проверены. Среди моноцитов большинство клеток с гиперхромными ядрами неправильной формы, базофильной цитоплазмой. Хроматин глыбчатый, нуклеолы отсутствуют. Клетки средних размеров.'
#  'Тромбоциты проверены. Моноцитоидные клетки 23 из 43'
#  'Лейкоциты после пересчета - 17,7х10*9/л. Тромбоциты проверены. Моноцитоидные клетки отличаются полиморфизмом ядер, высоким ядерно-цитоплазматическим соотношением, вакуолизацией цитоплазмы. '
#  'лейкоцитарную формулу подсчитать невозможно'
#  'мононуклеоидные элементы с более грой структурой хроматина и остатками нуклеол - 46; бласты с моноцитоидными ядрами'
#  'Анизоцитоз смешанный. Пойкилоцитоз с наличием дакриоцитов, шлемовидных эритроцитов, стоматоцитов, шизоцитов. Шизоциты- 2,5% (норма до 1%).  Встречаются полихроматофильные эритроциты. '
#  'среди моноцитоидных элеиентов встречаются единичные промоноциты'
#  'Тромбоциты в персчете (мазок) соответствуют счету анализатора'
#  'тромбоциты проверены.'
#  'Тромбоциты проверены. Тромбоциты по мазку крови - 21,0х10*9/л'
#  'тромбоциты соответствуют'
#  'Тромбоциты проверены. Встречаются микроснустки тромбоцитов!' 'ПРОВЕРЕНО'
#  'Встречаются полихроматофильные эритроциты' 'Результат проверен дважды.'
#  'тромбоциты по мазку соответствуют анализатору'
#  'остатки ядра мегакариоцита'
#  'среди моноцитоидных элементов встречаются промоноциты'
#  'лимфоидные элементы средних размеров,с ядрами неправильной формы,сглаженным рисунком хроматина,нечеткими ядрышками. тромбоциты по мазку из пробирки с цитратом 24х10*9/л'
#  'Лимфоидные элементы с неправильной формой ядра,с нечеткичи ядрышками.Тромбоциты по мазку периферической крови 26х10*9/л'
#  'Тромбоциты проверены. Рекомендована консультация гематолога.']

# %%
# Вывод уникальных значений в колонке 'Норма кач. показателя'
unique_norm_kach_pok = df['Норма кач. показателя'].unique()
print("Уникальные значения в колонке 'Норма кач. показателя':")
print(unique_norm_kach_pok)
# Out:
# Уникальные значения в колонке 'Норма кач. показателя':
# [nan '_' '+-' 'Общая норма' '0:2' '0:1']

# %%
# Список колонок для удаления
columns_to_drop = [
    'Кач. лаб. показатель', 
    'Значение кач. показателя',
    'Норма кач. показателя', 
    'Нижняя граница', 
    'Верхняя граница'
]

# Удаление колонок из DataFrame
df.drop(columns=columns_to_drop, inplace=True)

# Проверка изменений
df.head()
# Out:
#                      ID истории болезни Осн. диаг. при выписке МКБ10 (текст)  \
# 0  2e1d0b3f-488a-11ed-ab5a-0050568844e6               Плазмоклеточный лейкоз
# 1  2e1d0b3f-488a-11ed-ab5a-0050568844e6               Плазмоклеточный лейкоз
# 2  2e1d0b3f-488a-11ed-ab5a-0050568844e6               Плазмоклеточный лейкоз
# 3  2e1d0b3f-488a-11ed-ab5a-0050568844e6               Плазмоклеточный лейкоз
# 4  2e1d0b3f-488a-11ed-ab5a-0050568844e6               Плазмоклеточный лейкоз
#
#              Кол. лаб. показатель  Значение кол. показателя  \
# 0                 Лейкоциты (WBC)                      1.80
# 1                Эритроциты (RBC)                      4.18
# 2                Гемоглобин (HGB)                    120.00
# 3                Гематокрит (HCT)                     35.10
# 4  Средний объем эритроцита (MCV)                     84.00
#
#   Ед. изм. кол. показателя Норма кол. показателя Флаг нормы кол. показателя  \
# 0                   10*9/л              4.5:11.3                      Пониж
# 1                  10*12/л               3.8:5.3                       Норм
# 2                      г/л               117:160                       Норм
# 3                        %                 35:47                       Норм
# 4                       фл                81:101                       Норм
#
#    Пол  Возраст
# 0    0       62
# 1    0       62
# 2    0       62
# 3    0       62
# 4    0       62

# %%
# Вывод уникальных значений в колонке 'ID истории болезни' и их количества
unique_ids = df['ID истории болезни'].unique()
count_unique_ids = len(unique_ids)

print("Уникальные значения в колонке 'ID истории болезни':")
print(unique_ids)
print(f"Количество уникальных значений в колонке 'ID истории болезни': {count_unique_ids}")
# Out:
# Уникальные значения в колонке 'ID истории болезни':
# ['2e1d0b3f-488a-11ed-ab5a-0050568844e6'
#  '24612d4d-c466-11ec-ab54-0050568844e6'
#  'b0a85bb2-3404-11ed-ab56-0050568844e6'
#  '09564dae-ebb9-11ec-ab56-0050568844e6'
#  '2efd978b-cd3d-11ed-8604-005056880ecb'
#  '76416b20-b70b-11ec-ab54-0050568844e6'
#  'eb8b7ced-2860-11ed-ab56-0050568844e6'
#  '16e21cb0-ea56-11ed-ab67-0050568844e6'
#  'f52255a4-f9b6-11eb-bb97-2cea7fe73f75'
#  '86475e95-6a40-11ed-ab5f-0050568844e6'
#  'e6f7e5ed-0d76-11ed-ab56-0050568844e6'
#  'c6ecb784-05e2-11ee-8604-005056880ecb'
#  '9fd79b93-49f0-11ed-ab5a-0050568844e6'
#  '89570a49-1248-11ed-ab56-0050568844e6'
#  '6020d71a-e34f-11ed-ab67-0050568844e6'
#  'b36a2106-4308-11ed-ab5a-0050568844e6'
#  '0a0fbdfa-3a66-11ee-ab69-0050568844e6'
#  '7d6935ef-4493-11ed-ab5a-0050568844e6'
#  '5bcdbef9-efcf-11ed-8604-005056880ecb'
#  '7ed07467-c49f-11ed-8602-005056880ecb'
#  'cd1c9a58-63a0-11ef-ab70-0050568844e6'
#  '4dd618b8-d91a-11ed-ab67-0050568844e6'
#  '466e04bc-bc8d-11ec-ab54-0050568844e6'
#  '1c63c1e6-6b70-11eb-80ea-901b0e63368a'
#  '4e38fb7f-5443-11ed-ab5a-0050568844e6'
#  '3a624a2c-2816-11ec-bb98-2cea7fe73f75'
#  'b9e69694-699b-11ee-8604-005056880ecb'
#  'a6aad3bc-8f5f-11ee-ab6f-0050568844e6'
#  '3047e21e-6655-11ed-ab5f-0050568844e6'
#  '8cf06e3d-50dc-11ec-ab41-0050568819f3'
#  '7fbff64d-f55b-11ed-8604-005056880ecb'
#  'b520b217-4542-11ed-ab5a-0050568844e6'
#  '238483ff-70ab-11ed-ab61-0050568844e6'
#  'c6a9ecc0-a402-11eb-bb95-2cea7fe73f75'
#  'ff883bc4-80a2-11eb-bb94-2cea7fe73f75'
#  'fc6638ea-e869-11eb-bb97-2cea7fe73f75'
#  '9fc450e9-8feb-11ed-85f6-005056880ecb'
#  'eebeb925-9f8e-11ec-ab54-0050568844e6'
#  'ef1e1a6e-da72-11ec-ab54-0050568844e6'
#  'cf550ceb-8d49-11eb-bb95-2cea7fe73f75'
#  '6c042869-f6a6-11ec-ab56-0050568844e6'
#  'ba0484f1-c208-11ec-ab54-0050568844e6'
#  'ae3aa782-772d-11eb-80ec-901b0e633689'
#  'd5fb0a18-f67c-11eb-bb97-2cea7fe73f75'
#  '9918385b-0c30-11ee-8604-005056880ecb'
#  '4e40fb46-536e-11ed-ab5a-0050568844e6'
#  '2ac1f57a-b80b-11ed-ab63-0050568844e6'
#  'ca1603f3-976d-11eb-bb95-2cea7fe73f75'
#  '7ee25a9e-a480-11ed-8600-005056880ecb'
#  'd13aae4f-a605-11ed-ab61-0050568844e6'
#  'f9ab2b3b-3388-11ed-ab56-0050568844e6'
#  'f5efc525-e569-11ec-ab54-0050568844e6'
#  'c80a9fba-ba01-11eb-bb96-2cea7fe73f75'
#  '51e55390-581d-11ec-ab49-0050568819f3'
#  '81122832-7ada-11ed-ab61-0050568844e6'
#  '156f27a8-6a00-11eb-80e9-901b0e63368b'
#  '10a360bd-7b87-11ed-ab61-0050568844e6'
#  '587c8e25-5765-11ed-ab5c-0050568844e6'
#  '3e9fae92-1fba-11ee-ab69-0050568844e6'
#  'd2cff86d-e249-11ec-ab54-0050568844e6'
#  '937d9823-e9ff-11eb-bb97-2cea7fe73f75'
#  'e7f92e27-2fdb-11ec-bb98-2cea7fe73f75'
#  'bafb30cb-21f6-11ed-ab56-0050568844e6'
#  'c1f452ff-d091-11ee-8606-005056880ecb'
#  '6dcece01-58b9-11ec-ab49-0050568819f3'
#  'f8b6efc7-215c-11ee-ab69-0050568844e6'
#  'c361c10e-b221-11eb-bb95-2cea7fe73f75'
#  '9411e47e-0af9-11ec-bb98-2cea7fe73f75'
#  '4080a515-0ed7-11ec-bb98-2cea7fe73f75'
#  '287fe33f-fb67-11ec-ab56-0050568844e6'
#  'b2ddca30-82fc-11eb-bb94-2cea7fe73f75'
#  'aaf39b25-e684-11ee-ab6f-0050568844e6'
#  '0cf4c401-19f3-11ec-bb98-2cea7fe73f75'
#  '4639efe0-cd4d-11ed-ab67-0050568844e6'
#  '16268f70-d4df-11ec-ab54-0050568844e6'
#  'b490bccf-37bc-11ec-bb98-2cea7fe73f75'
#  '7208deed-6a3b-11ed-ab5f-0050568844e6'
#  'a33a6662-1f65-11ec-bb98-2cea7fe73f75'
#  '70076ff2-f7da-11ee-ab6f-0050568844e6'
#  '1a3d0bf5-fe8e-11ec-ab56-0050568844e6'
#  '5f7f09b8-88bc-11ec-ab52-0050568844e6'
#  'd01eefea-c9c7-11eb-bb97-2cea7fe73f75'
#  '5977dd16-a280-11eb-bb95-2cea7fe73f75'
#  'f732159c-f956-11ed-8604-005056880ecb'
#  'bfd5e4e8-066b-11ed-ab56-0050568844e6'
#  '6531656e-7f94-11ed-ab61-0050568844e6'
#  '51c51145-0c57-11ef-8607-005056880ecb'
#  '8c233c3e-b474-11eb-bb95-2cea7fe73f75'
#  'dfe7b162-10ee-11ef-ab70-0050568844e6'
#  '3e920e99-ff7d-11ed-ab67-0050568844e6'
#  'a6cc0de1-ac03-11ec-ab54-0050568844e6'
#  '43eef9d2-2a2f-11ef-8607-005056880ecb'
#  'b939b7b1-50d7-11ec-ab41-0050568819f3'
#  'f3ce5b34-84bf-11ec-ab52-0050568844e6'
#  '97adffed-3a95-11ef-8607-005056880ecb'
#  'f279faf3-a05e-11ec-ab54-0050568844e6'
#  'e150616f-b636-11ec-ab54-0050568844e6'
#  '2104a568-3266-11ed-ab56-0050568844e6'
#  '6ca81538-da78-11ec-ab54-0050568844e6'
#  'bcc40792-f99e-11eb-bb97-2cea7fe73f75'
#  '76c7bdde-4e4d-11ef-8607-005056880ecb'
#  '9b7b3519-77da-11ee-ab6d-0050568844e6'
#  'dcd56f96-a665-11eb-bb95-2cea7fe73f75'
#  '06a83aaa-8e27-11ec-ab52-0050568844e6'
#  '5cdfd41f-f6b2-11ec-ab56-0050568844e6'
#  'b3909ebb-cc58-11ec-ab54-0050568844e6'
#  '139dbc03-3277-11ed-ab56-0050568844e6'
#  '3fd06180-7e72-11ec-ab52-0050568844e6'
#  '7b9025cb-ae7c-11ec-ab54-0050568844e6'
#  '7f40c046-9899-11ed-85f8-005056880ecb'
#  '1e2e8fda-be65-11ed-8600-005056880ecb'
#  '3437c951-8d90-11ec-ab52-0050568844e6'
#  '1e4381d8-f3cc-11ed-8604-005056880ecb'
#  '0aa0d1b4-56fb-11eb-80e4-901b0e63368b'
#  'fc6b2aea-d5ad-11ec-ab54-0050568844e6'
#  '29a2a59b-1e0a-11ed-ab56-0050568844e6'
#  '44bc942f-71e5-11ec-ab4b-0050568819f3'
#  '84a0b162-6b6a-11eb-80ea-901b0e63368a'
#  '4a2c480d-a919-11ed-ab61-0050568844e6'
#  '6878f7b8-9784-11eb-bb95-2cea7fe73f75'
#  '3e338049-c7de-11ed-8602-005056880ecb'
#  '80232970-a5fa-11ed-8600-005056880ecb'
#  'ebe659f3-e300-11ec-ab54-0050568844e6'
#  '7dec1dcb-f628-11ed-ab67-0050568844e6'
#  'e1595e66-73d2-11ee-8604-005056880ecb'
#  '3b9b3bfb-87fc-11ec-ab52-0050568844e6'
#  '40c00e70-94d8-11ee-ab6f-0050568844e6'
#  '767ecc59-3232-11ec-bb98-2cea7fe73f75'
#  '4dd6bc50-2fe4-11ec-bb98-2cea7fe73f75'
#  '92f6abc6-eba4-11ec-ab56-0050568844e6'
#  'd13f240e-4d5b-11ea-80c8-901b0e63368a'
#  'db4d11e6-069d-11ea-80c0-901b0e63368b'
#  'da4a7c75-3b34-11ee-8604-005056880ecb'
#  '0f74aecf-5d0c-11ea-80ca-901b0e63368a'
#  'b86cafe6-6a6c-11ea-80cd-901b0e633689'
#  'f8b59bfd-4199-11ee-ab69-0050568844e6'
#  '432f1ac6-5d09-11ea-80ca-901b0e63368a'
#  'cb037b9f-0f7f-11eb-80da-901b0e63368a'
#  'd42a9adf-4bd8-11ea-80c8-901b0e63368a'
#  '0c2c320c-e69d-11ea-80d7-901b0e63368b'
#  'f3709508-3808-11ed-ab56-0050568844e6'
#  '864bb2bd-ef67-11e9-80bc-901b0e633689'
#  '087489cd-0fb8-11ec-bb98-2cea7fe73f75'
#  'b396c08b-f67a-11eb-bb97-2cea7fe73f75'
#  '268d2f6a-32ae-11ea-80c5-901b0e633689'
#  '731c7acf-87e2-11ec-ab52-0050568844e6'
#  'ffa72572-f065-11ec-ab56-0050568844e6'
#  '376cfe11-38ee-11ea-80c6-901b0e633689'
#  '8b9b8d32-b777-11ea-80d3-901b0e633689'
#  '6a603e8d-38fb-11ea-80c6-901b0e633689'
#  '6d7fc4c4-c8e5-11e9-80ba-901b0e633689'
#  'b122b70b-637f-11ea-80cc-901b0e63368b'
#  '511f4858-77d3-11ea-80ce-901b0e63368b'
#  '7e0cee6f-e531-11e9-80bc-901b0e633689'
#  'e651769b-3751-11ea-80c6-901b0e633689'
#  '8ede5ca1-e9e1-11e9-80bc-901b0e633689'
#  '0f59b100-2900-11ed-ab56-0050568844e6'
#  '2511213b-dfaf-11e9-80bb-901b0e633689'
#  '9995a332-c7c7-11ed-ab65-0050568844e6'
#  '722f2566-0b54-11ea-80c0-901b0e63368b'
#  '8bb4a289-2624-11ea-80c4-901b0e63368b'
#  '9facd6a9-569b-11ed-ab5c-0050568844e6'
#  '2a7fd76f-1817-11eb-80dd-901b0e63368b'
#  'ced2610a-a80f-11eb-bb95-2cea7fe73f75'
#  '4c888e2f-3ced-11ea-80c6-901b0e633689'
#  '1961cc39-068f-11ee-ab67-0050568844e6'
#  '7460e74e-33a1-11eb-80e0-901b0e633689'
#  'a58de71b-868c-11e9-80e1-901b0e63368a'
#  'e3ceff99-7a24-11ea-80ce-901b0e63368b'
#  '7266d14b-9e23-11e9-80e2-901b0e63368a'
#  '05deb1af-cf40-11e9-80ba-901b0e633689'
#  '21f4283b-0be6-11ed-ab56-0050568844e6'
#  '81f895b9-2ee2-11eb-80e0-901b0e633689'
#  '1e9f2b4d-98af-11e9-80e1-901b0e63368a'
#  '3196536a-06fd-11ec-bb97-2cea7fe73f75'
#  '137fd6a9-9649-11e9-80e1-901b0e63368a'
#  '778bee30-3b1a-11ed-ab58-0050568844e6'
#  'd931f0ea-7cad-11eb-bb94-2cea7fe73f75'
#  '51f1c2b1-172f-11ea-80c3-901b0e633688'
#  '503c9222-8236-11eb-bb94-2cea7fe73f75'
#  '72f64027-6cf5-11ea-80ce-901b0e63368b'
#  'e20a1d0a-1af8-11ee-ab69-0050568844e6'
#  '4f87b4a4-4406-11ea-80c7-901b0e633688'
#  '54182553-d2dd-11ed-8604-005056880ecb'
#  'c92695f6-a35f-11ec-ab54-0050568844e6'
#  '768e449c-92b0-11eb-bb95-2cea7fe73f75'
#  '0e99ec58-c708-11ed-8602-005056880ecb'
#  '965719ab-f0fd-11e9-80bd-901b0e633689'
#  'b2fd5cf8-6829-11ea-80cc-901b0e63368b'
#  'fc865ace-f83b-11ec-ab56-0050568844e6'
#  'd840ff0f-f2ee-11ed-ab67-0050568844e6'
#  '31a44efc-4d54-11ee-ab6d-0050568844e6'
#  '08475dc2-40af-11ee-8604-005056880ecb'
#  'c0528923-cfbc-11ee-8606-005056880ecb'
#  'f7a69394-d53e-11ee-8606-005056880ecb'
#  'f096d9a6-db97-11ee-ab6f-0050568844e6'
#  'df61aa7f-e2a3-11ee-ab6f-0050568844e6'
#  '1e4c6798-d14d-11ee-8606-005056880ecb'
#  '1d064dae-e202-11ee-ab6f-0050568844e6'
#  '429bdf6a-dc48-11ee-ab6f-0050568844e6'
#  '63417a1c-ea9c-11ee-8606-005056880ecb'
#  '110f1a4d-f003-11ee-8606-005056880ecb'
#  'b9c6d44b-fd5e-11ee-ab6f-0050568844e6'
#  '8a80287c-fc8f-11ee-8606-005056880ecb'
#  '80f51e57-fd5f-11ee-ab6f-0050568844e6'
#  '0839c9c1-1109-11ef-8607-005056880ecb'
#  '5c04d4d7-1295-11ef-ab70-0050568844e6'
#  '2adafd31-1685-11ef-8607-005056880ecb'
#  'aef5e883-142d-11ef-ab70-0050568844e6'
#  '49ace862-2189-11ef-ab70-0050568844e6'
#  '9015d129-1e62-11ef-ab70-0050568844e6'
#  'e5a96088-56b3-11ee-ab6d-0050568844e6'
#  '376c9361-23dc-11ef-8607-005056880ecb'
#  '57d0d8bd-2a29-11ef-ab70-0050568844e6'
#  'e322464e-346b-11ef-ab70-0050568844e6'
#  '69ec9d19-32e2-11ef-8607-005056880ecb'
#  '88e13b79-32cd-11ef-8607-005056880ecb'
#  'ab7dabbf-2e0e-11ef-8607-005056880ecb'
#  '56cbf56b-55ef-11ee-ab6d-0050568844e6'
#  '0a992bef-610b-11ee-ab6d-0050568844e6'
#  'afc9d801-4e42-11ef-ab70-0050568844e6'
#  '30dc6c21-50b7-11ef-8607-005056880ecb'
#  'c252822c-5497-11ef-ab70-0050568844e6'
#  '8ebc53a6-6357-11ee-ab6d-0050568844e6'
#  '22307b6b-6b63-11ef-8607-005056880ecb'
#  'fa6e833d-690f-11ef-ab70-0050568844e6'
#  '69f13457-7020-11ef-ab70-0050568844e6'
#  '481d0fb1-7b13-11ef-ab70-0050568844e6'
#  '4f7fae01-86e5-11ef-ab70-0050568844e6'
#  'e8e7f3c5-61bb-11ee-ab6d-0050568844e6'
#  'd85c6eaa-820c-11ee-8604-005056880ecb'
#  'e80ceac9-82d6-11ee-ab6d-0050568844e6'
#  '2f078398-8e98-11ee-8606-005056880ecb'
#  '6dadac1a-89ca-11ee-ab6f-0050568844e6'
#  'bdda164d-9fd4-11ee-ab6f-0050568844e6'
#  '451527e2-b04a-11ee-ab6f-0050568844e6'
#  '35466647-aeaf-11ee-ab6f-0050568844e6'
#  '69714728-b691-11ee-8606-005056880ecb'
#  'ffdf0ad3-bb5b-11ee-ab6f-0050568844e6'
#  '20f82885-b5cf-11ee-ab6f-0050568844e6'
#  '6166e156-c1af-11ed-8602-005056880ecb'
#  '516f652e-8bb8-11eb-bb95-2cea7fe73f75']
# Количество уникальных значений в колонке 'ID истории болезни': 242

# %%
# Вывод уникальных значений в колонке 'Кол. лаб. показатель' и их количества
unique_kol_lab_pok = df['Кол. лаб. показатель'].unique()
count_unique_klp = len(unique_kol_lab_pok)

print("Уникальные значения в колонке 'Кол. лаб. показатель':")
print(unique_kol_lab_pok)
print(f"Количество уникальных значений в колонке 'Кол. лаб. показатель': {count_unique_klp}")
# Out:
# Уникальные значения в колонке 'Кол. лаб. показатель':
# ['Лейкоциты (WBC)' 'Эритроциты (RBC)' 'Гемоглобин (HGB)'
#  'Гематокрит (HCT)' 'Средний объем эритроцита (MCV)'
#  'Среднее содержание гемоглобина в эритроците (MCH)'
#  'Средняя концентрация гемоглобина в эритроците (MCHC)' 'Тромбоциты (PLT)'
#  'Нейтрофилы, относительное количество (NE%)'
#  'Лимфоциты, относительное количество (LY%)'
#  'Нейтрофилы, абсолютное количество (NE#)'
#  'Лимфоциты, абсолютное количество (LY#)'
#  'Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)'
#  'Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)'
#  'Распределение эритроцитов по объему (RDW)' 'Тромбокрит (PCT)'
#  'Средний объем тромбоцита (MPV)'
#  'Распределение тромбоцитов по объему (PDW)'
#  'Моноциты, относительное количество (MO%)'
#  'Эозинофилы, относительное количество (EO%)'
#  'Базофилы, относительное количество (BA%)'
#  'Моноциты, абсолютное количество (MO#)'
#  'Эозинофилы, абсолютное количество (EO#)'
#  'Базофилы, абсолютное количество (BA#)' 'Цветовой показатель'
#  'СОЭ по Вестергрену' 'Палочкоядерные нейтрофилы (%)'
#  'Сегментоядерные нейтрофилы (%)' 'Эозинофилы (лейкоцитарная формула, %)'
#  'Лимфоциты (лейкоцитарная формула, %)'
#  'Моноциты (лейкоцитарная формула, %)'
#  'Базофилы (лейкоцитарная формула, %)']
# Количество уникальных значений в колонке 'Кол. лаб. показатель': 32

# %% [markdown]
# ### Этап 10: Упаковка данных в вектор

# %%
# Словарь для замены значений
rename_dict = {
    'Лейкоциты (WBC)': 'WBC',
    'Эритроциты (RBC)': 'RBC',
    'Гемоглобин (HGB)': 'HGB',
    'Гематокрит (HCT)': 'HCT',
    'Тромбоциты (PLT)': 'PLT',
    'Тромбокрит (PCT)': 'PCT',
    'Средний объем тромбоцита (MPV)': 'MPV',
    'Средний объем эритроцита (MCV)': 'MCV',
    'Среднее содержание гемоглобина в эритроците (MCH)': 'MCH',
    'Средняя концентрация гемоглобина в эритроците (MCHC)': 'MCHC',
    'Распределение тромбоцитов по объему (PDW)': 'PDW',
    'Распределение эритроцитов по объему (RDW)': 'RDW',
    'Распределение эритроцитов по объему, стандартное отклонение (RDW-SD)': 'RDW_SD',
    'Распределение эритроцитов по объему, коэффициент вариации (RDW-CV)': 'RDW_CV',
    'Лимфоциты, относительное количество (LY%)': 'LY_REL',
    'Моноциты, относительное количество (MO%)': 'MO_REL',
    'Нейтрофилы, относительное количество (NE%)': 'NE_REL',
    'Эозинофилы, относительное количество (EO%)': 'EO_REL',
    'Базофилы, относительное количество (BA%)': 'BA_REL',
    'Цветовой показатель': 'COLOR_INDEX',
    'Лимфоциты, абсолютное количество (LY#)': 'LY_ABS',
    'Моноциты, абсолютное количество (MO#)': 'MO_ABS',
    'Нейтрофилы, абсолютное количество (NE#)': 'NE_ABS',
    'Эозинофилы, абсолютное количество (EO#)': 'EO_ABS',
    'Базофилы, абсолютное количество (BA#)': 'BA_ABS',
    'Палочкоядерные нейтрофилы (%)': 'BAND_NEUT',
    'Сегментоядерные нейтрофилы (%)': 'SEGM_NEUT',
    'Лимфоциты (лейкоцитарная формула, %)': 'LY_LEICO',
    'Моноциты (лейкоцитарная формула, %)': 'MO_LEICO',
    'Эозинофилы (лейкоцитарная формула, %)': 'EO_LEICO',
    'Базофилы (лейкоцитарная формула, %)': 'BA_LEICO',
    'СОЭ по Вестергрену': 'ESR_Westergren'
}

# %%
# Замена значений в колонке 'Кол. лаб. показатель'
df['Кол. лаб. показатель'] = df['Кол. лаб. показатель'].replace(rename_dict)

# Проверка изменений
print("Переименованные значения в колонке 'Кол. лаб. показатель':")
print(df['Кол. лаб. показатель'].unique())
# Out:
# Переименованные значения в колонке 'Кол. лаб. показатель':
# ['WBC' 'RBC' 'HGB' 'HCT' 'MCV' 'MCH' 'MCHC' 'PLT' 'NE_REL' 'LY_REL'
#  'NE_ABS' 'LY_ABS' 'RDW_CV' 'RDW_SD' 'RDW' 'PCT' 'MPV' 'PDW' 'MO_REL'
#  'EO_REL' 'BA_REL' 'MO_ABS' 'EO_ABS' 'BA_ABS' 'COLOR_INDEX'
#  'ESR_Westergren' 'BAND_NEUT' 'SEGM_NEUT' 'EO_LEICO' 'LY_LEICO' 'MO_LEICO'
#  'BA_LEICO']

# %%
# Словарь для переименования колонок
columns_rename_dict = {
    'ID истории болезни': 'ID',
    'Осн. диаг. при выписке МКБ10 (текст)': 'ICD-10',
    'Кол. лаб. показатель': 'Parameter',
    'Значение кол. показателя': 'Result',
    'Ед. изм. кол. показателя': 'Unit',
    'Норма кол. показателя': 'Ref_Range',
    'Флаг нормы кол. показателя': 'Flag',
    'Пол': 'Sex',
    'Возраст': 'Age'
}

# Переименование колонок
df.rename(columns=columns_rename_dict, inplace=True)

# Проверка изменений
print("Переименованные колонки в DataFrame:")
print(df.columns)
# Out:
# Переименованные колонки в DataFrame:
# Index(['ID', 'ICD-10', 'Parameter', 'Result', 'Unit', 'Ref_Range', 'Flag',
#        'Sex', 'Age'],
#       dtype='object')

# %%
# Вывод уникальных значений из колонки 'ICD-10'
unique_icd10 = df['ICD-10'].unique()

print("Уникальные значения в колонке 'ICD-10':")
print(unique_icd10)
# Out:
# Уникальные значения в колонке 'ICD-10':
# ['Плазмоклеточный лейкоз' 'Другой уточненный лейкоз'
#  'Острый лимфобластный лейкоз' 'Хронический лимфоцитарный лейкоз'
#  'Волосатоклеточный лейкоз' 'Острый миелоидный лейкоз'
#  'Хронический миелоидный лейкоз' 'Острый миеломоноцитарный лейкоз'
#  'Другой миелоидный лейкоз' 'Острый лейкоз неуточненного клеточного типа']

# %%
# Подсчет количества уникальных значений
num_unique_icd10 = len(unique_icd10)

print(f"Количество уникальных значений в колонке 'ICD-10': {num_unique_icd10}")
# Out:
# Количество уникальных значений в колонке 'ICD-10': 10

# %%
# Фильтруем строки по ID и диагнозу ICD-10
filtered_df = df[(df['ID'] == '2e1d0b3f-488a-11ed-ab5a-0050568844e6') & (df['ICD-10'] == 'Плазмоклеточный лейкоз')]

# Выводим отфильтрованные строки
filtered_df
# Out:
#                                        ID                  ICD-10  Parameter  \
# 0    2e1d0b3f-488a-11ed-ab5a-0050568844e6  Плазмоклеточный лейкоз        WBC
# 1    2e1d0b3f-488a-11ed-ab5a-0050568844e6  Плазмоклеточный лейкоз        RBC
# 2    2e1d0b3f-488a-11ed-ab5a-0050568844e6  Плазмоклеточный лейкоз        HGB
# 3    2e1d0b3f-488a-11ed-ab5a-0050568844e6  Плазмоклеточный лейкоз        HCT
# 4    2e1d0b3f-488a-11ed-ab5a-0050568844e6  Плазмоклеточный лейкоз        MCV
# ..                                    ...                     ...        ...
# 424  2e1d0b3f-488a-11ed-ab5a-0050568844e6  Плазмоклеточный лейкоз  BAND_NEUT
# 425  2e1d0b3f-488a-11ed-ab5a-0050568844e6  Плазмоклеточный лейкоз  SEGM_NEUT
# 426  2e1d0b3f-488a-11ed-ab5a-0050568844e6  Плазмоклеточный лейкоз   EO_LEICO
# 427  2e1d0b3f-488a-11ed-ab5a-0050568844e6  Плазмоклеточный лейкоз   LY_LEICO
# 428  2e1d0b3f-488a-11ed-ab5a-0050568844e6  Плазмоклеточный лейкоз   MO_LEICO
#
#      Result     Unit Ref_Range   Flag  Sex  Age
# 0      1.80   10*9/л  4.5:11.3  Пониж    0   62
# 1      4.18  10*12/л   3.8:5.3   Норм    0   62
# 2    120.00      г/л   117:160   Норм    0   62
# 3     35.10        %     35:47   Норм    0   62
# 4     84.00       фл    81:101   Норм    0   62
# ..      ...      ...       ...    ...  ...  ...
# 424    1.00        %       1:6   Норм    0   62
# 425   22.00        %     47:72  Пониж    0   62
# 426    2.00        %       0:5   Норм    0   62
# 427   64.00        %     18:44  Повыш    0   62
# 428    7.00        %      2:12   Норм    0   62
#
# [273 rows x 9 columns]

# %%
# Подсчёт повторений для колонки Parameter
parameter_counts = filtered_df['Parameter'].value_counts()

# Вывод количества и списка уникальных параметров
print("Количество повторений каждого параметра для ID = '2e1d0b3f-488a-11ed-ab5a-0050568844e6':")
print(parameter_counts)
# Out:
# Количество повторений каждого параметра для ID = '2e1d0b3f-488a-11ed-ab5a-0050568844e6':
# Parameter
# WBC               12
# RBC               12
# HGB               12
# HCT               12
# MCV               12
# MCH               12
# MCHC              12
# PLT               12
# NE_REL            12
# LY_REL            12
# NE_ABS            12
# LY_ABS            12
# PCT                8
# RDW                7
# MO_REL             7
# MPV                7
# EO_LEICO           7
# ESR_Westergren     7
# EO_REL             7
# BA_REL             7
# EO_ABS             7
# MO_ABS             7
# BA_ABS             7
# COLOR_INDEX        7
# MO_LEICO           7
# LY_LEICO           7
# BAND_NEUT          7
# SEGM_NEUT          7
# RDW_CV             5
# RDW_SD             5
# PDW                5
# BA_LEICO           1
# Name: count, dtype: int64

# %%
# Подсчёт повторений для колонки Parameter
sex_counts = filtered_df['Sex'].value_counts()

# Вывод количества и списка уникальных параметров
print("Количество повторений Sex:")
print(sex_counts)
# Out:
# Количество повторений Sex:
# Sex
# 0    273
# Name: count, dtype: int64

# %%
# Подсчёт повторений для колонки Parameter
age_counts = filtered_df['Age'].value_counts()

# Вывод количества и списка уникальных параметров
print("Количество повторений Age:")
print(age_counts)
# Out:
# Количество повторений Age:
# Age
# 62    273
# Name: count, dtype: int64

# %%
# Создаем папку для сохранения файлов
output_dir = "done"
os.makedirs(output_dir, exist_ok=True)

# %%
# Функция для разбиения параметров по таблицам
def split_parameters_by_id(df):
    # Итерируем по каждому уникальному ID
    for unique_id in df["ID"].unique():
        id_data = df[df["ID"] == unique_id].copy()  # Данные для текущего ID
        table_counter = 1  # Счетчик для названий файлов
        
        while not id_data.empty:
            # Инициализируем список для хранения параметров, включенных в текущую таблицу
            included_parameters = set()
            
            # Выбираем строки с уникальными параметрами (по одному на каждый параметр)
            unique_table = id_data.loc[~id_data["Parameter"].duplicated(keep='first')]
            
            # Добавляем в список включенные параметры
            included_parameters.update(unique_table["Parameter"].unique())
            
            # Удаляем использованные строки из id_data
            id_data = id_data[~id_data.index.isin(unique_table.index)]
            
            # Создаем pivot-таблицу
            pivot_table = unique_table.pivot_table(
                index=["ID", "Sex", "Age", "ICD-10"],
                columns="Parameter",
                values="Result",
                aggfunc="first"
            ).reset_index()
            
            # Заполнение NaN для отсутствующих параметров
            pivot_table.fillna("NaN", inplace=True)
            
            # Сохраняем таблицу
            filename = f"done/{unique_id}_{table_counter}.csv"
            pivot_table.to_csv(filename, index=False)
            print(f"Сохранено: {filename}")
            
            # Увеличиваем счетчик для следующей таблицы
            table_counter += 1

# %%
# Пример вызова функции
split_parameters_by_id(df)
# Out:
# Сохранено: done/2e1d0b3f-488a-11ed-ab5a-0050568844e6_1.csv
# Сохранено: done/2e1d0b3f-488a-11ed-ab5a-0050568844e6_2.csv
# Сохранено: done/2e1d0b3f-488a-11ed-ab5a-0050568844e6_3.csv
# Сохранено: done/2e1d0b3f-488a-11ed-ab5a-0050568844e6_4.csv
# Сохранено: done/2e1d0b3f-488a-11ed-ab5a-0050568844e6_5.csv
# Сохранено: done/2e1d0b3f-488a-11ed-ab5a-0050568844e6_6.csv
# Сохранено: done/2e1d0b3f-488a-11ed-ab5a-0050568844e6_7.csv
# Сохранено: done/2e1d0b3f-488a-11ed-ab5a-0050568844e6_8.csv
# Сохранено: done/2e1d0b3f-488a-11ed-ab5a-0050568844e6_9.csv
# Сохранено: done/2e1d0b3f-488a-11ed-ab5a-0050568844e6_10.csv
# Сохранено: done/2e1d0b3f-488a-11ed-ab5a-0050568844e6_11.csv
# Сохранено: done/2e1d0b3f-488a-11ed-ab5a-0050568844e6_12.csv
# Сохранено: done/24612d4d-c466-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/24612d4d-c466-11ec-ab54-0050568844e6_2.csv
# Сохранено: done/24612d4d-c466-11ec-ab54-0050568844e6_3.csv
# Сохранено: done/24612d4d-c466-11ec-ab54-0050568844e6_4.csv
# Сохранено: done/24612d4d-c466-11ec-ab54-0050568844e6_5.csv
# Сохранено: done/24612d4d-c466-11ec-ab54-0050568844e6_6.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_1.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_2.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_3.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_4.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_5.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_6.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_7.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_8.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_9.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_10.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_11.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_12.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_13.csv
# Сохранено: done/b0a85bb2-3404-11ed-ab56-0050568844e6_14.csv
# Сохранено: done/09564dae-ebb9-11ec-ab56-0050568844e6_1.csv
# Сохранено: done/2efd978b-cd3d-11ed-8604-005056880ecb_1.csv
# Сохранено: done/2efd978b-cd3d-11ed-8604-005056880ecb_2.csv
# Сохранено: done/2efd978b-cd3d-11ed-8604-005056880ecb_3.csv
# Сохранено: done/2efd978b-cd3d-11ed-8604-005056880ecb_4.csv
# Сохранено: done/2efd978b-cd3d-11ed-8604-005056880ecb_5.csv
# Сохранено: done/2efd978b-cd3d-11ed-8604-005056880ecb_6.csv
# Сохранено: done/2efd978b-cd3d-11ed-8604-005056880ecb_7.csv
# Сохранено: done/76416b20-b70b-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/76416b20-b70b-11ec-ab54-0050568844e6_2.csv
# Сохранено: done/76416b20-b70b-11ec-ab54-0050568844e6_3.csv
# Сохранено: done/76416b20-b70b-11ec-ab54-0050568844e6_4.csv
# Сохранено: done/76416b20-b70b-11ec-ab54-0050568844e6_5.csv
# Сохранено: done/76416b20-b70b-11ec-ab54-0050568844e6_6.csv
# Сохранено: done/76416b20-b70b-11ec-ab54-0050568844e6_7.csv
# Сохранено: done/76416b20-b70b-11ec-ab54-0050568844e6_8.csv
# Сохранено: done/76416b20-b70b-11ec-ab54-0050568844e6_9.csv
# Сохранено: done/76416b20-b70b-11ec-ab54-0050568844e6_10.csv
# Сохранено: done/76416b20-b70b-11ec-ab54-0050568844e6_11.csv
# Сохранено: done/76416b20-b70b-11ec-ab54-0050568844e6_12.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_1.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_2.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_3.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_4.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_5.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_6.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_7.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_8.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_9.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_10.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_11.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_12.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_13.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_14.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_15.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_16.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_17.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_18.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_19.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_20.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_21.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_22.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_23.csv
# Сохранено: done/eb8b7ced-2860-11ed-ab56-0050568844e6_24.csv
# Сохранено: done/16e21cb0-ea56-11ed-ab67-0050568844e6_1.csv
# Сохранено: done/16e21cb0-ea56-11ed-ab67-0050568844e6_2.csv
# Сохранено: done/16e21cb0-ea56-11ed-ab67-0050568844e6_3.csv
# Сохранено: done/16e21cb0-ea56-11ed-ab67-0050568844e6_4.csv
# Сохранено: done/16e21cb0-ea56-11ed-ab67-0050568844e6_5.csv
# Сохранено: done/16e21cb0-ea56-11ed-ab67-0050568844e6_6.csv
# Сохранено: done/16e21cb0-ea56-11ed-ab67-0050568844e6_7.csv
# Сохранено: done/16e21cb0-ea56-11ed-ab67-0050568844e6_8.csv
# Сохранено: done/f52255a4-f9b6-11eb-bb97-2cea7fe73f75_1.csv
# Сохранено: done/f52255a4-f9b6-11eb-bb97-2cea7fe73f75_2.csv
# Сохранено: done/f52255a4-f9b6-11eb-bb97-2cea7fe73f75_3.csv
# Сохранено: done/86475e95-6a40-11ed-ab5f-0050568844e6_1.csv
# Сохранено: done/86475e95-6a40-11ed-ab5f-0050568844e6_2.csv
# Сохранено: done/86475e95-6a40-11ed-ab5f-0050568844e6_3.csv
# Сохранено: done/e6f7e5ed-0d76-11ed-ab56-0050568844e6_1.csv
# Сохранено: done/c6ecb784-05e2-11ee-8604-005056880ecb_1.csv
# Сохранено: done/c6ecb784-05e2-11ee-8604-005056880ecb_2.csv
# Сохранено: done/c6ecb784-05e2-11ee-8604-005056880ecb_3.csv
# Сохранено: done/c6ecb784-05e2-11ee-8604-005056880ecb_4.csv
# Сохранено: done/c6ecb784-05e2-11ee-8604-005056880ecb_5.csv
# Сохранено: done/c6ecb784-05e2-11ee-8604-005056880ecb_6.csv
# Сохранено: done/c6ecb784-05e2-11ee-8604-005056880ecb_7.csv
# Сохранено: done/c6ecb784-05e2-11ee-8604-005056880ecb_8.csv
# Сохранено: done/9fd79b93-49f0-11ed-ab5a-0050568844e6_1.csv
# Сохранено: done/9fd79b93-49f0-11ed-ab5a-0050568844e6_2.csv
# Сохранено: done/89570a49-1248-11ed-ab56-0050568844e6_1.csv
# Сохранено: done/89570a49-1248-11ed-ab56-0050568844e6_2.csv
# Сохранено: done/89570a49-1248-11ed-ab56-0050568844e6_3.csv
# Сохранено: done/89570a49-1248-11ed-ab56-0050568844e6_4.csv
# Сохранено: done/6020d71a-e34f-11ed-ab67-0050568844e6_1.csv
# Сохранено: done/6020d71a-e34f-11ed-ab67-0050568844e6_2.csv
# Сохранено: done/6020d71a-e34f-11ed-ab67-0050568844e6_3.csv
# Сохранено: done/6020d71a-e34f-11ed-ab67-0050568844e6_4.csv
# Сохранено: done/6020d71a-e34f-11ed-ab67-0050568844e6_5.csv
# Сохранено: done/6020d71a-e34f-11ed-ab67-0050568844e6_6.csv
# Сохранено: done/6020d71a-e34f-11ed-ab67-0050568844e6_7.csv
# Сохранено: done/6020d71a-e34f-11ed-ab67-0050568844e6_8.csv
# Сохранено: done/b36a2106-4308-11ed-ab5a-0050568844e6_1.csv
# Сохранено: done/b36a2106-4308-11ed-ab5a-0050568844e6_2.csv
# Сохранено: done/b36a2106-4308-11ed-ab5a-0050568844e6_3.csv
# Сохранено: done/b36a2106-4308-11ed-ab5a-0050568844e6_4.csv
# Сохранено: done/0a0fbdfa-3a66-11ee-ab69-0050568844e6_1.csv
# Сохранено: done/0a0fbdfa-3a66-11ee-ab69-0050568844e6_2.csv
# Сохранено: done/0a0fbdfa-3a66-11ee-ab69-0050568844e6_3.csv
# Сохранено: done/0a0fbdfa-3a66-11ee-ab69-0050568844e6_4.csv
# Сохранено: done/7d6935ef-4493-11ed-ab5a-0050568844e6_1.csv
# Сохранено: done/7d6935ef-4493-11ed-ab5a-0050568844e6_2.csv
# Сохранено: done/7d6935ef-4493-11ed-ab5a-0050568844e6_3.csv
# Сохранено: done/7d6935ef-4493-11ed-ab5a-0050568844e6_4.csv
# Сохранено: done/7d6935ef-4493-11ed-ab5a-0050568844e6_5.csv
# Сохранено: done/7d6935ef-4493-11ed-ab5a-0050568844e6_6.csv
# Сохранено: done/7d6935ef-4493-11ed-ab5a-0050568844e6_7.csv
# Сохранено: done/7d6935ef-4493-11ed-ab5a-0050568844e6_8.csv
# Сохранено: done/7d6935ef-4493-11ed-ab5a-0050568844e6_9.csv
# Сохранено: done/7d6935ef-4493-11ed-ab5a-0050568844e6_10.csv
# Сохранено: done/7d6935ef-4493-11ed-ab5a-0050568844e6_11.csv
# Сохранено: done/7d6935ef-4493-11ed-ab5a-0050568844e6_12.csv
# Сохранено: done/5bcdbef9-efcf-11ed-8604-005056880ecb_1.csv
# Сохранено: done/7ed07467-c49f-11ed-8602-005056880ecb_1.csv
# Сохранено: done/7ed07467-c49f-11ed-8602-005056880ecb_2.csv
# Сохранено: done/7ed07467-c49f-11ed-8602-005056880ecb_3.csv
# Сохранено: done/7ed07467-c49f-11ed-8602-005056880ecb_4.csv
# Сохранено: done/7ed07467-c49f-11ed-8602-005056880ecb_5.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_4.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_5.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_6.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_7.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_8.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_9.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_10.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_11.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_12.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_13.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_14.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_15.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_16.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_17.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_18.csv
# Сохранено: done/cd1c9a58-63a0-11ef-ab70-0050568844e6_19.csv
# Сохранено: done/4dd618b8-d91a-11ed-ab67-0050568844e6_1.csv
# Сохранено: done/4dd618b8-d91a-11ed-ab67-0050568844e6_2.csv
# Сохранено: done/4dd618b8-d91a-11ed-ab67-0050568844e6_3.csv
# Сохранено: done/4dd618b8-d91a-11ed-ab67-0050568844e6_4.csv
# Сохранено: done/4dd618b8-d91a-11ed-ab67-0050568844e6_5.csv
# Сохранено: done/4dd618b8-d91a-11ed-ab67-0050568844e6_6.csv
# Сохранено: done/4dd618b8-d91a-11ed-ab67-0050568844e6_7.csv
# Сохранено: done/4dd618b8-d91a-11ed-ab67-0050568844e6_8.csv
# Сохранено: done/466e04bc-bc8d-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/466e04bc-bc8d-11ec-ab54-0050568844e6_2.csv
# Сохранено: done/466e04bc-bc8d-11ec-ab54-0050568844e6_3.csv
# Сохранено: done/1c63c1e6-6b70-11eb-80ea-901b0e63368a_1.csv
# Сохранено: done/1c63c1e6-6b70-11eb-80ea-901b0e63368a_2.csv
# Сохранено: done/4e38fb7f-5443-11ed-ab5a-0050568844e6_1.csv
# Сохранено: done/4e38fb7f-5443-11ed-ab5a-0050568844e6_2.csv
# Сохранено: done/4e38fb7f-5443-11ed-ab5a-0050568844e6_3.csv
# Сохранено: done/4e38fb7f-5443-11ed-ab5a-0050568844e6_4.csv
# Сохранено: done/4e38fb7f-5443-11ed-ab5a-0050568844e6_5.csv
# Сохранено: done/4e38fb7f-5443-11ed-ab5a-0050568844e6_6.csv
# Сохранено: done/4e38fb7f-5443-11ed-ab5a-0050568844e6_7.csv
# Сохранено: done/3a624a2c-2816-11ec-bb98-2cea7fe73f75_1.csv
# Сохранено: done/3a624a2c-2816-11ec-bb98-2cea7fe73f75_2.csv
# Сохранено: done/3a624a2c-2816-11ec-bb98-2cea7fe73f75_3.csv
# Сохранено: done/3a624a2c-2816-11ec-bb98-2cea7fe73f75_4.csv
# Сохранено: done/3a624a2c-2816-11ec-bb98-2cea7fe73f75_5.csv
# Сохранено: done/3a624a2c-2816-11ec-bb98-2cea7fe73f75_6.csv
# Сохранено: done/b9e69694-699b-11ee-8604-005056880ecb_1.csv
# Сохранено: done/b9e69694-699b-11ee-8604-005056880ecb_2.csv
# Сохранено: done/a6aad3bc-8f5f-11ee-ab6f-0050568844e6_1.csv
# Сохранено: done/a6aad3bc-8f5f-11ee-ab6f-0050568844e6_2.csv
# Сохранено: done/a6aad3bc-8f5f-11ee-ab6f-0050568844e6_3.csv
# Сохранено: done/a6aad3bc-8f5f-11ee-ab6f-0050568844e6_4.csv
# Сохранено: done/3047e21e-6655-11ed-ab5f-0050568844e6_1.csv
# Сохранено: done/3047e21e-6655-11ed-ab5f-0050568844e6_2.csv
# Сохранено: done/3047e21e-6655-11ed-ab5f-0050568844e6_3.csv
# Сохранено: done/3047e21e-6655-11ed-ab5f-0050568844e6_4.csv
# Сохранено: done/3047e21e-6655-11ed-ab5f-0050568844e6_5.csv
# Сохранено: done/3047e21e-6655-11ed-ab5f-0050568844e6_6.csv
# Сохранено: done/8cf06e3d-50dc-11ec-ab41-0050568819f3_1.csv
# Сохранено: done/8cf06e3d-50dc-11ec-ab41-0050568819f3_2.csv
# Сохранено: done/8cf06e3d-50dc-11ec-ab41-0050568819f3_3.csv
# Сохранено: done/8cf06e3d-50dc-11ec-ab41-0050568819f3_4.csv
# Сохранено: done/8cf06e3d-50dc-11ec-ab41-0050568819f3_5.csv
# Сохранено: done/8cf06e3d-50dc-11ec-ab41-0050568819f3_6.csv
# Сохранено: done/8cf06e3d-50dc-11ec-ab41-0050568819f3_7.csv
# Сохранено: done/8cf06e3d-50dc-11ec-ab41-0050568819f3_8.csv
# Сохранено: done/8cf06e3d-50dc-11ec-ab41-0050568819f3_9.csv
# Сохранено: done/8cf06e3d-50dc-11ec-ab41-0050568819f3_10.csv
# Сохранено: done/8cf06e3d-50dc-11ec-ab41-0050568819f3_11.csv
# Сохранено: done/7fbff64d-f55b-11ed-8604-005056880ecb_1.csv
# Сохранено: done/b520b217-4542-11ed-ab5a-0050568844e6_1.csv
# Сохранено: done/b520b217-4542-11ed-ab5a-0050568844e6_2.csv
# Сохранено: done/b520b217-4542-11ed-ab5a-0050568844e6_3.csv
# Сохранено: done/b520b217-4542-11ed-ab5a-0050568844e6_4.csv
# Сохранено: done/238483ff-70ab-11ed-ab61-0050568844e6_1.csv
# Сохранено: done/238483ff-70ab-11ed-ab61-0050568844e6_2.csv
# Сохранено: done/238483ff-70ab-11ed-ab61-0050568844e6_3.csv
# Сохранено: done/238483ff-70ab-11ed-ab61-0050568844e6_4.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_1.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_2.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_3.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_4.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_5.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_6.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_7.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_8.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_9.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_10.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_11.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_12.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_13.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_14.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_15.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_16.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_17.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_18.csv
# Сохранено: done/c6a9ecc0-a402-11eb-bb95-2cea7fe73f75_19.csv
# Сохранено: done/ff883bc4-80a2-11eb-bb94-2cea7fe73f75_1.csv
# Сохранено: done/ff883bc4-80a2-11eb-bb94-2cea7fe73f75_2.csv
# Сохранено: done/ff883bc4-80a2-11eb-bb94-2cea7fe73f75_3.csv
# Сохранено: done/ff883bc4-80a2-11eb-bb94-2cea7fe73f75_4.csv
# Сохранено: done/ff883bc4-80a2-11eb-bb94-2cea7fe73f75_5.csv
# Сохранено: done/ff883bc4-80a2-11eb-bb94-2cea7fe73f75_6.csv
# Сохранено: done/ff883bc4-80a2-11eb-bb94-2cea7fe73f75_7.csv
# Сохранено: done/ff883bc4-80a2-11eb-bb94-2cea7fe73f75_8.csv
# Сохранено: done/fc6638ea-e869-11eb-bb97-2cea7fe73f75_1.csv
# Сохранено: done/fc6638ea-e869-11eb-bb97-2cea7fe73f75_2.csv
# Сохранено: done/fc6638ea-e869-11eb-bb97-2cea7fe73f75_3.csv
# Сохранено: done/fc6638ea-e869-11eb-bb97-2cea7fe73f75_4.csv
# Сохранено: done/fc6638ea-e869-11eb-bb97-2cea7fe73f75_5.csv
# Сохранено: done/fc6638ea-e869-11eb-bb97-2cea7fe73f75_6.csv
# Сохранено: done/fc6638ea-e869-11eb-bb97-2cea7fe73f75_7.csv
# Сохранено: done/fc6638ea-e869-11eb-bb97-2cea7fe73f75_8.csv
# Сохранено: done/9fc450e9-8feb-11ed-85f6-005056880ecb_1.csv
# Сохранено: done/9fc450e9-8feb-11ed-85f6-005056880ecb_2.csv
# Сохранено: done/9fc450e9-8feb-11ed-85f6-005056880ecb_3.csv
# Сохранено: done/eebeb925-9f8e-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/eebeb925-9f8e-11ec-ab54-0050568844e6_2.csv
# Сохранено: done/eebeb925-9f8e-11ec-ab54-0050568844e6_3.csv
# Сохранено: done/eebeb925-9f8e-11ec-ab54-0050568844e6_4.csv
# Сохранено: done/ef1e1a6e-da72-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_1.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_2.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_3.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_4.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_5.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_6.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_7.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_8.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_9.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_10.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_11.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_12.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_13.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_14.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_15.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_16.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_17.csv
# Сохранено: done/cf550ceb-8d49-11eb-bb95-2cea7fe73f75_18.csv
# Сохранено: done/6c042869-f6a6-11ec-ab56-0050568844e6_1.csv
# Сохранено: done/6c042869-f6a6-11ec-ab56-0050568844e6_2.csv
# Сохранено: done/6c042869-f6a6-11ec-ab56-0050568844e6_3.csv
# Сохранено: done/6c042869-f6a6-11ec-ab56-0050568844e6_4.csv
# Сохранено: done/ba0484f1-c208-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/ba0484f1-c208-11ec-ab54-0050568844e6_2.csv
# Сохранено: done/ae3aa782-772d-11eb-80ec-901b0e633689_1.csv
# Сохранено: done/ae3aa782-772d-11eb-80ec-901b0e633689_2.csv
# Сохранено: done/d5fb0a18-f67c-11eb-bb97-2cea7fe73f75_1.csv
# Сохранено: done/d5fb0a18-f67c-11eb-bb97-2cea7fe73f75_2.csv
# Сохранено: done/9918385b-0c30-11ee-8604-005056880ecb_1.csv
# Сохранено: done/9918385b-0c30-11ee-8604-005056880ecb_2.csv
# Сохранено: done/9918385b-0c30-11ee-8604-005056880ecb_3.csv
# Сохранено: done/9918385b-0c30-11ee-8604-005056880ecb_4.csv
# Сохранено: done/9918385b-0c30-11ee-8604-005056880ecb_5.csv
# Сохранено: done/4e40fb46-536e-11ed-ab5a-0050568844e6_1.csv
# Сохранено: done/4e40fb46-536e-11ed-ab5a-0050568844e6_2.csv
# Сохранено: done/4e40fb46-536e-11ed-ab5a-0050568844e6_3.csv
# Сохранено: done/4e40fb46-536e-11ed-ab5a-0050568844e6_4.csv
# Сохранено: done/4e40fb46-536e-11ed-ab5a-0050568844e6_5.csv
# Сохранено: done/4e40fb46-536e-11ed-ab5a-0050568844e6_6.csv
# Сохранено: done/4e40fb46-536e-11ed-ab5a-0050568844e6_7.csv
# Сохранено: done/4e40fb46-536e-11ed-ab5a-0050568844e6_8.csv
# Сохранено: done/2ac1f57a-b80b-11ed-ab63-0050568844e6_1.csv
# Сохранено: done/ca1603f3-976d-11eb-bb95-2cea7fe73f75_1.csv
# Сохранено: done/ca1603f3-976d-11eb-bb95-2cea7fe73f75_2.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_1.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_2.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_3.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_4.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_5.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_6.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_7.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_8.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_9.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_10.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_11.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_12.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_13.csv
# Сохранено: done/7ee25a9e-a480-11ed-8600-005056880ecb_14.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_1.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_2.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_3.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_4.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_5.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_6.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_7.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_8.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_9.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_10.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_11.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_12.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_13.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_14.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_15.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_16.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_17.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_18.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_19.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_20.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_21.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_22.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_23.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_24.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_25.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_26.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_27.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_28.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_29.csv
# Сохранено: done/d13aae4f-a605-11ed-ab61-0050568844e6_30.csv
# Сохранено: done/f9ab2b3b-3388-11ed-ab56-0050568844e6_1.csv
# Сохранено: done/f9ab2b3b-3388-11ed-ab56-0050568844e6_2.csv
# Сохранено: done/f9ab2b3b-3388-11ed-ab56-0050568844e6_3.csv
# Сохранено: done/f9ab2b3b-3388-11ed-ab56-0050568844e6_4.csv
# Сохранено: done/f5efc525-e569-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/f5efc525-e569-11ec-ab54-0050568844e6_2.csv
# Сохранено: done/f5efc525-e569-11ec-ab54-0050568844e6_3.csv
# Сохранено: done/f5efc525-e569-11ec-ab54-0050568844e6_4.csv
# Сохранено: done/f5efc525-e569-11ec-ab54-0050568844e6_5.csv
# Сохранено: done/f5efc525-e569-11ec-ab54-0050568844e6_6.csv
# Сохранено: done/f5efc525-e569-11ec-ab54-0050568844e6_7.csv
# Сохранено: done/f5efc525-e569-11ec-ab54-0050568844e6_8.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_1.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_2.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_3.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_4.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_5.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_6.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_7.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_8.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_9.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_10.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_11.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_12.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_13.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_14.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_15.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_16.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_17.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_18.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_19.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_20.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_21.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_22.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_23.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_24.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_25.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_26.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_27.csv
# Сохранено: done/c80a9fba-ba01-11eb-bb96-2cea7fe73f75_28.csv
# Сохранено: done/51e55390-581d-11ec-ab49-0050568819f3_1.csv
# Сохранено: done/51e55390-581d-11ec-ab49-0050568819f3_2.csv
# Сохранено: done/51e55390-581d-11ec-ab49-0050568819f3_3.csv
# Сохранено: done/51e55390-581d-11ec-ab49-0050568819f3_4.csv
# Сохранено: done/51e55390-581d-11ec-ab49-0050568819f3_5.csv
# Сохранено: done/51e55390-581d-11ec-ab49-0050568819f3_6.csv
# Сохранено: done/51e55390-581d-11ec-ab49-0050568819f3_7.csv
# Сохранено: done/81122832-7ada-11ed-ab61-0050568844e6_1.csv
# Сохранено: done/81122832-7ada-11ed-ab61-0050568844e6_2.csv
# Сохранено: done/81122832-7ada-11ed-ab61-0050568844e6_3.csv
# Сохранено: done/81122832-7ada-11ed-ab61-0050568844e6_4.csv
# Сохранено: done/81122832-7ada-11ed-ab61-0050568844e6_5.csv
# Сохранено: done/81122832-7ada-11ed-ab61-0050568844e6_6.csv
# Сохранено: done/81122832-7ada-11ed-ab61-0050568844e6_7.csv
# Сохранено: done/81122832-7ada-11ed-ab61-0050568844e6_8.csv
# Сохранено: done/156f27a8-6a00-11eb-80e9-901b0e63368b_1.csv
# Сохранено: done/156f27a8-6a00-11eb-80e9-901b0e63368b_2.csv
# Сохранено: done/10a360bd-7b87-11ed-ab61-0050568844e6_1.csv
# Сохранено: done/10a360bd-7b87-11ed-ab61-0050568844e6_2.csv
# Сохранено: done/10a360bd-7b87-11ed-ab61-0050568844e6_3.csv
# Сохранено: done/10a360bd-7b87-11ed-ab61-0050568844e6_4.csv
# Сохранено: done/10a360bd-7b87-11ed-ab61-0050568844e6_5.csv
# Сохранено: done/10a360bd-7b87-11ed-ab61-0050568844e6_6.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_1.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_2.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_3.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_4.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_5.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_6.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_7.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_8.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_9.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_10.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_11.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_12.csv
# Сохранено: done/587c8e25-5765-11ed-ab5c-0050568844e6_13.csv
# Сохранено: done/3e9fae92-1fba-11ee-ab69-0050568844e6_1.csv
# Сохранено: done/3e9fae92-1fba-11ee-ab69-0050568844e6_2.csv
# Сохранено: done/3e9fae92-1fba-11ee-ab69-0050568844e6_3.csv
# Сохранено: done/3e9fae92-1fba-11ee-ab69-0050568844e6_4.csv
# Сохранено: done/3e9fae92-1fba-11ee-ab69-0050568844e6_5.csv
# Сохранено: done/3e9fae92-1fba-11ee-ab69-0050568844e6_6.csv
# Сохранено: done/3e9fae92-1fba-11ee-ab69-0050568844e6_7.csv
# Сохранено: done/d2cff86d-e249-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/937d9823-e9ff-11eb-bb97-2cea7fe73f75_1.csv
# Сохранено: done/937d9823-e9ff-11eb-bb97-2cea7fe73f75_2.csv
# Сохранено: done/937d9823-e9ff-11eb-bb97-2cea7fe73f75_3.csv
# Сохранено: done/937d9823-e9ff-11eb-bb97-2cea7fe73f75_4.csv
# Сохранено: done/937d9823-e9ff-11eb-bb97-2cea7fe73f75_5.csv
# Сохранено: done/937d9823-e9ff-11eb-bb97-2cea7fe73f75_6.csv
# Сохранено: done/e7f92e27-2fdb-11ec-bb98-2cea7fe73f75_1.csv
# Сохранено: done/e7f92e27-2fdb-11ec-bb98-2cea7fe73f75_2.csv
# Сохранено: done/e7f92e27-2fdb-11ec-bb98-2cea7fe73f75_3.csv
# Сохранено: done/e7f92e27-2fdb-11ec-bb98-2cea7fe73f75_4.csv
# Сохранено: done/e7f92e27-2fdb-11ec-bb98-2cea7fe73f75_5.csv
# Сохранено: done/e7f92e27-2fdb-11ec-bb98-2cea7fe73f75_6.csv
# Сохранено: done/bafb30cb-21f6-11ed-ab56-0050568844e6_1.csv
# Сохранено: done/bafb30cb-21f6-11ed-ab56-0050568844e6_2.csv
# Сохранено: done/bafb30cb-21f6-11ed-ab56-0050568844e6_3.csv
# Сохранено: done/bafb30cb-21f6-11ed-ab56-0050568844e6_4.csv
# Сохранено: done/bafb30cb-21f6-11ed-ab56-0050568844e6_5.csv
# Сохранено: done/bafb30cb-21f6-11ed-ab56-0050568844e6_6.csv
# Сохранено: done/bafb30cb-21f6-11ed-ab56-0050568844e6_7.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_1.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_2.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_3.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_4.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_5.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_6.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_7.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_8.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_9.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_10.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_11.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_12.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_13.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_14.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_15.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_16.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_17.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_18.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_19.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_20.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_21.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_22.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_23.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_24.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_25.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_26.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_27.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_28.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_29.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_30.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_31.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_32.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_33.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_34.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_35.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_36.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_37.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_38.csv
# Сохранено: done/c1f452ff-d091-11ee-8606-005056880ecb_39.csv
# Сохранено: done/6dcece01-58b9-11ec-ab49-0050568819f3_1.csv
# Сохранено: done/6dcece01-58b9-11ec-ab49-0050568819f3_2.csv
# Сохранено: done/6dcece01-58b9-11ec-ab49-0050568819f3_3.csv
# Сохранено: done/6dcece01-58b9-11ec-ab49-0050568819f3_4.csv
# Сохранено: done/f8b6efc7-215c-11ee-ab69-0050568844e6_1.csv
# Сохранено: done/f8b6efc7-215c-11ee-ab69-0050568844e6_2.csv
# Сохранено: done/f8b6efc7-215c-11ee-ab69-0050568844e6_3.csv
# Сохранено: done/f8b6efc7-215c-11ee-ab69-0050568844e6_4.csv
# Сохранено: done/f8b6efc7-215c-11ee-ab69-0050568844e6_5.csv
# Сохранено: done/f8b6efc7-215c-11ee-ab69-0050568844e6_6.csv
# Сохранено: done/f8b6efc7-215c-11ee-ab69-0050568844e6_7.csv
# Сохранено: done/f8b6efc7-215c-11ee-ab69-0050568844e6_8.csv
# Сохранено: done/f8b6efc7-215c-11ee-ab69-0050568844e6_9.csv
# Сохранено: done/c361c10e-b221-11eb-bb95-2cea7fe73f75_1.csv
# Сохранено: done/c361c10e-b221-11eb-bb95-2cea7fe73f75_2.csv
# Сохранено: done/c361c10e-b221-11eb-bb95-2cea7fe73f75_3.csv
# Сохранено: done/c361c10e-b221-11eb-bb95-2cea7fe73f75_4.csv
# Сохранено: done/c361c10e-b221-11eb-bb95-2cea7fe73f75_5.csv
# Сохранено: done/c361c10e-b221-11eb-bb95-2cea7fe73f75_6.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_1.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_2.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_3.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_4.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_5.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_6.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_7.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_8.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_9.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_10.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_11.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_12.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_13.csv
# Сохранено: done/9411e47e-0af9-11ec-bb98-2cea7fe73f75_14.csv
# Сохранено: done/4080a515-0ed7-11ec-bb98-2cea7fe73f75_1.csv
# Сохранено: done/4080a515-0ed7-11ec-bb98-2cea7fe73f75_2.csv
# Сохранено: done/4080a515-0ed7-11ec-bb98-2cea7fe73f75_3.csv
# Сохранено: done/4080a515-0ed7-11ec-bb98-2cea7fe73f75_4.csv
# Сохранено: done/4080a515-0ed7-11ec-bb98-2cea7fe73f75_5.csv
# Сохранено: done/4080a515-0ed7-11ec-bb98-2cea7fe73f75_6.csv
# Сохранено: done/287fe33f-fb67-11ec-ab56-0050568844e6_1.csv
# Сохранено: done/287fe33f-fb67-11ec-ab56-0050568844e6_2.csv
# Сохранено: done/287fe33f-fb67-11ec-ab56-0050568844e6_3.csv
# Сохранено: done/287fe33f-fb67-11ec-ab56-0050568844e6_4.csv
# Сохранено: done/287fe33f-fb67-11ec-ab56-0050568844e6_5.csv
# Сохранено: done/287fe33f-fb67-11ec-ab56-0050568844e6_6.csv
# Сохранено: done/b2ddca30-82fc-11eb-bb94-2cea7fe73f75_1.csv
# Сохранено: done/b2ddca30-82fc-11eb-bb94-2cea7fe73f75_2.csv
# Сохранено: done/b2ddca30-82fc-11eb-bb94-2cea7fe73f75_3.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_1.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_2.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_3.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_4.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_5.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_6.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_7.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_8.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_9.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_10.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_11.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_12.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_13.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_14.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_15.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_16.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_17.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_18.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_19.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_20.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_21.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_22.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_23.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_24.csv
# Сохранено: done/aaf39b25-e684-11ee-ab6f-0050568844e6_25.csv
# Сохранено: done/0cf4c401-19f3-11ec-bb98-2cea7fe73f75_1.csv
# Сохранено: done/0cf4c401-19f3-11ec-bb98-2cea7fe73f75_2.csv
# Сохранено: done/0cf4c401-19f3-11ec-bb98-2cea7fe73f75_3.csv
# Сохранено: done/0cf4c401-19f3-11ec-bb98-2cea7fe73f75_4.csv
# Сохранено: done/4639efe0-cd4d-11ed-ab67-0050568844e6_1.csv
# Сохранено: done/4639efe0-cd4d-11ed-ab67-0050568844e6_2.csv
# Сохранено: done/4639efe0-cd4d-11ed-ab67-0050568844e6_3.csv
# Сохранено: done/16268f70-d4df-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/16268f70-d4df-11ec-ab54-0050568844e6_2.csv
# Сохранено: done/16268f70-d4df-11ec-ab54-0050568844e6_3.csv
# Сохранено: done/16268f70-d4df-11ec-ab54-0050568844e6_4.csv
# Сохранено: done/16268f70-d4df-11ec-ab54-0050568844e6_5.csv
# Сохранено: done/16268f70-d4df-11ec-ab54-0050568844e6_6.csv
# Сохранено: done/b490bccf-37bc-11ec-bb98-2cea7fe73f75_1.csv
# Сохранено: done/b490bccf-37bc-11ec-bb98-2cea7fe73f75_2.csv
# Сохранено: done/b490bccf-37bc-11ec-bb98-2cea7fe73f75_3.csv
# Сохранено: done/b490bccf-37bc-11ec-bb98-2cea7fe73f75_4.csv
# Сохранено: done/b490bccf-37bc-11ec-bb98-2cea7fe73f75_5.csv
# Сохранено: done/7208deed-6a3b-11ed-ab5f-0050568844e6_1.csv
# Сохранено: done/7208deed-6a3b-11ed-ab5f-0050568844e6_2.csv
# Сохранено: done/7208deed-6a3b-11ed-ab5f-0050568844e6_3.csv
# Сохранено: done/a33a6662-1f65-11ec-bb98-2cea7fe73f75_1.csv
# Сохранено: done/a33a6662-1f65-11ec-bb98-2cea7fe73f75_2.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_1.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_2.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_3.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_4.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_5.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_6.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_7.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_8.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_9.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_10.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_11.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_12.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_13.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_14.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_15.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_16.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_17.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_18.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_19.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_20.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_21.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_22.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_23.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_24.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_25.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_26.csv
# Сохранено: done/70076ff2-f7da-11ee-ab6f-0050568844e6_27.csv
# Сохранено: done/1a3d0bf5-fe8e-11ec-ab56-0050568844e6_1.csv
# Сохранено: done/1a3d0bf5-fe8e-11ec-ab56-0050568844e6_2.csv
# Сохранено: done/5f7f09b8-88bc-11ec-ab52-0050568844e6_1.csv
# Сохранено: done/5f7f09b8-88bc-11ec-ab52-0050568844e6_2.csv
# Сохранено: done/5f7f09b8-88bc-11ec-ab52-0050568844e6_3.csv
# Сохранено: done/5f7f09b8-88bc-11ec-ab52-0050568844e6_4.csv
# Сохранено: done/5f7f09b8-88bc-11ec-ab52-0050568844e6_5.csv
# Сохранено: done/5f7f09b8-88bc-11ec-ab52-0050568844e6_6.csv
# Сохранено: done/5f7f09b8-88bc-11ec-ab52-0050568844e6_7.csv
# Сохранено: done/5f7f09b8-88bc-11ec-ab52-0050568844e6_8.csv
# Сохранено: done/d01eefea-c9c7-11eb-bb97-2cea7fe73f75_1.csv
# Сохранено: done/d01eefea-c9c7-11eb-bb97-2cea7fe73f75_2.csv
# Сохранено: done/d01eefea-c9c7-11eb-bb97-2cea7fe73f75_3.csv
# Сохранено: done/d01eefea-c9c7-11eb-bb97-2cea7fe73f75_4.csv
# Сохранено: done/d01eefea-c9c7-11eb-bb97-2cea7fe73f75_5.csv
# Сохранено: done/5977dd16-a280-11eb-bb95-2cea7fe73f75_1.csv
# Сохранено: done/5977dd16-a280-11eb-bb95-2cea7fe73f75_2.csv
# Сохранено: done/5977dd16-a280-11eb-bb95-2cea7fe73f75_3.csv
# Сохранено: done/5977dd16-a280-11eb-bb95-2cea7fe73f75_4.csv
# Сохранено: done/5977dd16-a280-11eb-bb95-2cea7fe73f75_5.csv
# Сохранено: done/f732159c-f956-11ed-8604-005056880ecb_1.csv
# Сохранено: done/f732159c-f956-11ed-8604-005056880ecb_2.csv
# Сохранено: done/bfd5e4e8-066b-11ed-ab56-0050568844e6_1.csv
# Сохранено: done/bfd5e4e8-066b-11ed-ab56-0050568844e6_2.csv
# Сохранено: done/bfd5e4e8-066b-11ed-ab56-0050568844e6_3.csv
# Сохранено: done/bfd5e4e8-066b-11ed-ab56-0050568844e6_4.csv
# Сохранено: done/bfd5e4e8-066b-11ed-ab56-0050568844e6_5.csv
# Сохранено: done/bfd5e4e8-066b-11ed-ab56-0050568844e6_6.csv
# Сохранено: done/bfd5e4e8-066b-11ed-ab56-0050568844e6_7.csv
# Сохранено: done/bfd5e4e8-066b-11ed-ab56-0050568844e6_8.csv
# Сохранено: done/bfd5e4e8-066b-11ed-ab56-0050568844e6_9.csv
# Сохранено: done/6531656e-7f94-11ed-ab61-0050568844e6_1.csv
# Сохранено: done/6531656e-7f94-11ed-ab61-0050568844e6_2.csv
# Сохранено: done/6531656e-7f94-11ed-ab61-0050568844e6_3.csv
# Сохранено: done/6531656e-7f94-11ed-ab61-0050568844e6_4.csv
# Сохранено: done/6531656e-7f94-11ed-ab61-0050568844e6_5.csv
# Сохранено: done/6531656e-7f94-11ed-ab61-0050568844e6_6.csv
# Сохранено: done/6531656e-7f94-11ed-ab61-0050568844e6_7.csv
# Сохранено: done/6531656e-7f94-11ed-ab61-0050568844e6_8.csv
# Сохранено: done/6531656e-7f94-11ed-ab61-0050568844e6_9.csv
# Сохранено: done/6531656e-7f94-11ed-ab61-0050568844e6_10.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_1.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_2.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_3.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_4.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_5.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_6.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_7.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_8.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_9.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_10.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_11.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_12.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_13.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_14.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_15.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_16.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_17.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_18.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_19.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_20.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_21.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_22.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_23.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_24.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_25.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_26.csv
# Сохранено: done/51c51145-0c57-11ef-8607-005056880ecb_27.csv
# Сохранено: done/8c233c3e-b474-11eb-bb95-2cea7fe73f75_1.csv
# Сохранено: done/8c233c3e-b474-11eb-bb95-2cea7fe73f75_2.csv
# Сохранено: done/8c233c3e-b474-11eb-bb95-2cea7fe73f75_3.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_4.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_5.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_6.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_7.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_8.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_9.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_10.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_11.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_12.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_13.csv
# Сохранено: done/dfe7b162-10ee-11ef-ab70-0050568844e6_14.csv
# Сохранено: done/3e920e99-ff7d-11ed-ab67-0050568844e6_1.csv
# Сохранено: done/3e920e99-ff7d-11ed-ab67-0050568844e6_2.csv
# Сохранено: done/3e920e99-ff7d-11ed-ab67-0050568844e6_3.csv
# Сохранено: done/3e920e99-ff7d-11ed-ab67-0050568844e6_4.csv
# Сохранено: done/3e920e99-ff7d-11ed-ab67-0050568844e6_5.csv
# Сохранено: done/3e920e99-ff7d-11ed-ab67-0050568844e6_6.csv
# Сохранено: done/3e920e99-ff7d-11ed-ab67-0050568844e6_7.csv
# Сохранено: done/3e920e99-ff7d-11ed-ab67-0050568844e6_8.csv
# Сохранено: done/3e920e99-ff7d-11ed-ab67-0050568844e6_9.csv
# Сохранено: done/a6cc0de1-ac03-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/a6cc0de1-ac03-11ec-ab54-0050568844e6_2.csv
# Сохранено: done/a6cc0de1-ac03-11ec-ab54-0050568844e6_3.csv
# Сохранено: done/a6cc0de1-ac03-11ec-ab54-0050568844e6_4.csv
# Сохранено: done/a6cc0de1-ac03-11ec-ab54-0050568844e6_5.csv
# Сохранено: done/a6cc0de1-ac03-11ec-ab54-0050568844e6_6.csv
# Сохранено: done/a6cc0de1-ac03-11ec-ab54-0050568844e6_7.csv
# Сохранено: done/a6cc0de1-ac03-11ec-ab54-0050568844e6_8.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_1.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_2.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_3.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_4.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_5.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_6.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_7.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_8.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_9.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_10.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_11.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_12.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_13.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_14.csv
# Сохранено: done/43eef9d2-2a2f-11ef-8607-005056880ecb_15.csv
# Сохранено: done/b939b7b1-50d7-11ec-ab41-0050568819f3_1.csv
# Сохранено: done/b939b7b1-50d7-11ec-ab41-0050568819f3_2.csv
# Сохранено: done/b939b7b1-50d7-11ec-ab41-0050568819f3_3.csv
# Сохранено: done/b939b7b1-50d7-11ec-ab41-0050568819f3_4.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_1.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_2.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_3.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_4.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_5.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_6.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_7.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_8.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_9.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_10.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_11.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_12.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_13.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_14.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_15.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_16.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_17.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_18.csv
# Сохранено: done/f3ce5b34-84bf-11ec-ab52-0050568844e6_19.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_1.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_2.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_3.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_4.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_5.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_6.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_7.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_8.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_9.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_10.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_11.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_12.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_13.csv
# Сохранено: done/97adffed-3a95-11ef-8607-005056880ecb_14.csv
# Сохранено: done/f279faf3-a05e-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/f279faf3-a05e-11ec-ab54-0050568844e6_2.csv
# Сохранено: done/f279faf3-a05e-11ec-ab54-0050568844e6_3.csv
# Сохранено: done/e150616f-b636-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/2104a568-3266-11ed-ab56-0050568844e6_1.csv
# Сохранено: done/2104a568-3266-11ed-ab56-0050568844e6_2.csv
# Сохранено: done/2104a568-3266-11ed-ab56-0050568844e6_3.csv
# Сохранено: done/2104a568-3266-11ed-ab56-0050568844e6_4.csv
# Сохранено: done/2104a568-3266-11ed-ab56-0050568844e6_5.csv
# Сохранено: done/2104a568-3266-11ed-ab56-0050568844e6_6.csv
# Сохранено: done/6ca81538-da78-11ec-ab54-0050568844e6_1.csv
# Сохранено: done/6ca81538-da78-11ec-ab54-0050568844e6_2.csv
# Сохранено: done/6ca81538-da78-11ec-ab54-0050568844e6_3.csv
# Сохранено: done/bcc40792-f99e-11eb-bb97-2cea7fe73f75_1.csv
# Сохранено: done/bcc40792-f99e-11eb-bb97-2cea7fe73f75_2.csv
# Сохранено: done/76c7bdde-4e4d-11ef-8607-005056880ecb_1.csv
# Сохранено: done/76c7bdde-4e4d-11ef-8607-005056880ecb_2.csv
# Сохранено: done/76c7bdde-4e4d-11ef-8607-005056880ecb_3.csv
# Сохранено: done/76c7bdde-4e4d-11ef-8607-005056880ecb_4.csv
# Сохранено: done/9b7b3519-77da-11ee-ab6d-0050568844e6_1.csv
# Сохранено: done/9b7b3519-77da-11ee-ab6d-0050568844e6_2.csv
# Сохранено: done/9b7b3519-77da-11ee-ab6d-0050568844e6_3.csv
# Сохранено: done/dcd56f96-a665-11eb-bb95-2cea7fe73f75_1.csv
# Сохранено: done/dcd56f96-a665-11eb-bb95-2cea7fe73f75_2.csv
# Сохранено: done/dcd56f96-a665-11eb-bb95-2cea7fe73f75_3.csv
# Сохранено: done/06a83aaa-8e27-11ec-ab52-0050568844e6_1.csv
# Сохранено: done/06a83aaa-8e27-11ec-ab52-0050568844e6_2.csv
# Сохранено: done/06a83aaa-8e27-11ec-ab52-0050568844e6_3.csv
# Сохранено: done/06a83aaa-8e27-11ec-ab52-0050568844e6_4.csv
# Сохранено: done/06a83aaa-8e27-11ec-ab52-0050568844e6_5.csv
# Сохранено: done/5cdfd41f-f6b2-11ec-ab56-0050568844e6_1.csv
# Сохранено: done/5cdfd41f-f6b2-11ec-ab56-0050568844e6_2.csv
# Сохранено: done/5cdfd41f-f6b2-11ec-ab56-0050568844e6_3.csv
# Сохранено: done/5cdfd41f-f6b2-11ec-ab56-0050568844e6_4.csv
# Сохранено: done/5cdfd41f-f6b2-11ec-ab56-0050568844e6_5.csv
# Сохранено: done/5cdfd41f-f6b2-11ec-ab56-0050568844e6_6.csv
# Сохранено: done/5cdfd41f-f6b2-11ec-ab56-0050568844e6_7.csv
# Сохранено: done/5cdfd41f-f6b2-11ec-ab56-0050568844e6_8.csv
# Сохранено: done/5cdfd41f-f6b2-11ec-ab56-0050568844e6_9.csv
# Сохранено: done/5cdfd41f-f6b2-11ec-ab56-0050568844e6_10.csv
# Сохранено: done/5cdfd41f-f6b2-11ec-ab56-0050568844e6_11.csv
# Сохранено: done/5cdfd41f-f6b2-11ec-ab56-0050568844e6_12.csv
# Сохранено: done/b3909ebb-cc58-11ec-ab54-0050568844e6_1.csv
# ...
# Сохранено: done/63417a1c-ea9c-11ee-8606-005056880ecb_3.csv
# Сохранено: done/63417a1c-ea9c-11ee-8606-005056880ecb_4.csv
# Сохранено: done/63417a1c-ea9c-11ee-8606-005056880ecb_5.csv
# Сохранено: done/63417a1c-ea9c-11ee-8606-005056880ecb_6.csv
# Сохранено: done/110f1a4d-f003-11ee-8606-005056880ecb_1.csv
# Сохранено: done/110f1a4d-f003-11ee-8606-005056880ecb_2.csv
# Сохранено: done/110f1a4d-f003-11ee-8606-005056880ecb_3.csv
# Сохранено: done/110f1a4d-f003-11ee-8606-005056880ecb_4.csv
# Сохранено: done/110f1a4d-f003-11ee-8606-005056880ecb_5.csv
# Сохранено: done/110f1a4d-f003-11ee-8606-005056880ecb_6.csv
# Сохранено: done/110f1a4d-f003-11ee-8606-005056880ecb_7.csv
# Сохранено: done/b9c6d44b-fd5e-11ee-ab6f-0050568844e6_1.csv
# Сохранено: done/b9c6d44b-fd5e-11ee-ab6f-0050568844e6_2.csv
# Сохранено: done/b9c6d44b-fd5e-11ee-ab6f-0050568844e6_3.csv
# Сохранено: done/8a80287c-fc8f-11ee-8606-005056880ecb_1.csv
# Сохранено: done/8a80287c-fc8f-11ee-8606-005056880ecb_2.csv
# Сохранено: done/8a80287c-fc8f-11ee-8606-005056880ecb_3.csv
# Сохранено: done/8a80287c-fc8f-11ee-8606-005056880ecb_4.csv
# Сохранено: done/8a80287c-fc8f-11ee-8606-005056880ecb_5.csv
# Сохранено: done/8a80287c-fc8f-11ee-8606-005056880ecb_6.csv
# Сохранено: done/8a80287c-fc8f-11ee-8606-005056880ecb_7.csv
# Сохранено: done/8a80287c-fc8f-11ee-8606-005056880ecb_8.csv
# Сохранено: done/80f51e57-fd5f-11ee-ab6f-0050568844e6_1.csv
# Сохранено: done/80f51e57-fd5f-11ee-ab6f-0050568844e6_2.csv
# Сохранено: done/80f51e57-fd5f-11ee-ab6f-0050568844e6_3.csv
# Сохранено: done/80f51e57-fd5f-11ee-ab6f-0050568844e6_4.csv
# Сохранено: done/80f51e57-fd5f-11ee-ab6f-0050568844e6_5.csv
# Сохранено: done/80f51e57-fd5f-11ee-ab6f-0050568844e6_6.csv
# Сохранено: done/80f51e57-fd5f-11ee-ab6f-0050568844e6_7.csv
# Сохранено: done/80f51e57-fd5f-11ee-ab6f-0050568844e6_8.csv
# Сохранено: done/80f51e57-fd5f-11ee-ab6f-0050568844e6_9.csv
# Сохранено: done/0839c9c1-1109-11ef-8607-005056880ecb_1.csv
# Сохранено: done/0839c9c1-1109-11ef-8607-005056880ecb_2.csv
# Сохранено: done/0839c9c1-1109-11ef-8607-005056880ecb_3.csv
# Сохранено: done/0839c9c1-1109-11ef-8607-005056880ecb_4.csv
# Сохранено: done/0839c9c1-1109-11ef-8607-005056880ecb_5.csv
# Сохранено: done/0839c9c1-1109-11ef-8607-005056880ecb_6.csv
# Сохранено: done/0839c9c1-1109-11ef-8607-005056880ecb_7.csv
# Сохранено: done/0839c9c1-1109-11ef-8607-005056880ecb_8.csv
# Сохранено: done/0839c9c1-1109-11ef-8607-005056880ecb_9.csv
# Сохранено: done/0839c9c1-1109-11ef-8607-005056880ecb_10.csv
# Сохранено: done/0839c9c1-1109-11ef-8607-005056880ecb_11.csv
# Сохранено: done/5c04d4d7-1295-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/5c04d4d7-1295-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/5c04d4d7-1295-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/5c04d4d7-1295-11ef-ab70-0050568844e6_4.csv
# Сохранено: done/5c04d4d7-1295-11ef-ab70-0050568844e6_5.csv
# Сохранено: done/5c04d4d7-1295-11ef-ab70-0050568844e6_6.csv
# Сохранено: done/2adafd31-1685-11ef-8607-005056880ecb_1.csv
# Сохранено: done/2adafd31-1685-11ef-8607-005056880ecb_2.csv
# Сохранено: done/aef5e883-142d-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/aef5e883-142d-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/aef5e883-142d-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/aef5e883-142d-11ef-ab70-0050568844e6_4.csv
# Сохранено: done/aef5e883-142d-11ef-ab70-0050568844e6_5.csv
# Сохранено: done/49ace862-2189-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/49ace862-2189-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/49ace862-2189-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/49ace862-2189-11ef-ab70-0050568844e6_4.csv
# Сохранено: done/49ace862-2189-11ef-ab70-0050568844e6_5.csv
# Сохранено: done/49ace862-2189-11ef-ab70-0050568844e6_6.csv
# Сохранено: done/49ace862-2189-11ef-ab70-0050568844e6_7.csv
# Сохранено: done/49ace862-2189-11ef-ab70-0050568844e6_8.csv
# Сохранено: done/9015d129-1e62-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/9015d129-1e62-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/9015d129-1e62-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/9015d129-1e62-11ef-ab70-0050568844e6_4.csv
# Сохранено: done/9015d129-1e62-11ef-ab70-0050568844e6_5.csv
# Сохранено: done/9015d129-1e62-11ef-ab70-0050568844e6_6.csv
# Сохранено: done/e5a96088-56b3-11ee-ab6d-0050568844e6_1.csv
# Сохранено: done/e5a96088-56b3-11ee-ab6d-0050568844e6_2.csv
# Сохранено: done/e5a96088-56b3-11ee-ab6d-0050568844e6_3.csv
# Сохранено: done/e5a96088-56b3-11ee-ab6d-0050568844e6_4.csv
# Сохранено: done/e5a96088-56b3-11ee-ab6d-0050568844e6_5.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_1.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_2.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_3.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_4.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_5.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_6.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_7.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_8.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_9.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_10.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_11.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_12.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_13.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_14.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_15.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_16.csv
# Сохранено: done/376c9361-23dc-11ef-8607-005056880ecb_17.csv
# Сохранено: done/57d0d8bd-2a29-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/57d0d8bd-2a29-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/57d0d8bd-2a29-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/57d0d8bd-2a29-11ef-ab70-0050568844e6_4.csv
# Сохранено: done/57d0d8bd-2a29-11ef-ab70-0050568844e6_5.csv
# Сохранено: done/57d0d8bd-2a29-11ef-ab70-0050568844e6_6.csv
# Сохранено: done/e322464e-346b-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/e322464e-346b-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/e322464e-346b-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/69ec9d19-32e2-11ef-8607-005056880ecb_1.csv
# Сохранено: done/69ec9d19-32e2-11ef-8607-005056880ecb_2.csv
# Сохранено: done/69ec9d19-32e2-11ef-8607-005056880ecb_3.csv
# Сохранено: done/88e13b79-32cd-11ef-8607-005056880ecb_1.csv
# Сохранено: done/88e13b79-32cd-11ef-8607-005056880ecb_2.csv
# Сохранено: done/88e13b79-32cd-11ef-8607-005056880ecb_3.csv
# Сохранено: done/88e13b79-32cd-11ef-8607-005056880ecb_4.csv
# Сохранено: done/88e13b79-32cd-11ef-8607-005056880ecb_5.csv
# Сохранено: done/88e13b79-32cd-11ef-8607-005056880ecb_6.csv
# Сохранено: done/88e13b79-32cd-11ef-8607-005056880ecb_7.csv
# Сохранено: done/88e13b79-32cd-11ef-8607-005056880ecb_8.csv
# Сохранено: done/ab7dabbf-2e0e-11ef-8607-005056880ecb_1.csv
# Сохранено: done/56cbf56b-55ef-11ee-ab6d-0050568844e6_1.csv
# Сохранено: done/56cbf56b-55ef-11ee-ab6d-0050568844e6_2.csv
# Сохранено: done/56cbf56b-55ef-11ee-ab6d-0050568844e6_3.csv
# Сохранено: done/56cbf56b-55ef-11ee-ab6d-0050568844e6_4.csv
# Сохранено: done/56cbf56b-55ef-11ee-ab6d-0050568844e6_5.csv
# Сохранено: done/56cbf56b-55ef-11ee-ab6d-0050568844e6_6.csv
# Сохранено: done/0a992bef-610b-11ee-ab6d-0050568844e6_1.csv
# Сохранено: done/0a992bef-610b-11ee-ab6d-0050568844e6_2.csv
# Сохранено: done/0a992bef-610b-11ee-ab6d-0050568844e6_3.csv
# Сохранено: done/0a992bef-610b-11ee-ab6d-0050568844e6_4.csv
# Сохранено: done/0a992bef-610b-11ee-ab6d-0050568844e6_5.csv
# Сохранено: done/0a992bef-610b-11ee-ab6d-0050568844e6_6.csv
# Сохранено: done/0a992bef-610b-11ee-ab6d-0050568844e6_7.csv
# Сохранено: done/afc9d801-4e42-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/afc9d801-4e42-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/afc9d801-4e42-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/afc9d801-4e42-11ef-ab70-0050568844e6_4.csv
# Сохранено: done/afc9d801-4e42-11ef-ab70-0050568844e6_5.csv
# Сохранено: done/afc9d801-4e42-11ef-ab70-0050568844e6_6.csv
# Сохранено: done/afc9d801-4e42-11ef-ab70-0050568844e6_7.csv
# Сохранено: done/afc9d801-4e42-11ef-ab70-0050568844e6_8.csv
# Сохранено: done/30dc6c21-50b7-11ef-8607-005056880ecb_1.csv
# Сохранено: done/30dc6c21-50b7-11ef-8607-005056880ecb_2.csv
# Сохранено: done/30dc6c21-50b7-11ef-8607-005056880ecb_3.csv
# Сохранено: done/30dc6c21-50b7-11ef-8607-005056880ecb_4.csv
# Сохранено: done/30dc6c21-50b7-11ef-8607-005056880ecb_5.csv
# Сохранено: done/30dc6c21-50b7-11ef-8607-005056880ecb_6.csv
# Сохранено: done/30dc6c21-50b7-11ef-8607-005056880ecb_7.csv
# Сохранено: done/c252822c-5497-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/c252822c-5497-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/c252822c-5497-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/c252822c-5497-11ef-ab70-0050568844e6_4.csv
# Сохранено: done/c252822c-5497-11ef-ab70-0050568844e6_5.csv
# Сохранено: done/c252822c-5497-11ef-ab70-0050568844e6_6.csv
# Сохранено: done/c252822c-5497-11ef-ab70-0050568844e6_7.csv
# Сохранено: done/c252822c-5497-11ef-ab70-0050568844e6_8.csv
# Сохранено: done/c252822c-5497-11ef-ab70-0050568844e6_9.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_1.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_2.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_3.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_4.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_5.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_6.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_7.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_8.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_9.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_10.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_11.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_12.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_13.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_14.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_15.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_16.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_17.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_18.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_19.csv
# Сохранено: done/8ebc53a6-6357-11ee-ab6d-0050568844e6_20.csv
# Сохранено: done/22307b6b-6b63-11ef-8607-005056880ecb_1.csv
# Сохранено: done/22307b6b-6b63-11ef-8607-005056880ecb_2.csv
# Сохранено: done/22307b6b-6b63-11ef-8607-005056880ecb_3.csv
# Сохранено: done/fa6e833d-690f-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/fa6e833d-690f-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/fa6e833d-690f-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/fa6e833d-690f-11ef-ab70-0050568844e6_4.csv
# Сохранено: done/fa6e833d-690f-11ef-ab70-0050568844e6_5.csv
# Сохранено: done/fa6e833d-690f-11ef-ab70-0050568844e6_6.csv
# Сохранено: done/fa6e833d-690f-11ef-ab70-0050568844e6_7.csv
# Сохранено: done/fa6e833d-690f-11ef-ab70-0050568844e6_8.csv
# Сохранено: done/69f13457-7020-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/69f13457-7020-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/69f13457-7020-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/69f13457-7020-11ef-ab70-0050568844e6_4.csv
# Сохранено: done/69f13457-7020-11ef-ab70-0050568844e6_5.csv
# Сохранено: done/69f13457-7020-11ef-ab70-0050568844e6_6.csv
# Сохранено: done/69f13457-7020-11ef-ab70-0050568844e6_7.csv
# Сохранено: done/69f13457-7020-11ef-ab70-0050568844e6_8.csv
# Сохранено: done/481d0fb1-7b13-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/481d0fb1-7b13-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/481d0fb1-7b13-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/481d0fb1-7b13-11ef-ab70-0050568844e6_4.csv
# Сохранено: done/481d0fb1-7b13-11ef-ab70-0050568844e6_5.csv
# Сохранено: done/481d0fb1-7b13-11ef-ab70-0050568844e6_6.csv
# Сохранено: done/4f7fae01-86e5-11ef-ab70-0050568844e6_1.csv
# Сохранено: done/4f7fae01-86e5-11ef-ab70-0050568844e6_2.csv
# Сохранено: done/4f7fae01-86e5-11ef-ab70-0050568844e6_3.csv
# Сохранено: done/e8e7f3c5-61bb-11ee-ab6d-0050568844e6_1.csv
# Сохранено: done/e8e7f3c5-61bb-11ee-ab6d-0050568844e6_2.csv
# Сохранено: done/e8e7f3c5-61bb-11ee-ab6d-0050568844e6_3.csv
# Сохранено: done/e8e7f3c5-61bb-11ee-ab6d-0050568844e6_4.csv
# Сохранено: done/e8e7f3c5-61bb-11ee-ab6d-0050568844e6_5.csv
# Сохранено: done/e8e7f3c5-61bb-11ee-ab6d-0050568844e6_6.csv
# Сохранено: done/e8e7f3c5-61bb-11ee-ab6d-0050568844e6_7.csv
# Сохранено: done/e8e7f3c5-61bb-11ee-ab6d-0050568844e6_8.csv
# Сохранено: done/d85c6eaa-820c-11ee-8604-005056880ecb_1.csv
# Сохранено: done/d85c6eaa-820c-11ee-8604-005056880ecb_2.csv
# Сохранено: done/d85c6eaa-820c-11ee-8604-005056880ecb_3.csv
# Сохранено: done/d85c6eaa-820c-11ee-8604-005056880ecb_4.csv
# Сохранено: done/d85c6eaa-820c-11ee-8604-005056880ecb_5.csv
# Сохранено: done/d85c6eaa-820c-11ee-8604-005056880ecb_6.csv
# Сохранено: done/d85c6eaa-820c-11ee-8604-005056880ecb_7.csv
# Сохранено: done/e80ceac9-82d6-11ee-ab6d-0050568844e6_1.csv
# Сохранено: done/e80ceac9-82d6-11ee-ab6d-0050568844e6_2.csv
# Сохранено: done/2f078398-8e98-11ee-8606-005056880ecb_1.csv
# Сохранено: done/2f078398-8e98-11ee-8606-005056880ecb_2.csv
# Сохранено: done/2f078398-8e98-11ee-8606-005056880ecb_3.csv
# Сохранено: done/2f078398-8e98-11ee-8606-005056880ecb_4.csv
# Сохранено: done/2f078398-8e98-11ee-8606-005056880ecb_5.csv
# Сохранено: done/2f078398-8e98-11ee-8606-005056880ecb_6.csv
# Сохранено: done/2f078398-8e98-11ee-8606-005056880ecb_7.csv
# Сохранено: done/6dadac1a-89ca-11ee-ab6f-0050568844e6_1.csv
# Сохранено: done/6dadac1a-89ca-11ee-ab6f-0050568844e6_2.csv
# Сохранено: done/6dadac1a-89ca-11ee-ab6f-0050568844e6_3.csv
# Сохранено: done/6dadac1a-89ca-11ee-ab6f-0050568844e6_4.csv
# Сохранено: done/6dadac1a-89ca-11ee-ab6f-0050568844e6_5.csv
# Сохранено: done/6dadac1a-89ca-11ee-ab6f-0050568844e6_6.csv
# Сохранено: done/6dadac1a-89ca-11ee-ab6f-0050568844e6_7.csv
# Сохранено: done/bdda164d-9fd4-11ee-ab6f-0050568844e6_1.csv
# Сохранено: done/bdda164d-9fd4-11ee-ab6f-0050568844e6_2.csv
# Сохранено: done/bdda164d-9fd4-11ee-ab6f-0050568844e6_3.csv
# Сохранено: done/bdda164d-9fd4-11ee-ab6f-0050568844e6_4.csv
# Сохранено: done/bdda164d-9fd4-11ee-ab6f-0050568844e6_5.csv
# Сохранено: done/bdda164d-9fd4-11ee-ab6f-0050568844e6_6.csv
# Сохранено: done/451527e2-b04a-11ee-ab6f-0050568844e6_1.csv
# Сохранено: done/451527e2-b04a-11ee-ab6f-0050568844e6_2.csv
# Сохранено: done/451527e2-b04a-11ee-ab6f-0050568844e6_3.csv
# Сохранено: done/451527e2-b04a-11ee-ab6f-0050568844e6_4.csv
# Сохранено: done/451527e2-b04a-11ee-ab6f-0050568844e6_5.csv
# Сохранено: done/451527e2-b04a-11ee-ab6f-0050568844e6_6.csv
# Сохранено: done/35466647-aeaf-11ee-ab6f-0050568844e6_1.csv
# Сохранено: done/35466647-aeaf-11ee-ab6f-0050568844e6_2.csv
# Сохранено: done/35466647-aeaf-11ee-ab6f-0050568844e6_3.csv
# Сохранено: done/69714728-b691-11ee-8606-005056880ecb_1.csv
# Сохранено: done/69714728-b691-11ee-8606-005056880ecb_2.csv
# Сохранено: done/69714728-b691-11ee-8606-005056880ecb_3.csv
# Сохранено: done/69714728-b691-11ee-8606-005056880ecb_4.csv
# Сохранено: done/ffdf0ad3-bb5b-11ee-ab6f-0050568844e6_1.csv
# Сохранено: done/ffdf0ad3-bb5b-11ee-ab6f-0050568844e6_2.csv
# Сохранено: done/ffdf0ad3-bb5b-11ee-ab6f-0050568844e6_3.csv
# Сохранено: done/ffdf0ad3-bb5b-11ee-ab6f-0050568844e6_4.csv
# Сохранено: done/ffdf0ad3-bb5b-11ee-ab6f-0050568844e6_5.csv
# Сохранено: done/ffdf0ad3-bb5b-11ee-ab6f-0050568844e6_6.csv
# Сохранено: done/ffdf0ad3-bb5b-11ee-ab6f-0050568844e6_7.csv
# Сохранено: done/20f82885-b5cf-11ee-ab6f-0050568844e6_1.csv
# Сохранено: done/20f82885-b5cf-11ee-ab6f-0050568844e6_2.csv
# Сохранено: done/20f82885-b5cf-11ee-ab6f-0050568844e6_3.csv
# Сохранено: done/20f82885-b5cf-11ee-ab6f-0050568844e6_4.csv
# Сохранено: done/20f82885-b5cf-11ee-ab6f-0050568844e6_5.csv
# Сохранено: done/20f82885-b5cf-11ee-ab6f-0050568844e6_6.csv
# Сохранено: done/20f82885-b5cf-11ee-ab6f-0050568844e6_7.csv
# Сохранено: done/20f82885-b5cf-11ee-ab6f-0050568844e6_8.csv
# Сохранено: done/20f82885-b5cf-11ee-ab6f-0050568844e6_9.csv
# Сохранено: done/20f82885-b5cf-11ee-ab6f-0050568844e6_10.csv
# Сохранено: done/6166e156-c1af-11ed-8602-005056880ecb_1.csv
# Сохранено: done/6166e156-c1af-11ed-8602-005056880ecb_2.csv
# Сохранено: done/6166e156-c1af-11ed-8602-005056880ecb_3.csv
# Сохранено: done/6166e156-c1af-11ed-8602-005056880ecb_4.csv
# Сохранено: done/6166e156-c1af-11ed-8602-005056880ecb_5.csv
# Сохранено: done/516f652e-8bb8-11eb-bb95-2cea7fe73f75_1.csv

# %%
# Путь к папке, где находятся таблицы
folder_path = './done'

# %%
# Список всех CSV-файлов в папке
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Список для хранения всех данных
dataframes = []

# Обработка каждого CSV-файла
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    
    # Извлечение имени файла без расширения
    file_id = os.path.splitext(file)[0]
    
    # Перезапись значений в колонке ID
    if 'ID' in df.columns:
        df['ID'] = file_id
    else:
        # В случае отсутствия колонки ID создаём с нужным значением
        df['ID'] = file_id
    
    # Добавляем обработанную таблицу в список
    dataframes.append(df)

# Объединение всех таблиц
combined_df = pd.concat(dataframes, ignore_index=True)

# Сохранение в clean.csv
output_file = "data/id_clean.csv"
combined_df.to_csv(output_file, index=False)

# %%
# Открыть файл clean.csv
file_path = 'data/id_clean.csv'
data = pd.read_csv(file_path)

# %%
# Удаляем колонку ID
data = data.drop(columns=['ID'])

# %%
# Сохраняем файл под новым названием leucosis.csv
new_file_path = 'data/leucosis.csv'
data.to_csv(new_file_path, index=False)
